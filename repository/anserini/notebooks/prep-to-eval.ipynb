# %%
import json
import jsonlines

# %%
predicted_path='/home/ryparmar/pyserini/ctk/retrieval-nfc/predicted.dev.tsv'
org_dev='/mnt/data/factcheck/CTK/par5/ctk-data/dev.jsonl'
output_path='/mnt/data/factcheck/CTK/par5/predictions/dev_anserini_k500.jsonl'

# %%
def load_jsonl(input_path: str) -> list:
    """Read list of objects from a JSON lines file."""
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.rstrip('\n|\r')))
    return data

# %%
def save_jsonl(data: list, output_path: str, append=False):
    """Write list of objects to a JSON lines file."""
    mode = 'a+' if append else 'w'
    with open(output_path, mode, encoding='utf-8') as f:
        for line in data:
            json_record = json.dumps(line, ensure_ascii=False)
            f.write(json_record + '\n')
    print('Wrote {} records to {}'.format(len(data), output_path))

# %%
def load_anserini_predictions(path: str):
    with open(path) as fr:
        predictions = {}
        for line in fr.readlines():
            idx, pred_id, _ = line.split('\t')
            if idx not in predictions:
                predictions[idx] = [pred_id]
            else:
                predictions[idx].append(pred_id)
    return predictions

# %%
dev = load_jsonl(org_dev)

# %%
dev
# Out:
# [{'id': 24,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Společnost Bühler Motor Hradec Králové vlastní výrobní halu za 90 miliónů korun.',
#   'evidence': [[[-1, 15, '20020322E03049_1', -1]],
#    [[-1, 260, '20020322E03049_1', -1]],
#    [[-1, 957, '20020322E03049_1', -1]]],
#   'orig_par_id': '20020322E03049_1'},
#  {'id': 70,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Andrzej Žulawski zemřel na rakovinu.',
#   'evidence': [[[-1, 28, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 27,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Společnost Bühler Motor otevřela výrobní halu za 90 miliónů korun v Hradci Králové.',
#   'evidence': [[[-1, 37, '20020322E03049_1', -1]],
#    [[-1, 243, '20020322E03049_1', -1]]],
#   'orig_par_id': '20020322E03049_1'},
#  {'id': 32,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Christof Furtwängler nepracuje pro firmu Bühler Motor.',
#   'evidence': [[[-1, 40, '20020322E03049_1', -1]],
#    [[-1, 1451, '20020322E03049_1', -1]]],
#   'orig_par_id': '20020322E03049_1'},
#  {'id': 31,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Christof Furtwängler je jednatelem firmy.',
#   'evidence': [[[-1, 45, '20020322E03049_1', -1]],
#    [[-1, 98, '20020322E03049_1', -1]]],
#   'orig_par_id': '20020322E03049_1'},
#  {'id': 75,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Žulawski zemřel na COVID-19.',
#   'evidence': [[[-1, 47, 'T201602170468301_1', -1]],
#    [[-1, 198, 'T201602170468301_1', -1]],
#    [[-1, 1068, 'T201602170468301_1', -1]],
#    [[-1, 1583, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 64,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Andrzej Žulawski zemřel v Polsku ve věku 75 let.',
#   'evidence': [[[-1, 48, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 62,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Ve věku 75 let zemřel Andrzej Žulawski.',
#   'evidence': [[[-1, 49, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 29,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Jednatel firmy Bühler Motor se jmenuje Christof Furtwängler.',
#   'evidence': [[[-1, 52, '20020322E03049_1', -1]],
#    [[-1, 190, '20020322E03049_1', -1]],
#    [[-1, 362, '20020322E03049_1', -1]],
#    [[-1, 570, '20020322E03049_1', -1]]],
#   'orig_par_id': '20020322E03049_1'},
#  {'id': 25,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Společnost Bühler Motor otevřela výrobní halu.',
#   'evidence': [[[-1, 55, '20020322E03049_1', -1]],
#    [[-1, 636, '20020322E03049_1', -1]],
#    [[-1, 948, '20020322E03049_1', -1]]],
#   'orig_par_id': '20020322E03049_1'},
#  {'id': 63,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Andrzej Žulawski zemřel ve věku 53 let.',
#   'evidence': [[[-1, 59, 'T201602170468301_1', -1]],
#    [[-1, 912, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 69,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Andrzej Žulawski se narodil v Rakousku.',
#   'evidence': [[[-1, 64, 'T201602170468301_1', -1]],
#    [[-1, 239, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 240,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Režisér kontroverzního snímku Třetí část noci (1971) zemřel ve Lvově.',
#   'evidence': [[[-1, 67, 'T201602170468301_1', -1]],
#    [[-1, 1269, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 126,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Příčiny havárie raketoplánů Challenger a Columbie byly rozdílné.',
#   'evidence': [[[-1, 79, '20050619F00320_1', -1]]],
#   'orig_par_id': '20050619F00320_1'},
#  {'id': 326,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'V Havaně zemřel kubánský disident Chepe.',
#   'evidence': [[[-1, 86, 'T201309230523601_1', -1]],
#    [[-1, 611, 'T201309230523601_1', -1], [-1, 611, 'T201309230523601_2', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 348,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Slovenský prezident apeloval na maďarskou hlavu státu, aby nejela v den výročí okupace vojsky Varšavské smlouvy na Slovensko.',
#   'evidence': [[[-1, 119, 'T200908210782602_8', -1]],
#    [[-1, 335, 'T200908210782602_8', -1]]],
#   'orig_par_id': 'T200908210782602_8'},
#  {'id': 353,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Slovenský prezident nemluvil se svým maďarským protějškem.',
#   'evidence': [[[-1, 135, 'T200908210782602_8', -1]]],
#   'orig_par_id': 'T200908210782602_8'},
#  {'id': 352,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Slovenský prezident vyzval svůj maďarský protějšek, aby v den významného výročí nenavštěvoval okupované země.',
#   'evidence': [[[-1, 137, 'T200908210782602_8', -1]]],
#   'orig_par_id': 'T200908210782602_8'},
#  {'id': 58,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V Polsku byl The Devil zakázán.',
#   'evidence': [[[-1, 143, 'T201602170468301_2', -1]],
#    [[-1, 807, 'T201602170468301_2', -1]],
#    [[-1, 846, 'T201602170468301_2', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 235,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Oceňovaný polský režisér Andrzej Žulawski zmizel.',
#   'evidence': [[[-1, 144, 'T201602170468301_1', -1]],
#    [[-1, 866, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 343,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Irácký premiér Ajád Aláví chce obhájit svůj mandát.',
#   'evidence': [[[-1, 152, '20050304F01164_7', -1]],
#    [[-1, 527, '20050304F01164_7', -1]]],
#   'orig_par_id': '20050304F01164_7'},
#  {'id': 65,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Andrzej Žulawski zemřel.',
#   'evidence': [[[-1, 153, 'T201602170468301_1', -1]],
#    [[-1, 257, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 71,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Andrzej Zulawski utrpěl infarkt.',
#   'evidence': [[[-1, 163, 'T201602170468301_1', -1]],
#    [[-1, 231, 'T201602170468301_1', -1]],
#    [[-1, 1325, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 233,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Oceňovaný polský režisér Andrzej Žulawski skonal na rakovinu.',
#   'evidence': [[[-1, 166, 'T201602170468301_1', -1]],
#    [[-1, 333, 'T201602170468301_1', -1]],
#    [[-1, 617, 'T201602170468301_1', -1]],
#    [[-1, 829, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 239,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Režisér kontroverzního snímku Třetí část noci (1971) zemřel v Polsku.',
#   'evidence': [[[-1, 182, 'T201602170468301_1', -1],
#     [-1, 182, 'T201602170468301_2', -1]],
#    [[-1, 299, 'T201602170468301_1', -1], [-1, 299, 'T201602170468301_2', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 234,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Oceňovaný polský režisér Andrzej Žulawski zemřel na infarkt.',
#   'evidence': [[[-1, 205, 'T201602170468301_1', -1]],
#    [[-1, 327, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 331,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Obránci lidských práv na Kubě vyloučili onemocnění jater jako příčinu Chepeho smrti.',
#   'evidence': [[[-1, 256, 'T201309230523601_1', -1]],
#    [[-1, 385, 'T201309230523601_1', -1]],
#    [[-1, 426, 'T201309230523601_1', -1], [-1, 426, 'T201309230523601_2', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 125,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Mise raketoplánů Challenger i Columbie skončila neúspěchem a havárií.',
#   'evidence': [[[-1, 273, '20050619F00320_1', -1],
#     [-1, 273, '20050619F00320_2', -1],
#     [-1, 273, '20050619F00320_3', -1],
#     [-1, 273, '20050619F00320_6', -1],
#     [-1, 273, '20050619F00320_7', -1]]],
#   'orig_par_id': '20050619F00320_1'},
#  {'id': 504,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kolumbie má kvůli únosům nechvalnou pověst.',
#   'evidence': [[[-1, 279, '20010131F08007_1', -1]],
#    [[-1, 1330, '20010131F08007_1', -1]]],
#   'orig_par_id': '20010131F08007_1'},
#  {'id': 616,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Šéfovi Všeobecné zdravotní pojišťovny Pavlu Horákovi hrozí, že bude odvolán.',
#   'evidence': [[[-1, 298, 'T201203220862701_2', -1],
#     [-1, 298, 'T201203220862701_4', -1],
#     [-1, 298, 'T201203220862701_5', -1],
#     [-1, 298, 'T201203220862701_6', -1]],
#    [[-1, 357, 'T201203220862701_2', -1]],
#    [[-1, 615, 'T201203220862701_2', -1]],
#    [[-1, 1342, 'T201203220862701_2', -1]]],
#   'orig_par_id': 'T201203220862701_2'},
#  {'id': 626,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Vozy Fiat 126 se vyráběly v Evropě.',
#   'evidence': [[[-1, 369, 'T201008250441401_5', -1],
#     [-1, 369, 'T201008250441401_9', -1]]],
#   'orig_par_id': 'T201008250441401_12'},
#  {'id': 760,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Bill Clinton bývá považován za nejvýznamnějšího žijícího jazykovědce.',
#   'evidence': [[[-1, 374, 'T201406020628801_1', -1]],
#    [[-1, 456, 'T201406020628801_3', -1]]],
#   'orig_par_id': 'T201406020628801_3'},
#  {'id': 761,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Noam Chomsky bývá považován za nejvýznamnějšího žijícího křesťana.',
#   'evidence': [[[-1, 379, 'T201406020628801_1', -1],
#     [-1, 379, 'T201406020628801_3', -1]]],
#   'orig_par_id': 'T201406020628801_3'},
#  {'id': 759,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Noam Chomsky bývá považován za nejvýznamnějšího žijícího lingvistu.',
#   'evidence': [[[-1, 380, 'T201406020628801_3', -1]],
#    [[-1, 708, 'T201406020628801_3', -1]]],
#   'orig_par_id': 'T201406020628801_3'},
#  {'id': 757,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Hlavní kubánský disident Oscar Espinosa Chepe dnes oslavoval.',
#   'evidence': [[[-1, 381, 'T201309230523601_1', -1]],
#    [[-1, 751, 'T201309230523601_1', -1]],
#    [[-1, 805, 'T201309230523601_1', -1]],
#    [[-1, 1436, 'T201309230523601_1', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 67,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Žulawski je slovenský režisér.',
#   'evidence': [[[-1, 392, 'T201602170468301_1', -1]],
#    [[-1, 1519, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 344,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Irácký premiér Ajád Aláví již nechce dále vykonávat svou funkci.',
#   'evidence': [[[-1, 413, '20050304F01164_7', -1]]],
#   'orig_par_id': '20050304F01164_7'},
#  {'id': 659,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'S 2000 únosy za rok je Kolumbie první na světě.',
#   'evidence': [[[-1, 422, '20010131F08007_5', -1]],
#    [[-1, 461, '20010131F08007_5', -1]],
#    [[-1, 886, '20010131F08007_5', -1]],
#    [[-1, 1106, '20010131F08007_5', -1]]],
#   'orig_par_id': '20010131F08007_1'},
#  {'id': 660,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Zločinnost v Kolumbii roste.',
#   'evidence': [[[-1, 423, '20010131F08007_1', -1],
#     [-1, 423, '20010131F08007_5', -1]]],
#   'orig_par_id': '20010131F08007_1'},
#  {'id': 611,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Středočeský kraj nabízí stipendia pro zahraniční studenty.',
#   'evidence': [[[-1, 428, 'T201110240362601_1', -1],
#     [-1, 428, 'T201110240362601_4', -1]]],
#   'orig_par_id': 'T201110240362601_4'},
#  {'id': 755,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Přední kubánský disident Oscar Espinosa Chepe dnes skonal.',
#   'evidence': [[[-1, 438, 'T201309230523601_1', -1],
#     [-1, 438, 'T201309230523601_2', -1]],
#    [[-1, 612, 'T201309230523601_1', -1], [-1, 612, 'T201309230523601_2', -1]],
#    [[-1, 1643, 'T201309230523601_1', -1],
#     [-1, 1643, 'T201309230523601_2', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 627,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Méně než 70% všech vozů Fiat 126 bylo vyrobeno v Polsku.',
#   'evidence': [[[-1, 472, 'T201008250441401_12', -1]],
#    [[-1, 1416, 'T201008250441401_12', -1]]],
#   'orig_par_id': 'T201008250441401_12'},
#  {'id': 881,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Kanadský ministr životního prostředí Peter Kent oznámil, že se Kanada nepřipojila ke Kjótského protokolu.',
#   'evidence': [[[-1, 500, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 890,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Kanada zůstává zastáncem Kjótského protokolu.',
#   'evidence': [[[-1, 501, 'T201112130836202_3', -1],
#     [-1, 501, 'T201112130836202_4', -1],
#     [-1, 501, 'T201112130836202_5', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 883,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Podle španělského ministra životního prostředí Petera Kenta protokol o snižování emisí skleníkových plynů nefunguje.',
#   'evidence': [[[-1, 504, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 878,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Kanadský ministr financí Peter Kent oznámil, že Kanada odstoupila od Kjótského protokolu.',
#   'evidence': [[[-1, 505, 'T201112130836202_3', -1]],
#    [[-1, 1512, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 888,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Kanada jako první země odstoupila od smlouvy s dodavatelem elektřiny.',
#   'evidence': [[[-1, 507, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 880,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kanadský ministr životního prostředí Peter Kent oznámil, že Kanada odstoupila od protokolu k větší ochraně životního prostředí.',
#   'evidence': [[[-1, 509, 'T201112130836202_3', -1]],
#    [[-1, 1640, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 889,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kanada jako první země odstoupila od protokolu k ochraně životního prostředí.',
#   'evidence': [[[-1, 511, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 885,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Podle kanadského politika protokol o snižování emisí skleníkových plynů nefunguje.',
#   'evidence': [[[-1, 512, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 507,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Bogota je světovou metropolí únosů.',
#   'evidence': [[[-1, 528, '20010131F08007_1', -1]]],
#   'orig_par_id': '20010131F08007_1'},
#  {'id': 243,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Režisér kontroverzních filmů zemřel ve Varšavě.',
#   'evidence': [[[-1, 529, 'T201602170468301_1', -1],
#     [-1, 529, 'T201602170468301_2', -1]],
#    [[-1, 607, 'T201602170468301_1', -1], [-1, 607, 'T201602170468301_2', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 72,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Obama zemřel na rakovinu.',
#   'evidence': [[[-1, 531, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 884,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Podle kanadského ministra životního prostředí Petera Kenta protokol o vodním hospodářství nefunguje.',
#   'evidence': [[[-1, 554, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 328,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V hlavním městě evropské země zemřel kubánský disident Chepe.',
#   'evidence': [[[-1, 569, 'T201309230523601_1', -1]],
#    [[-1, 1644, 'T201309230523601_1', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 989,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Spolupráce finančních skupin vyšla zhruba na 30,2 miliard korun.',
#   'evidence': [[[-1, 571, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 985,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Dohoda mezi pojišťovnou Zurich a bankou Santander umožní švýcarské skupině přístup k trhům zemí amerického kontinentu jižně od USA.',
#   'evidence': [[[-1, 574, 'T201102220276901_1', -1]],
#    [[-1, 1124, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 981,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Pojišťovna Zurich bude mít přístup k latinskoamerickému obchodu díky dohodě s bankou Santander.',
#   'evidence': [[[-1, 579, 'T201102220276901_1', -1],
#     [-1, 579, 'T201102220276901_5', -1]],
#    [[-1, 790, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 984,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Spolupráce pojišťovny Zurich a banky Santander zpřístupní švýcarské skupině rychle rostoucí trhy a španělské instituci kapitál na další akvizice v Latinské Americe.',
#   'evidence': [[[-1, 582, 'T201102220276901_1', -1]],
#    [[-1, 791, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 986,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Spolupráce pojišťovny Zurich a banky Santander zamezila přístup švýcarské skupiny k trhům v Latinské Americe.',
#   'evidence': [[[-1, 585, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 988,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Dohoda institucí vyšla zhruba na 40 miliard korun.',
#   'evidence': [[[-1, 587, 'T201102220276901_1', -1]],
#    [[-1, 775, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 886,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Podle kanadského ministra životního prostředí Petera Kenta je protokol o snižování emisí skleníkových plynů účinný.',
#   'evidence': [[[-1, 591, 'T201112130836202_3', -1],
#     [-1, 591, 'T201112130836202_4', -1],
#     [-1, 591, 'T201112130836202_5', -1]],
#    [[-1, 773, 'T201112130836202_3', -1]]],
#   'orig_par_id': 'T201112130836202_3'},
#  {'id': 325,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V hlavním městě Španělska zemřel kubánský disident Chepe.',
#   'evidence': [[[-1, 603, 'T201309230523601_1', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 329,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Podle ochránců lidských práv na Kubě Castro podlehl onemocnění jater.',
#   'evidence': [[[-1, 635, 'T201309230523601_1', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 1098,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Noam Chomsky je emeritním profesorem lingvistiky na Massachusettském technologickém institutu ve Spojených státech.',
#   'evidence': [[[-1, 651, 'T201406020628801_3', -1],
#     [-1, 651, 'T200811050578801_13', -1]]],
#   'orig_par_id': 'T201406020628801_3'},
#  {'id': 1090,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Ředitel plzeňské ČOI Václav Havlík informaci o zabavení padělaného zboží před ČTK zamlčel.',
#   'evidence': [[[-1, 653, '20050912F00303_1', -1],
#     [-1, 653, '20050203F01154_1', -1],
#     [-1, 653, '20050705E02322_1', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1082,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Během kontroly na tržnici v Železné Rudě na Klatovsku zabavila Česká obchodní inspekce padělky značkového zboží v hodnotě 15 milionů korun.',
#   'evidence': [[[-1, 657, '20050912F00303_1', -1],
#     [-1, 657, '20040824F01248_1', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1087,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Informaci o prodeji padělaného zboží sdělil rádiu Impuls generální ředitel Generálního ředitelství cel Milan Poulíček.',
#   'evidence': [[[-1, 660, '20050912F00303_1', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1086,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Informaci o porušení podmínek sdělil agentuře Associated Press ředitel brněnské ČOI Karel Havlíček.',
#   'evidence': [[[-1, 661, '20050912F00303_1', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1099,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Chomsky je profesorem lingvistiky na univerzitě v Massachusetts.',
#   'evidence': [[[-1, 662, 'T201406020628801_3', -1]]],
#   'orig_par_id': 'T201406020628801_3'},
#  {'id': 1089,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Informaci sdělil ČTK ředitel plzeňské ČOI Václav Havlík.',
#   'evidence': [[[-1, 663, '20050912F00303_1', -1]],
#    [[-1, 937, '20050912F00303_1', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1096,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Noam Chomsky je profesorem lingvistiky ve výzkumném centru Univerzity Karlovy v Hradci Králové.',
#   'evidence': [[[-1, 664, 'T201406020628801_3', -1]]],
#   'orig_par_id': 'T201406020628801_3'},
#  {'id': 1095,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Americký vědec Noam Chomsky vyučuje jazykovědu na Technologickém institutu v Massachusetts.',
#   'evidence': [[[-1, 665, 'T201406020628801_3', -1]]],
#   'orig_par_id': 'T201406020628801_3'},
#  {'id': 1081,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Státní zemědělská a potravinářská inspekce zabavila v restauraci v Železné Rudě nebezpečné potraviny v hodnotě 15 milionů korun.',
#   'evidence': [[[-1, 666, '20050912F00303_1', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1085,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'O zabavení padělaného zboží informoval Českou tiskovou kancelář Václav Havlík, ředitel plzeňské pobočky České obchodní inspekce.',
#   'evidence': [[[-1, 668, '20050912F00303_1', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1084,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Česká obchodní inspekce povolila na tržnici v Železné Rudě prodej padělaného značkového zboží.',
#   'evidence': [[[-1, 671, '20050912F00303_1', -1],
#     [-1, 671, '20000502E02461_3', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1088,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Informaci o tom, že Česká obchodní inspekce zabavila na tržnici v Železné Rudě padělané zboží za desítky milionů, sdělil České tiskové kanceláři ředitel plzeňské ČOI Václav Havlík.',
#   'evidence': [[[-1, 672, '20050912F00303_1', -1]]],
#   'orig_par_id': '20050912F00303_1'},
#  {'id': 1118,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V Třemošnici na Chrudimsku se otrávil metanolem první člověk.',
#   'evidence': [[[-1, 699, 'T201209210580302_1', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 1116,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'V Moravskoslezském kraji se otrávil metanolem první člověk.',
#   'evidence': [[[-1, 701, 'T201209210580302_4', -1],
#     [-1, 701, 'T201209140257301_8', -1],
#     [-1, 701, 'T201209140211201_6', -1]],
#    [[-1, 855, 'T201209210580302_1', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 1134,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V Česku podlehlo otravě metanolem 23 lidí.',
#   'evidence': [[[-1, 729, 'T201209210580302_4', -1]],
#    [[-1, 783, 'T201209210580302_4', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 1126,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Nejvíce otrav metanolem bylo v Pardubickém kraji.',
#   'evidence': [[[-1, 730, 'T201209210580302_4', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 1119,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V Pardubickém kraji se otrávil člověk.',
#   'evidence': [[[-1, 731, 'T201209210580302_1', -1]],
#    [[-1, 895, 'T201209210580302_1', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 237,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Oceňovaný evropský režisér Andrzej Žulawski zemřel na rakovinu.',
#   'evidence': [[[-1, 742, 'T201602170468301_1', -1]],
#    [[-1, 1511, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 756,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Hlavní kubánský disident Václav Havel dnes zemřel.',
#   'evidence': [[[-1, 743, 'T201309230523601_1', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 1247,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Luděk Niedermayer bude kandidovat za TOP 09 v letošních parlamentních volbách v Česku.',
#   'evidence': [[[-1, 756, 'T201402200946902_1', -1]]],
#   'orig_par_id': 'T201402200946902_1'},
#  {'id': 1250,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Bývalý viceguvernér České národní banky Luděk Niedermayer se rozhodl nekandidovat do Evropského parlamentu za TOP 09.',
#   'evidence': [[[-1, 759, 'T201402200946902_1', -1]]],
#   'orig_par_id': 'T201402200946902_1'},
#  {'id': 1137,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V evropské zemi zemřelo na otravu metanolem 23 lidí.',
#   'evidence': [[[-1, 762, 'T201209210580302_4', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 992,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Soupeření institucí vyšlo každou z firem zhruba na 30,2 miliard korun.',
#   'evidence': [[[-1, 764, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 1280,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kocianovo kvarteto získalo hudební ocenění za nahrávku hudební skladby.',
#   'evidence': [[[-1, 776, 'T200706010229101_1', -1]]],
#   'orig_par_id': 'T200706010229101_1'},
#  {'id': 1311,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Odvolací soud v Kyjevě trest exministra obrany Ivaščenka změnil na roční podmínku.',
#   'evidence': [[[-1, 780, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 1310,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Prezident trest Ivaščenka změnil na roční podmínku.',
#   'evidence': [[[-1, 782, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 1201,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Knihy Neználkův výlet do Slunečního města a Neználek na Měsíci vznikly ve svobodném prostředí.',
#   'evidence': [[[-1, 787, 'T201101190758401_5', -1]]],
#   'orig_par_id': 'T201101190758401_5'},
#  {'id': 1309,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Soud trest Ivaščenka změnil na trest smrti.',
#   'evidence': [[[-1, 793, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 1316,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Bývalý člen vlády částečně přiznal vinu.',
#   'evidence': [[[-1, 794, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 1300,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Odvolací soud propustil ukrajinkského exministra.',
#   'evidence': [[[-1, 797, 'T201208140501101_2', -1]],
#    [[-1, 844, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 1125,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V Moravskoslezském kraji se intoxikovalo metanolem nejvíce lidí.',
#   'evidence': [[[-1, 838, 'T201209210580302_4', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 617,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Řediteli Všeobecné zdravotní pojišťovny Pavlu Horákovi hrozí vyhoštění.',
#   'evidence': [[[-1, 849, 'T201203220862701_2', -1]]],
#   'orig_par_id': 'T201203220862701_2'},
#  {'id': 510,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V Kolumbii přibývá únosů.',
#   'evidence': [[[-1, 878, '20010131F08007_1', -1],
#     [-1, 878, '20010131F08007_5', -1]]],
#   'orig_par_id': '20010131F08007_1'},
#  {'id': 1246,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Bývalý viceguvernér České národní banky Luděk Niedermayer povede kandidátku TOP09 do Evropského parlamentu.',
#   'evidence': [[[-1, 896, 'T201402200946902_1', -1]]],
#   'orig_par_id': 'T201402200946902_1'},
#  {'id': 625,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Přes 70%  všech vozů Fiat 126 bylo vyrobeno v polských montovnách.',
#   'evidence': [[[-1, 902, 'T201008250441401_12', -1]],
#    [[-1, 1414, 'T201008250441401_12', -1]]],
#   'orig_par_id': 'T201008250441401_12'},
#  {'id': 1459,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Proti plesu rakouské FPÖ prostestovali lidé z německého autobusu.',
#   'evidence': [[[-1, 904, 'T201501301144603_1', -1],
#     [-1, 904, 'T201501301144603_3', -1]]],
#   'orig_par_id': 'T201501301144603_7'},
#  {'id': 1313,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Soud trest Ivaščenka nemohl zmírnit na roční podmínku.',
#   'evidence': [[[-1, 907, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 505,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Mexiko je světovou metropolí únosů.',
#   'evidence': [[[-1, 911, '20010131F08007_1', -1]]],
#   'orig_par_id': '20010131F08007_1'},
#  {'id': 1117,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'V Pardubickém kraji se otrávil jedovatými houbami první člověk.',
#   'evidence': [[[-1, 925, 'T201209210580302_1', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 991,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Dohoda přesáhla třicet miliard korun.',
#   'evidence': [[[-1, 935, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 1199,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Knihy Neználkův výlet do Slunečního města z roku 1961 a Neználek na Měsíci z roku 1968 jsou poznamenány komunistickou propagandou.',
#   'evidence': [[[-1, 943, 'T201101190758401_5', -1]],
#    [[-1, 1177, 'T201101190758401_5', -1]]],
#   'orig_par_id': 'T201101190758401_5'},
#  {'id': 1198,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Knihy Neználkův výlet do Slunečního města a Neználek na Měsíci napsal Nikolaj Nosov.',
#   'evidence': [[[-1, 979, 'T201101190758401_1', -1],
#     [-1, 979, 'T201101190758401_5', -1]]],
#   'orig_par_id': 'T201101190758401_5'},
#  {'id': 1554,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Ministr zemědělství Petr Gandalovič dnes oznámil nového šéfa státního podniku Lesy ČR.',
#   'evidence': [[[-1, 1007, 'T200712110528601_5', -1]]],
#   'orig_par_id': 'T200712110528601_5'},
#  {'id': 622,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Přes 70% Fiatů 126 bylo vyrobeno Polské republice.',
#   'evidence': [[[-1, 1016, 'T201008250441401_12', -1]],
#    [[-1, 1415, 'T201008250441401_12', -1]]],
#   'orig_par_id': 'T201008250441401_12'},
#  {'id': 1555,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Ministr zdravotnictví Petr Gandalovič dnes oznámil nového ředitele státního podniku Lesy ČR.',
#   'evidence': [[[-1, 1017, 'T200712110528601_5', -1]]],
#   'orig_par_id': 'T200712110528601_5'},
#  {'id': 1553,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Jiří Novák neuspěl ve výběrovém řízení se 17 konkurenty.',
#   'evidence': [[[-1, 1019, 'T200712110528601_5', -1]],
#    [[-1, 1197, 'T200712110528601_5', -1]]],
#   'orig_par_id': 'T200712110528601_5'},
#  {'id': 1248,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Luděk Niedermayer povede kandidátku TOP 09 do Evropského parlamentu.',
#   'evidence': [[[-1, 1024, 'T201402200946902_1', -1]]],
#   'orig_par_id': 'T201402200946902_1'},
#  {'id': 1297,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Odvolací soud propustil ruského exministra obrany.',
#   'evidence': [[[-1, 1035, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 1521,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kubánský disident Oscar Espinosa Chepe již není mezi živými.',
#   'evidence': [[[-1, 1040, 'T201309230523601_1', -1],
#     [-1, 1040, 'T201309230523601_2', -1]],
#    [[-1, 1277, 'T201309230523601_1', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 624,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Přes 70% všech vozů Fiat 126 je stále provozuschopných.',
#   'evidence': [[[-1, 1076, 'T201008250441401_6', -1],
#     [-1, 1076, 'T201008250441401_7', -1]]],
#   'orig_par_id': 'T201008250441401_12'},
#  {'id': 1299,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Odvolací soud v Kyjevě propusil bývalého ministra obrany Valerije Ivaščenka.',
#   'evidence': [[[-1, 1077, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 1115,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V Pardubickém kraji zemřel na otravu metanolem první člověk.',
#   'evidence': [[[-1, 1134, 'T201209210580302_1', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 1830,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Odpůrce globalizace v Česku nenajdeme.',
#   'evidence': [[[-1, 1184, '20000823F00736_1', -1],
#     [-1, 1184, '20000823F00736_2', -1]]],
#   'orig_par_id': '20000823F00736_1'},
#  {'id': 1520,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kubánský disident Oscar Espinosa Chepe zemřel ve věku 72 let.',
#   'evidence': [[[-1, 1198, 'T201309230523601_1', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 1682,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'KVIFF je filmový festival, který se koná na dvanácti pražských ostrovech.',
#   'evidence': [[[-1, 1233, '20050602F02080_1', -1]]],
#   'orig_par_id': '20050602F02080_3'},
#  {'id': 1871,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Chomsky svými myšlenkami inklinuje k politické pravici.',
#   'evidence': [[[-1, 1265, 'T201406020628801_3', -1]]],
#   'orig_par_id': 'T201406020628801_3'},
#  {'id': 26,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Společnost Bühler Motor vynaložila 90 miliónů korun v Hradci Králové.',
#   'evidence': [[[-1, 1306, '20020322E03049_1', -1]]],
#   'orig_par_id': '20020322E03049_1'},
#  {'id': 1296,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Odvolací soud propustil ukrajinského bývalého člena vlády.',
#   'evidence': [[[-1, 1316, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 66,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Andrzej Žulawski oslavil 80 let.',
#   'evidence': [[[-1, 1320, 'T201602170468301_1', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 1643,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Cílová skupina, kterou chtějí na akci pořadatelé United Islands přilákat, se podobá té loňské.',
#   'evidence': [[[-1, 1321, '20050602F02080_3', -1]],
#    [[-1, 1382, '20050602F02080_3', -1], [-1, 1382, '20050531F01306_4', -1]]],
#   'orig_par_id': '20050602F02080_3'},
#  {'id': 978,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Švýcarská pojišťovna Zurich a španělská banka Santander představily nové společné podnikání v Latinské Americe.',
#   'evidence': [[[-1, 1348, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 1314,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Ivaščenko potvrdil, že je částečně vinný.',
#   'evidence': [[[-1, 1357, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 1196,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Knihy Nikolaje Nosova o Neználkovi jsou poznamenány komunistikcou propagandou.',
#   'evidence': [[[-1, 1392, 'T201101190758401_5', -1]],
#    [[-1, 1429, 'T201101190758401_1', -1],
#     [-1, 1429, 'T201101190758401_5', -1]]],
#   'orig_par_id': 'T201101190758401_5'},
#  {'id': 1556,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Ministr Petr Gandalovič dnes oznámil nového ředitele vybraného státního podniku.',
#   'evidence': [[[-1, 1393, 'T200712110528601_5', -1]],
#    [[-1, 1605, 'T200712110528601_5', -1]]],
#   'orig_par_id': 'T200712110528601_5'},
#  {'id': 1967,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Air France vyřadí z provozu nadzvuková letadla Concorde.',
#   'evidence': [[[-1, 1408, '20030410E01205_2', -1]]],
#   'orig_par_id': '20030410E01205_2'},
#  {'id': 1968,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Letecké společnosti vyřazují z provozu nadzvuková letadla Concorde.',
#   'evidence': [[[-1, 1410, '20030410E01205_2', -1]]],
#   'orig_par_id': '20030410E01205_2'},
#  {'id': 1969,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Air France a British Airways zařadí do provozu nadzvuková letadla Concorde.',
#   'evidence': [[[-1, 1411, '20030410E01205_2', -1]]],
#   'orig_par_id': '20030410E01205_2'},
#  {'id': 1323,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Ivaščenko byl ve vládě Oleksije Hončaruka.',
#   'evidence': [[[-1, 1444, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 2058,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Odvolací soud v Kyjevě propustil na svobodu vězněného exministra obrany.',
#   'evidence': [[[-1, 1469, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 2059,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Odvolací soud v Kyjevě nezrušil trest ukrajinského exministra obrany Valerije Ivaščenka.',
#   'evidence': [[[-1, 1470, 'T201208140501101_2', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 975,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Španělská banka Santander a švýcarská pojišťovna Zurich uzavřely novou dohodu.',
#   'evidence': [[[-1, 1479, 'T201102220276901_1', -1]]],
#   'orig_par_id': 'T201102220276901_1'},
#  {'id': 1557,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Ministr zemědělství Petr Gandalovič dnes odmítl veřejnosti sdělit jméno nového ředitele státního podniku Lesy ČR.',
#   'evidence': [[[-1, 1487, 'T200712110528601_5', -1]]],
#   'orig_par_id': 'T200712110528601_5'},
#  {'id': 1684,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Na festivalu United Islands mohou diváci slyšet nejrůznější interprety a hudební soubory.',
#   'evidence': [[[-1, 1517, '20050602F02080_1', -1]]],
#   'orig_par_id': '20050602F02080_3'},
#  {'id': 1551,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Jiří Novák porazil ve výběrovém řízení 17 soupeřů.',
#   'evidence': [[[-1, 1552, 'T200712110528601_5', -1]]],
#   'orig_par_id': 'T200712110528601_5'},
#  {'id': 2150,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'V roce 1997 byla francouzská cena udělena Kocianovu kvartetu.',
#   'evidence': [[[-1, 1553, 'T200706010229101_1', -1],
#     [-1, 1553, 'T200706010229101_2', -1]],
#    [[-1, 1554, 'T200706010229101_1', -1]]],
#   'orig_par_id': 'T200706010229101_1'},
#  {'id': 2154,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kocianovo kvarteto získalo francouzskou cenu ve 20. století.',
#   'evidence': [[[-1, 1556, 'T200706010229101_1', -1]]],
#   'orig_par_id': 'T200706010229101_1'},
#  {'id': 2155,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Kocianovo kvarteto nikdy nezískalo žádnou cenu.',
#   'evidence': [[[-1, 1557, 'T200706010229101_1', -1]]],
#   'orig_par_id': 'T200706010229101_1'},
#  {'id': 2141,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kocianovo kvarteto získalo francouzskou cenu nazvanou Velká cena francouzské Akademie Charlese Crose.',
#   'evidence': [[[-1, 1558, 'T200706010229101_1', -1]]],
#   'orig_par_id': 'T200706010229101_1'},
#  {'id': 2142,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Kocianovo kvarteto získalo cenu.',
#   'evidence': [[[-1, 1559, 'T200706010229101_1', -1]]],
#   'orig_par_id': 'T200706010229101_1'},
#  {'id': 2138,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Velká cena francouzské Akademie Charlese Crose byla udělena Kocianovu kvartetu.',
#   'evidence': [[[-1, 1560, 'T200706010229101_1', -1]]],
#   'orig_par_id': 'T200706010229101_1'},
#  {'id': 1983,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Přituhuje ohledně slovensko-maďarských vztahů.',
#   'evidence': [[[-1, 1588, 'T200908210782602_14', -1],
#     [-1, 1588, 'T200908210782602_5', -1],
#     [-1, 1588, 'T200908210782602_7', -1],
#     [-1, 1588, 'T200908210782602_8', -1]]],
#   'orig_par_id': 'T200908210782602_8'},
#  {'id': 1995,
#   'verifiable': 'VERIFIABLE',
#   'label': 'REFUTES',
#   'claim': 'Slovenský prezident požádal maďarského prezidenta o návštěvu Slovenska během výročí okupace Českolovenska vojsky Varšavské smlouvy.',
#   'evidence': [[[-1, 1589, 'T200908210782602_5', -1],
#     [-1, 1589, 'T200908210782602_8', -1]]],
#   'orig_par_id': 'T200908210782602_8'},
#  {'id': 2257,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Maďarský prezident Sólyom neodcestoval 21. sprna 2009 na svou soukromou cestu do Slovenska.',
#   'evidence': [[[-1, 1624, 'T200908210782602_5', -1],
#     [-1, 1624, 'T200908210782602_7', -1]]],
#   'orig_par_id': 'T200908210782602_8'},
#  {'id': 2254,
#   'verifiable': 'VERIFIABLE',
#   'label': 'SUPPORTS',
#   'claim': 'Maďarský prezident Sólyom byl vyzván slovenským prezidentem Gašparovičem, aby nejezdil na Slovensko v den výroční okupace, který připadá na 21. srpen 2009.',
#   'evidence': [[[-1, 1629, 'T200908210782602_8', -1]]],
#   'orig_par_id': 'T200908210782602_8'},
#  {'id': 236,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Oceňovaný polský režisér Andrzej Žulawski zemřel na rakovinu slinivky.',
#   'evidence': [[[-1, 115, 'T200612020478901_10', -1],
#     [-1, 115, 'T201109290716101_12', -1],
#     [-1, 115, 'T201007200234601_6', -1],
#     [-1, 115, 'T201001110175601_6', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 242,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Režisér kontroverzního snímku Třetí část noci (1971) zemřel ve svém varšavském bytě.',
#   'evidence': [[[-1, 159, 'T200612020478901_10', -1],
#     [-1, 159, 'T201109290716101_12', -1],
#     [-1, 159, 'T200912150244801_5', -1],
#     [-1, 159, '20020917E02289_5', -1]]],
#   'orig_par_id': 'T201602170468301_2'},
#  {'id': 658,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'V Brazílii se prodá nejvíce banánů v Jižní Americe.',
#   'evidence': [[[-1, 340, '20000413E00840_11', -1],
#     [-1, 340, '20000519F03000_5', -1],
#     [-1, 340, '20000107E00627_6', -1]]],
#   'orig_par_id': '20010131F08007_1'},
#  {'id': 506,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Kolumbie je oblíbenou turistickou destinací.',
#   'evidence': [[[-1, 906, '20000925E00573_10', -1],
#     [-1, 906, '20001114F01452_5', -1],
#     [-1, 906, '20000925E00573_16', -1]]],
#   'orig_par_id': '20010131F08007_1'},
#  {'id': 1519,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Kubánský disident Oscar Espinosa Chepe vyrůstal v Madridu.',
#   'evidence': [[[-1, 952, '20030409E01333_12', -1],
#     [-1, 952, '20041114E01491_4', -1],
#     [-1, 952, '20010523F05518_3', -1],
#     [-1, 952, 'T200710020870201_4', -1]]],
#   'orig_par_id': 'T201309230523601_1'},
#  {'id': 1686,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'KVIFF je artový filmový festival.',
#   'evidence': [[[-1, 1089, '20020326E03417_5', -1],
#     [-1, 1089, '20030901E03698_3', -1],
#     [-1, 1089, '20010108F01562_3', -1],
#     [-1, 1089, '20040828E00914_5', -1]]],
#   'orig_par_id': '20050602F02080_3'},
#  {'id': 1671,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Pořadatelé připravili pro seniory doprovodnou scénu.',
#   'evidence': [[[-1, 1090, '20031122E01609_4', -1],
#     [-1, 1090, '20041209F00708_7', -1]]],
#   'orig_par_id': '20050602F02080_3'},
#  {'id': 1282,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Producent získal ocenění za nahrávku hudební skladby.',
#   'evidence': [[[-1, 1391, 'T200702010183101_3', -1],
#     [-1, 1391, '20060215E05426_9', -1],
#     [-1, 1391, '20030430F01976_3', -1],
#     [-1, 1391, '20040126F01378_5', -1]]],
#   'orig_par_id': 'T200706010229101_1'},
#  {'id': 1966,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Air France a British Airways vyřadí z provozu letadla Boeing 737.',
#   'evidence': [[[-1, 1407, '20010620E01034_4', -1],
#     [-1, 1407, '20011107E04104_7', -1],
#     [-1, 1407, '20011107F01704_6', -1],
#     [-1, 1407, '20020722E01412_3', -1]]],
#   'orig_par_id': '20030410E01205_2'},
#  {'id': 1136,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'V České republice zemřelo na otravu oxidem uhelnatým 23 lidí.',
#   'evidence': [[[-1, 1435, 'T201001180759502_8', -1],
#     [-1, 1435, 'T200707160535101_3', -1],
#     [-1, 1435, '20040609E04353_6', -1]]],
#   'orig_par_id': 'T201209210580302_4'},
#  {'id': 2057,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Odvolací soud v Kábulu propustil všechny politické vězně.',
#   'evidence': [[[-1, 1467, 'T201102210068601_3', -1],
#     [-1, 1467, 'T201008100657202_6', -1],
#     [-1, 1467, '20020404E01361_2', -1],
#     [-1, 1467, 'T200706280150701_5', -1]]],
#   'orig_par_id': 'T201208140501101_2'},
#  {'id': 2140,
#   'verifiable': 'NOT VERIFIABLE',
#   'label': 'NOT ENOUGH INFO',
#   'claim': 'Kocianovo kvarteto získalo Oscara.',
#   'evidence': [[[-1, 1555, '20030419E00022_2', -1],
#     [-1, 1555, '20030419E00022_8', -1],
#     [-1, 1555, '20010908E01531_4', -1],
#     [-1, 1555, 'T200704060245301_8', -1]]],
#   'orig_par_id': 'T200706010229101_1'}]

# %%
predicted = load_anserini_predictions(predicted_path)

# %%
predicted['24']
# Out:
# ['20020322E03049_1',
#  '20010820E01855_10',
#  '20001025F03296_8',
#  '20001025E02353_1',
#  '20020322E03049_0',
#  '20001025E02353_0',
#  'T200607270350401_1',
#  '20001010F02102_1',
#  '20001025E02353_4',
#  'T200803190462701_9',
#  '20011010F03425_1',
#  '20010608F02683_3',
#  'T201301070209701_0',
#  'T202001200859401_1',
#  '20011111E00670_1',
#  'T201311110568501_4',
#  '20020628F02139_1',
#  '20020630E01442_2',
#  '20001025E02353_3',
#  'T201301070298501_11',
#  '20020716E01943_1',
#  '20031126F01589_5',
#  'T201301070209701_1',
#  '20021014E01540_8',
#  '20030227F01628_1',
#  '20010322F01062_3',
#  '20021014E01320_1',
#  '20001203E01132_10',
#  '20021020E01784_11',
#  '20020318E02551_1',
#  '20001025F03029_2',
#  '20001203F01143_1',
#  '20010108F02652_2',
#  '20010514F05336_3',
#  '20021020E00984_1',
#  '20051206E01460_1',
#  'T201504160405901_6',
#  '20000208E01878_1',
#  '20021223F00327_1',
#  '20010925F03545_1',
#  '20020812E02704_4',
#  'T201504160332201_1',
#  '20000727E01583_1',
#  '20000804E01138_0',
#  '20020227F02823_1',
#  '20011127E02197_1',
#  '20020602E01429_5',
#  'T200809090319801_1',
#  '20020812E02704_1',
#  '20020531E02578_1',
#  '20011108F01881_2',
#  '20010627F03875_1',
#  '20020613F01727_1',
#  '20010817E01344_1',
#  '20010412F01918_4',
#  '20000711F01415_1',
#  '20020618F02003_5',
#  '20000811E01479_5',
#  '20011230E01252_4',
#  '20021223F00576_3',
#  '20011009E01252_1',
#  '20010619F03467_9',
#  '20010101E01376_8',
#  '20001129F03677_9',
#  '20020617E04017_1',
#  '20000829F01302_1',
#  '20000905E00830_9',
#  '20040312F01572_1',
#  '20000627E02201_6',
#  '20001229F03631_1',
#  '20010131F03597_1',
#  '20010131F04077_1',
#  '20001016F02162_1',
#  '20000208F01761_5',
#  '20011228E02297_1',
#  '20020621F02261_1',
#  '20010102F02438_1',
#  '20010402F03206_1',
#  '20021223E02159_2',
#  '20021223E02667_2',
#  '20021223F00450_1',
#  '20000804E01138_1',
#  '20001129F02498_1',
#  '20010518F02028_1',
#  '20010521F02975_1',
#  '20010524F01898_10',
#  '20010902F00806_3',
#  '20020725F00804_1',
#  '20040305E01377_9',
#  '20040406F02372_5',
#  '20000628F00850_1',
#  '20010405E01995_1',
#  '20010904E01472_4',
#  '20010628F01171_1',
#  'T201504130593301_4',
#  '20020610E03055_3',
#  '20020619F01680_4',
#  '20020626F02295_3',
#  '20010802F01925_1',
#  '20010718F02485_5',
#  '20011114E02127_4',
#  '20001022F01808_9',
#  '20020513E01859_1',
#  '20010401E02346_9',
#  '20001210F01708_9',
#  '20010517E02197_1',
#  '20050511F01567_1',
#  'T201811270517001_1',
#  '20001208F03189_1',
#  'T201504130555901_1',
#  'T200611270456102_7',
#  '20000315F01684_8',
#  '20020523F02062_1',
#  '20000322F02272_1',
#  '20020205E01108_3',
#  'T200709180418001_1',
#  '20050413F00300_1',
#  '20011026F03224_11',
#  '20010918E02127_1',
#  '20021117E00937_7',
#  '20011026F01409_1',
#  '20000608F01913_7',
#  '20020125F03321_3',
#  '20000203F01727_7',
#  'T201406040493001_1',
#  'T200805140663001_4',
#  'T200806100456901_4',
#  'T200806220186801_4',
#  'T200809030413402_3',
#  '20000825F01544_1',
#  '20021023F01186_1',
#  'T201708230620301_8',
#  'T200606070609102_3',
#  '20000323E03548_5',
#  '20010404F03649_10',
#  '20021117E00551_1',
#  '20001015E01741_1',
#  '20010923F00738_1',
#  '20030528F01662_5',
#  '20020322E03049_5',
#  '20000214F01607_9',
#  '20020624F01574_1',
#  '20041226E00552_1',
#  '20031001E02784_1',
#  '20011026F02470_1',
#  '20000316F01161_1',
#  '20000203F01464_1',
#  '20010404F02932_1',
#  'T201606270375301_6',
#  'T201106010620701_1',
#  '20010116F02422_1',
#  'T201909240692101_10',
#  '20020515F01439_1',
#  '20040610E03125_1',
#  '20001212F00629_1',
#  'T200805160492301_3',
#  '20000222F00892_1',
#  '20010220E01796_9',
#  '20010807E01182_7',
#  '20020621E03524_1',
#  'T201010130683001_6',
#  '20020620F02140_8',
#  '20010629E01912_2',
#  '20021004F00305_1',
#  '20020322E03049_3',
#  '20000211F01156_1',
#  '20000628F00850_5',
#  '20000214F01407_1',
#  '20010911F02953_1',
#  '20010301F02641_3',
#  '20010220F01377_1',
#  '20010622E02941_6',
#  '20011128F02954_9',
#  '20010301E01964_1',
#  '20010116E02759_4',
#  '20010107F00789_4',
#  'T201507100372801_1',
#  '20000626E02042_1',
#  'T200603290638901_1',
#  '20010615F02729_4',
#  '20000911F00843_1',
#  '20020319F01905_2',
#  '20050322F00940_2',
#  '20050906F01746_2',
#  'T201311290485001_4',
#  '20020626F02295_1',
#  'T201606270258301_1',
#  '20010724E02455_1',
#  '20000811E01051_1',
#  '20000504E02531_15',
#  '20010807F01361_1',
#  '20020607F02680_1',
#  '20010402F02185_2',
#  '20000503F02627_6',
#  'T200805210430101_0',
#  'T200704260422301_5',
#  '20010406E03098_2',
#  '20000410E01927_1',
#  'T201405160605901_11',
#  'T201811220528901_0',
#  '20010305F02366_1',
#  '20011128F01609_1',
#  '20000704F01366_1',
#  '20011207E02081_1',
#  '20010622F03260_1',
#  '20040115F01481_8',
#  '20000627F01201_1',
#  '20010808F02485_9',
#  '20010821E01287_3',
#  'T200707190614801_11',
#  '20001123F03224_10',
#  '20011105E02760_1',
#  '20001010F02102_0',
#  '20001210E00723_0',
#  '20011004F04254_0',
#  '20011009F03404_0',
#  '20021112E02147_6',
#  '20021112F00804_1',
#  'T201605130424801_7',
#  '20000915F01764_1',
#  '20020626E02702_3',
#  '20020925F01806_8',
#  '20001019F02246_1',
#  '20020426F01570_1',
#  'T201505050376301_14',
#  '20010621E03251_9',
#  '20010621F03624_9',
#  '20020618E03842_1',
#  'T200911050708802_8',
#  'T201002260588201_4',
#  'T201004070541101_4',
#  'T201004080432901_7',
#  'T201007220191001_5',
#  'T201009070606201_4',
#  'T201009080361501_9',
#  'T201010190299802_11',
#  'T201106290734401_4',
#  'T201106300224201_8',
#  'T201107010463302_11',
#  '20000503F02627_11',
#  '20010426E02799_1',
#  '20000326E01976_8',
#  'T201012050507801_7',
#  'T201901080415901_11',
#  '20050620E02223_5',
#  '20001015F02684_9',
#  '20020813E01909_1',
#  '20000209E02031_1',
#  '20021017E04163_3',
#  '20001123F01998_1',
#  '20010718F01968_1',
#  '20020319F01905_1',
#  'T201805160759001_1',
#  '20050607F00404_1',
#  'T201301110631601_3',
#  '20010622F03768_1',
#  '20010624E02389_5',
#  '20020624F01918_4',
#  '20000820E01515_6',
#  '20011018E01119_13',
#  '20001023F03315_1',
#  'T200711060700501_2',
#  '20001016F02162_0',
#  '20010405E01995_0',
#  '20010530E02966_1',
#  'T201806050382701_13',
#  'T200707190424701_1',
#  '20040115E02944_1',
#  '20040604E01704_1',
#  '20020523F01119_12',
#  '20000414E02209_1',
#  '20001123F02727_1',
#  '20020926E02984_1',
#  '20020722E02461_1',
#  'T201301090335201_1',
#  'T200706060547001_5',
#  '20020526E00911_1',
#  '20000530F01589_4',
#  '20000822F01014_1',
#  'T200806180336501_5',
#  'T200806190432501_4',
#  'T200806200424301_5',
#  'T200806260415501_11',
#  '20020513F00614_4',
#  'T201312030354401_15',
#  '20000503F01806_1',
#  '20010619E02567_1',
#  '20010828F02287_1',
#  '20010621F02628_1',
#  '20021108E01316_2',
#  '20000414F01641_1',
#  'T200605160554301_1',
#  'T201901080293901_1',
#  '20010608F02683_1',
#  '20011018E00899_1',
#  'T201012030514701_1',
#  '20010514F04257_1',
#  '20000326E01329_1',
#  '20020506F00797_7',
#  '20021014E03926_12',
#  'T201806120679901_4',
#  'T201806050166301_1',
#  'T201905050149501_5',
#  '20010213E01784_8',
#  '20000509F01846_1',
#  '20010820F02236_1',
#  'T200901300676001_1',
#  'T201410220383601_3',
#  'T201705090677801_11',
#  'T200808070571201_7',
#  '20020707E00749_1',
#  '20000719F00690_5',
#  '20000817E01806_1',
#  '20020514F00604_1',
#  '20041221E00856_4',
#  '20020225F02359_13',
#  '20020523F01020_1',
#  '20020725E03567_1',
#  'T200604210226501_1',
#  '20020416F01063_1',
#  '20021029F01153_1',
#  '20020528F00465_1',
#  'T200703090234401_1',
#  'T201206300352901_8',
#  'T201109260664601_4',
#  '20000920E02226_6',
#  '20000920F02898_6',
#  '20010712E01002_1',
#  '20010111F04430_4',
#  '20000314F01589_8',
#  'T201805070247001_1',
#  '20021017F00736_1',
#  'T201905030402701_1',
#  'T200805210430101_4',
#  '20021129F00597_3',
#  '20010829E01887_4',
#  '20030902E03142_9',
#  '20000301F00892_6',
#  '20010621F03665_1',
#  '20020430E02751_1',
#  '20020506F00731_1',
#  '20020607F02688_1',
#  '20020726E01446_1',
#  '20021014E02939_1',
#  'T201705090642601_1',
#  'T201805070326101_9',
#  '20041228E02016_3',
#  '20000513E00081_2',
#  'T200909170545202_3',
#  'T200909170650901_11',
#  'T200906100314701_4',
#  '20010926F02278_1',
#  '20000314F01194_1',
#  '20000910F00609_1',
#  '20000530F01589_1',
#  '20010608F02683_0',
#  '20010318F01285_4',
#  'T201506030620501_22',
#  'T201409220379701_0',
#  '20001210E00723_1',
#  'T200810210617401_13',
#  '20000622F00869_1',
#  '20020415E03603_12',
#  'T201104270658401_1',
#  '20011022F02308_5',
#  '20001018E02298_1',
#  '20031013F01504_1',
#  '20000112F01517_1',
#  '20010905F02047_1',
#  '20010417E02592_1',
#  'T200609140246201_1',
#  '20030902E02264_1',
#  '20000427F01134_1',
#  '20000330E01377_3',
#  'T200810020461501_1',
#  '20000522E02985_6',
#  '20020912E02147_1',
#  '20020218F02484_1',
#  '20030821F00991_1',
#  '20020122E03064_1',
#  '20010419E02667_1',
#  '20010410E02257_1',
#  '20021004F02018_1',
#  '20060106F00881_8',
#  '20011219F02538_1',
#  '20021126E03401_1',
#  '20040227F01379_1',
#  '20000521E02123_9',
#  '20020620F02221_1',
#  '20020708E02224_1',
#  'T200712100175601_1',
#  '20040922F01361_5',
#  '20000204E03846_4',
#  '20000321F01676_13',
#  'T201009170698701_6',
#  '20000726E01071_4',
#  '20010513E02193_7',
#  '20000104E01552_1',
#  'T201403100356401_4',
#  '20000804F00719_8',
#  'T200809150540401_1',
#  'T201511030696401_13',
#  '20031202F01307_4',
#  'T200702040428401_6',
#  '20001129F02498_4',
#  '20010207F02104_2',
#  '20040206F00360_3',
#  '20040227F01737_3',
#  'T200810210393101_1',
#  '20020619F01680_1',
#  'T201306300283001_6',
#  '20010409F03293_4',
#  'T200705010301701_1',
#  '20000426E01482_1',
#  '20020702E03365_1',
#  'T200806250642001_8',
#  'T201509260178601_0',
#  '20000519E02338_1',
#  '20020415F01569_1',
#  'T201511030478201_1',
#  'T201811020274401_1',
#  'T201905070973601_1',
#  'T201906041019901_7',
#  'T201905080173101_4',
#  '20000419F00827_1',
#  '20010514E00695_5',
#  '20010530F03822_4',
#  'T200806190432501_1',
#  '20010425E03303_1',
#  'T201807170776701_11',
#  '20020526E01402_13',
#  'T201102210429501_9',
#  'T200811260730801_1',
#  'T200811260798901_9',
#  'T201709250496101_3',
#  '20020711E02958_1',
#  'T201711060711101_16',
#  '20020821F01089_3',
#  'T200905060274801_4',
#  '20000519E02378_1',
#  '20010426E02101_2',
#  'T200810280615601_6',
#  '20000321F01586_1',
#  '20010903E00655_1',
#  'T201805160526201_1',
#  '20010623E01135_1',
#  '20020409F01389_3',
#  'T201906040598601_1',
#  '20020701E03700_3',
#  '20040826E05466_2',
#  '20020203E00799_1',
#  '20050821E00353_3',
#  '20030530E02296_1',
#  '20041013F01711_11',
#  'T200610160322101_9',
#  'T202011110494901_8',
#  'T201312130523701_6',
#  '20050812E02606_1',
#  'T201504020461001_1',
#  'T201504020602001_9',
#  'T201505260818301_9',
#  'T201705220650501_1',
#  'T201811080420801_1',
#  '20021021E02829_4',
#  '20050822F01142_1',
#  '20000413E03095_1',
#  'T200810270665501_1',
#  '20011003F04442_1',
#  '20020215F02289_1',
#  'T201710310787101_8',
#  '20010926F02278_0',
#  'T201711060610301_1',
#  '20041226E00552_0',
#  'T200804160278601_0',
#  '20020924E01732_1',
#  'T200703200431101_6',
#  'T201005170236301_4',
#  'T200711200160401_1',
#  '20021129F00877_1',
#  '20010530E03597_1',
#  '20010621F03466_1',
#  '20010730F01187_1',
#  '20010730F02386_12',
#  '20011110E01023_1',
#  'T201203220707401_6',
#  'T201311190377801_8',
#  'T200703090630701_7',
#  'T200703230337701_1',
#  '20051010F01562_1',
#  'T201202020745201_5',
#  '20000526F01352_2',
#  'T201109120563301_1',
#  'T201905300424101_1',
#  'T201905300750201_4',
#  'T200701150569301_3',
#  'T201010120320101_4',
#  'T200712040623401_1',
#  '20041013F00952_1',
#  'T200911250430501_1',
#  'T200911250518401_9']

# %%
with open(output_path, 'w') as fw:
    for claim in dev:
        claim['orig_par_id'] = predicted[str(claim['id'])]
        fw.write(json.dumps(claim, ensure_ascii=False) + '\n')

# %% [markdown]
# # Playing with NFC / NFD normalization of unicode

# %%
import unicodedata as ud

# %%
d = load_jsonl('/mnt/data/factcheck/fever/data_titles-cs/predictions/dev_anserini_k500.jsonl')

# %%
ans1 = d[0]['predicted_pages'][0]
ans1
# Out:
# 'Katedra sociologie Fakulty sociálních studií Masarykovy univerzity'

# %%
dd = load_jsonl('/mnt/data/factcheck/fever/data_titles-cs/predictions/dev_drqa_k500.jsonl')

# %%
drqa1 = dd[0]['predicted_pages'][0]
drqa1
# Out:
# 'Katedra sociologie Fakulty sociálních studií Masarykovy univerzity'
