# %% [markdown]
# # Measuring Data Quality
#
# https://www.aclweb.org/anthology/2020.fever-1.6.pdf
#
# Contents:
#
# 1. Prepare the data
# 2. Cue Productivity and Coverage\
# 2.1. Create a balanced dataset \
# 2.2. Calculate applicability, productivity, coverage, utility metrics
# 3. Dataset-weighted Cue Information\
# 3.1 Prepare skip-grams \
# 3.2 Calculate weighted cue information on the skip-grams

# %% [markdown]
# # Prepare the data
#
# Using csv dump from adminer.

# %%
# !python -m pip install pymysql --user

# %%
import pandas as pd
import os
from collections import Counter, OrderedDict
import json

# %%
# !ls ../
# Out:
# ColBERT    claims_quality_metrics  student_teacher
# README.md  getadd.sh		   test.py
# anserini   pretraining		   xlmr_to_longformer

# %%
path = '/mnt/data/factcheck/fever/data-cs/fever-data'
files = [os.path.join(path, file) for file in os.listdir(path) if file.endswith(".jsonl")]

# %%
files
# Out:
# ['/mnt/data/factcheck/fever/data-cs/fever-data/test.jsonl',
#  '/mnt/data/factcheck/fever/data-cs/fever-data/train.jsonl',
#  '/mnt/data/factcheck/fever/data-cs/fever-data/dev.jsonl']

# %%
# sql = open('../fcheck.sql').read()

# connection = sqlite3.connect(":memory:")  # create DB in RAM
# cursor = connection.cursor()

# df = pd.read_sql(sql, connection)

# %%
# conn = pymysql.connect(host='127.0.0.1',
#                        port=int(3306),
#                        user='fcheck',
#                        password='gVLKsbh9OK9sdgATY6DKcc17Do8p0g',
#                        database='fcheck')

# df = a.read_sql_query("SELECT * FROM user", conn)

# %%
# !ls /home/ryparmar/db
# Out:
# 4-skip-unigram-dci.csv	claim_knowledge.csv  paragraph.csv	      user.csv
# article.csv		evidence.csv	     paragraph_knowledge.csv
# average_route_time.csv	export_uni_cv.csv    time_spent.csv
# claim.csv		label.csv	     unigram-dci.csv

# %%
claims = pd.read_csv('/home/ryparmar/db/claim.csv')
claims.dropna(subset=['id', 'claim'], inplace=True)
claims.head()
# Out:
#     id  user                                              claim paragraph  \
# 0  2.0     3              Ben Sheets první zápas v MLB prohrál.       NaN
# 2  3.0     3  Baseballový tým USA porazil na olympijských hr...       NaN
# 4  4.0     3  USA na olympijských hrách v Sydney získalo v b...       NaN
# 6  5.0     3  ArcelorMittal Ostrava přispěje zaměstnancům na...       NaN
# 8  6.0     3  Věra Breiová je mluvčí společnosti ArcelorMitt...       172
#
#   mutated_from mutation_type ners  sandbox  labelled    created_at  \
# 0          NaN           NaN  NaN      NaN       NaN           NaN
# 2          NaN           NaN  NaN      NaN       NaN           NaN
# 4          NaN           NaN  NaN      NaN       NaN           NaN
# 6          NaN           NaN  NaN      NaN       NaN           NaN
# 8          NaN           NaN  NaN      0.0       0.0  1.604445e+09
#
#      updated_at
# 0           NaN
# 2           NaN
# 4           NaN
# 6           NaN
# 8  1.604445e+09

# %%
len(claims)
# Out:
# 2259

# %%
claims['claim'].value_counts(sort=True)
# Out:
# Dánský premiér bude usilovat o pozici generálního tajemníka Severoatlantické aliance.          2
# Robert Pelikán vyjádřil znepokojení nad Okamurovými výroky.                                    2
# Maďarský prezident Sólyom neodcestoval 21. sprna 2009 na svou soukromou cestu do Slovenska.    2
# Posádka raketoplánu Columbie čítala 7 lidí.                                                    2
# Nejen Lidovci volají po odvolání Tomia Okamury z pozice místopředsedy Sněmovny.                2
#                                                                                               ..
# Ukrajina někdejšího gruzínského prezidenta vyhostila do Varšavy.                               1
# Druhém kolo voleb bylo pro Kuncaře fatální.                                                    1
# Dánský premiér Anders Fogh Rasmussen odmítl kandidovat na post generálního tajemníka NATO.     1
# Pirátská kopie filmu Osm hrozných unikla na internet. ↵                                        1
# Česká skupina Energo-PRO chce získat třináct elektráren v bulharské Sofii.                     1
# Name: claim, Length: 2247, dtype: int64

# %%
claims[claims.claim == 'Nejen Lidovci volají po odvolání Tomia Okamury z pozice místopředsedy Sněmovny.']
# Out:
#         id  user                                              claim paragraph  \
# 443  405.0    66  Nejen Lidovci volají po odvolání Tomia Okamury...       NaN
# 450  410.0    66  Nejen Lidovci volají po odvolání Tomia Okamury...       891
#
#     mutated_from mutation_type                    ners  sandbox  labelled  \
# 443          NaN           NaN                     NaN      NaN       NaN
# 450          405      specific  Tomia Okamury,Sněmovny      0.0       1.0
#
#        created_at    updated_at
# 443           NaN           NaN
# 450  1.606490e+09  1.606490e+09

# %%
labels = pd.read_csv('/home/ryparmar/db/label.csv')
labels.head()
# Out:
#    id  user  claim     label  sandbox  oracle  flag condition  created_at  \
# 0   2     5      8  SUPPORTS        0       0     0       NaN  1604492144
# 1   3     5      2  SUPPORTS        0       0     0       NaN  1604492158
# 2   4     5      9  SUPPORTS        0       0     0       NaN  1604492193
# 3   5     6      4  SUPPORTS        0       0     0       NaN  1604514332
# 4   7     7      3  SUPPORTS        0       0     0       NaN  1604589242
#
#    updated_at  deleted
# 0  1604492144        0
# 1  1604492158        0
# 2  1604492193        0
# 3  1604514332        0
# 4  1604589242        0

# %%
len(labels)
# Out:
# 1644

# %%
labels.claim.value_counts(sort=True)
# Out:
# 545     6
# 136     6
# 142     6
# 644     5
# 303     5
#        ..
# 1140    1
# 1139    1
# 1137    1
# 1136    1
# 2       1
# Name: claim, Length: 1054, dtype: int64

# %%
labels[labels.claim == 545]
# Out:
#         id  user  claim     label  sandbox  oracle  flag condition  \
# 703    709     9    545  SUPPORTS        0       0     0       NaN
# 829    835    62    545  SUPPORTS        0       1     0       NaN
# 932    938    37    545  SUPPORTS        0       0     0       NaN
# 1123  1129    40    545  SUPPORTS        0       0     0       NaN
# 1226  1232    36    545  SUPPORTS        0       0     0       NaN
# 1607  1613    17    545  SUPPORTS        0       0     0       NaN
#
#       created_at  updated_at  deleted
# 703   1607202400  1607202400        0
# 829   1607346370  1607346370        0
# 932   1607367394  1607367394        0
# 1123  1607383646  1607383646        0
# 1226  1607416261  1607416261        0
# 1607  1607513079  1607513079        0

# %%
claims[claims.id==545]
# Out:
#         id  user                                              claim paragraph  \
# 596  545.0    62  Zásilkový obchod v ČR oproti západní Evropě a ...     15297
#
#     mutated_from mutation_type           ners  sandbox  labelled  \
# 596          539      specific  ČR,USA,Evropě      0.0       1.0
#
#        created_at    updated_at
# 596  1.606816e+09  1.606816e+09

# %%
labels['label'].value_counts()
# Out:
# SUPPORTS           811
# REFUTES            587
# NOT ENOUGH INFO    195
# Name: label, dtype: int64

# %%
print(f"#claims: {len(claims.claim.unique())} #labels: {len(labels.claim.unique())}")
# Out:
# #claims: 2247 #labels: 1054

# %%
labels.id = labels.claim
df = claims.merge(labels[['id', 'label']], on='id', how='left')
df = df.dropna(subset=['claim', 'label'])
df = df[['id', 'claim', 'label']]
df.reset_index(inplace=True, drop=True)

# del claims, labels

# %%
df.head()
# Out:
#     id                                              claim     label
# 0  2.0              Ben Sheets první zápas v MLB prohrál.  SUPPORTS
# 1  3.0  Baseballový tým USA porazil na olympijských hr...  SUPPORTS
# 2  4.0  USA na olympijských hrách v Sydney získalo v b...  SUPPORTS
# 3  7.0  ArcelorMittal Ostrava finančně podpoří odvykán...  SUPPORTS
# 4  7.0  ArcelorMittal Ostrava finančně podpoří odvykán...  SUPPORTS

# %%
df.count()
# Out:
# id       1593
# claim    1593
# label    1593
# dtype: int64

# %%
print(f"Unique claims: {len(df.claim.unique())}\nTotal labels: {len(df)}")
# Out:
# Unique claims: 1018
# Total labels: 1593

# %%
df.head(10)
# Out:
#      id                                              claim     label
# 0   2.0              Ben Sheets první zápas v MLB prohrál.  SUPPORTS
# 1   3.0  Baseballový tým USA porazil na olympijských hr...  SUPPORTS
# 2   4.0  USA na olympijských hrách v Sydney získalo v b...  SUPPORTS
# 3   7.0  ArcelorMittal Ostrava finančně podpoří odvykán...  SUPPORTS
# 4   7.0  ArcelorMittal Ostrava finančně podpoří odvykán...  SUPPORTS
# 5   8.0  Německá firma Bühler Motor investovala v Hradc...  SUPPORTS
# 6   9.0  Německá firma Bühler Motor má v Hradci Králové...  SUPPORTS
# 7  11.0   Německá firma Bühler Motor vyrábí elektropohony.  SUPPORTS
# 8  22.0  Společnost Bühler Motor investovala v Hradci K...  SUPPORTS
# 9  23.0  Christof Furtwängler je jednatelem firmy Bühle...  SUPPORTS

# %% [markdown]
# # Cue Productivity and Coverage

# %% [markdown]
# ## Sample balanced dataset
#
# This approach assumes a balanced dataset with regard to the frequency of each label. If executed on an imbalanced dataset, a given cue’s productivity would be dominated by the most frequent label, not because it is actually more likely to appear in a claim with that label but purely since the label is more frequent overall.
#
# V clanku undersampluji majority classes, a to opakuji 10x, aby dostali robustnejsi odhad. Tady pocitam jak 10-fold CV, tak i metriky na vsech datech.

# %%
SAMPLE_SIZE = min(df['label'].value_counts())
NUM_SAMPLES = 10
SAMPLES = []
for i in range(NUM_SAMPLES):
    df_to_join = []
    for label in df.label.unique():
        df_to_join.append(df[df.label == label].sample(SAMPLE_SIZE)[['claim', 'label']])

    SAMPLES.append(pd.concat(df_to_join).reset_index(drop=True))

# %%
SAMPLES[0].head()
# Out:
#                                                claim     label
# 0  Internetový obchod v ČR je ve srovnání se zápa...  SUPPORTS
# 1  25 členů dětského parlamentu bude nápomocno mě...  SUPPORTS
# 2   Radnice v Postoloprtech zachraňuje místní kapli.  SUPPORTS
# 3  Festival amatérských filmů se tradičně pořádá ...  SUPPORTS
# 4  Když se objeví křeče z přehřátí, je dobré zůst...  SUPPORTS

# %% [markdown]
# ## Cues are represented by unigrams and bigrams
#
# Cue = bias v datech, ktery ulehcuje ML rozhodovani jen na zaklade nej. (Napriklad slovo 'not' v anglickych datech bude pritono v claimech s labelem takoveho rozdeleni: 80% REFUTES, 5% SUPPORTS, 15% NOT ENOUGH INFO - coz vypada na bias vuci REFUTES class; ML predikuje REFUTES vzdy v pripade pritomnosti 'not', coz neni zadouci!)

# %%
LABELS = len(df['label'].unique())

# %%
# all data
unigrams_all = [[ii.strip('.') for ii in c.split()] for c in df['claim'] if isinstance(c, str)]
# unigrams = [([ii.strip('.') for ii in c.split()], df['label'][i]) for i, c in enumerate(df['claim']) if isinstance(c, str)]

bigrams_all = [[i.strip('.') + ' ' + ii.strip('.') 
            for i, ii in zip(c.split()[:-1], c.split()[1:])] 
           for c in df['claim'] if isinstance(c, str)]

# per samples / k-fold cross validation like
unigrams, bigrams = [], []
for sample in SAMPLES:
    unigrams.append([[ii.strip('.') for ii in c.split()] for c in sample['claim'] if isinstance(c, str)])
    bigrams.append([[i.strip('.') + ' ' + ii.strip('.')
                     for i, ii in zip(c.split()[:-1], c.split()[1:])]
                    for c in sample['claim'] if isinstance(c, str)])

# %%
unigrams[0][:2]
# Out:
# [['Internetový',
#   'obchod',
#   'v',
#   'ČR',
#   'je',
#   've',
#   'srovnání',
#   'se',
#   'západní',
#   'Evropou',
#   'nižší'],
#  ['25',
#   'členů',
#   'dětského',
#   'parlamentu',
#   'bude',
#   'nápomocno',
#   'městským',
#   'radním']]

# %%
bigrams[0][:2]
# Out:
# [['Internetový obchod',
#   'obchod v',
#   'v ČR',
#   'ČR je',
#   'je ve',
#   've srovnání',
#   'srovnání se',
#   'se západní',
#   'západní Evropou',
#   'Evropou nižší'],
#  ['25 členů',
#   'členů dětského',
#   'dětského parlamentu',
#   'parlamentu bude',
#   'bude nápomocno',
#   'nápomocno městským',
#   'městským radním']]

# %% [markdown]
# ## Lets try also wordpieces as cues

# %%
import transformers

tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# %%
wordpieces_all = [tokenizer.tokenize(c.rstrip('.')) for c in df['claim'] if isinstance(c, str)]

# %%
len(wordpieces_all)
# Out:
# 1593

# %%
wordpieces_all
# Out:
# [['Ben', 'She', '##ets', 'první', 'zápas', 'v', 'MLB', 'pro', '##hr', '##ál'],
#  ['Baseball',
#   '##ový',
#   'tým',
#   'USA',
#   'por',
#   '##azil',
#   'na',
#   'olympijských',
#   'hrách',
#   'v',
#   'Sydney',
#   'hráč',
#   '##e',
#   'Ku',
#   '##by'],
#  ['USA',
#   'na',
#   'olympijských',
#   'hrách',
#   'v',
#   'Sydney',
#   'získal',
#   '##o',
#   'v',
#   'baseball',
#   '##u',
#   'zlato',
#   '##u',
#   'medaili'],
#  ['Arc',
#   '##elor',
#   '##M',
#   '##itt',
#   '##al',
#   'Ostrava',
#   'fina',
#   '##n',
#   '##čně',
#   'pod',
#   '##po',
#   '##ří',
#   'od',
#   '##vy',
#   '##kání',
#   'ko',
#   '##u',
#   '##ření',
#   'u',
#   'svých',
#   'za',
#   '##mě',
#   '##st',
#   '##nan',
#   '##ců'],
#  ['Arc',
#   '##elor',
#   '##M',
#   '##itt',
#   '##al',
#   'Ostrava',
#   'fina',
#   '##n',
#   '##čně',
#   'pod',
#   '##po',
#   '##ří',
#   'od',
#   '##vy',
#   '##kání',
#   'ko',
#   '##u',
#   '##ření',
#   'u',
#   'svých',
#   'za',
#   '##mě',
#   '##st',
#   '##nan',
#   '##ců'],
#  ['N',
#   '##ě',
#   '##me',
#   '##cká',
#   'firma',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'in',
#   '##vest',
#   '##ovala',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové',
#   'asi',
#   'p',
#   '##ůl',
#   'mil',
#   '##iard',
#   '##y'],
#  ['N',
#   '##ě',
#   '##me',
#   '##cká',
#   'firma',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'má',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##y'],
#  ['N',
#   '##ě',
#   '##me',
#   '##cká',
#   'firma',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'v',
#   '##yr',
#   '##á',
#   '##bí',
#   'ele',
#   '##kt',
#   '##rop',
#   '##oh',
#   '##ony'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'in',
#   '##vest',
#   '##ovala',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové',
#   '90',
#   'mil',
#   '##ión',
#   '##ů',
#   'kor',
#   '##un'],
#  ['Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler',
#   'je',
#   'jedna',
#   '##tele',
#   '##m',
#   'firmy',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'Hradec',
#   'Králové',
#   'vlastní',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##u',
#   'za',
#   '90',
#   'mil',
#   '##ión',
#   '##ů',
#   'kor',
#   '##un'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'Hradec',
#   'Králové',
#   'vlastní',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##u',
#   'za',
#   '90',
#   'mil',
#   '##ión',
#   '##ů',
#   'kor',
#   '##un'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'Hradec',
#   'Králové',
#   'vlastní',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##u',
#   'za',
#   '90',
#   'mil',
#   '##ión',
#   '##ů',
#   'kor',
#   '##un'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'ot',
#   '##ev',
#   '##řel',
#   '##a',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##u'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'ot',
#   '##ev',
#   '##řel',
#   '##a',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##u'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'ot',
#   '##ev',
#   '##řel',
#   '##a',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##u'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'v',
#   '##yna',
#   '##lo',
#   '##žila',
#   '90',
#   'mil',
#   '##ión',
#   '##ů',
#   'kor',
#   '##un',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'ot',
#   '##ev',
#   '##řel',
#   '##a',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##u',
#   'za',
#   '90',
#   'mil',
#   '##ión',
#   '##ů',
#   'kor',
#   '##un',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'ot',
#   '##ev',
#   '##řel',
#   '##a',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ní',
#   'hal',
#   '##u',
#   'za',
#   '90',
#   'mil',
#   '##ión',
#   '##ů',
#   'kor',
#   '##un',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'Hradec',
#   'Králové',
#   'in',
#   '##vest',
#   '##ovala',
#   'v',
#   'České',
#   'republice'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'Hradec',
#   'Králové',
#   'in',
#   '##vest',
#   '##ovala',
#   'v',
#   'České',
#   'republice'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'Hradec',
#   'Králové',
#   'in',
#   '##vest',
#   '##ovala',
#   'v',
#   'České',
#   'republice'],
#  ['Sp',
#   '##ole',
#   '##čnost',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'Hradec',
#   'Králové',
#   'in',
#   '##vest',
#   '##ovala',
#   'v',
#   'České',
#   'republice'],
#  ['Jedna',
#   '##tel',
#   'firmy',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'se',
#   'j',
#   '##menu',
#   '##je',
#   'Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler'],
#  ['Jedna',
#   '##tel',
#   'firmy',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'se',
#   'j',
#   '##menu',
#   '##je',
#   'Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler'],
#  ['Jedna',
#   '##tel',
#   'firmy',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'se',
#   'j',
#   '##menu',
#   '##je',
#   'Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler'],
#  ['Jedna',
#   '##tel',
#   'firmy',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor',
#   'se',
#   'j',
#   '##menu',
#   '##je',
#   'Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler'],
#  ['N',
#   '##ě',
#   '##me',
#   '##c',
#   'Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler',
#   'je',
#   'je',
#   '##dn',
#   '##tele',
#   '##m',
#   'firmy',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor'],
#  ['N',
#   '##ě',
#   '##me',
#   '##c',
#   'Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler',
#   'je',
#   'je',
#   '##dn',
#   '##tele',
#   '##m',
#   'firmy',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor'],
#  ['Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler',
#   'je',
#   'jedna',
#   '##tele',
#   '##m',
#   'firmy'],
#  ['Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler',
#   'je',
#   'jedna',
#   '##tele',
#   '##m',
#   'firmy'],
#  ['Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler',
#   'ne',
#   '##pra',
#   '##cuje',
#   'pro',
#   'firm',
#   '##u',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor'],
#  ['Christ',
#   '##of',
#   'Fu',
#   '##rt',
#   '##w',
#   '##äng',
#   '##ler',
#   'ne',
#   '##pra',
#   '##cuje',
#   'pro',
#   'firm',
#   '##u',
#   'B',
#   '##ühle',
#   '##r',
#   'Motor'],
#  ['V',
#   'T',
#   '##ře',
#   '##bí',
#   '##či',
#   'b',
#   '##ývají',
#   'problémy',
#   's',
#   'velkou',
#   'vo',
#   '##dou'],
#  ['T', '##ře', '##bí', '##č', 'boj', '##uje', 's', 'tsunami'],
#  ['T', '##ře', '##bí', '##č', 'boj', '##uje', 's', 'Op', '##avo', '##u'],
#  ['T', '##ře', '##bí', '##č', 'boj', '##uje', 's', 'Op', '##avo', '##u'],
#  ['Po',
#   '##vod',
#   '##í',
#   'Mora',
#   '##vy',
#   'boj',
#   '##uje',
#   's',
#   'velkou',
#   'vo',
#   '##dou'],
#  ['Z',
#   '##áp',
#   '##lav',
#   '##y',
#   'v',
#   'T',
#   '##ře',
#   '##bí',
#   '##či',
#   'jsou',
#   'v',
#   '##yl',
#   '##ou',
#   '##čen',
#   '##y'],
#  ['Z',
#   '##áp',
#   '##lav',
#   '##y',
#   'v',
#   'T',
#   '##ře',
#   '##bí',
#   '##či',
#   'jsou',
#   'v',
#   '##yl',
#   '##ou',
#   '##čen',
#   '##y'],
#  ['Z',
#   '##áp',
#   '##lav',
#   '##y',
#   'v',
#   'T',
#   '##ře',
#   '##bí',
#   '##či',
#   'jsou',
#   'v',
#   '##yl',
#   '##ou',
#   '##čen',
#   '##y'],
#  ['Z',
#   '##áp',
#   '##lav',
#   '##y',
#   'v',
#   'T',
#   '##ře',
#   '##bí',
#   '##či',
#   'jsou',
#   'v',
#   '##yl',
#   '##ou',
#   '##čen',
#   '##y'],
#  ['Z',
#   '##áp',
#   '##lav',
#   '##y',
#   'v',
#   'T',
#   '##ře',
#   '##bí',
#   '##či',
#   'jsou',
#   'v',
#   '##yl',
#   '##ou',
#   '##čen',
#   '##y'],
#  ['Česká',
#   'republika',
#   'má',
#   'přes',
#   '160',
#   'vo',
#   '##dnich',
#   'ná',
#   '##dr',
#   '##ží'],
#  ['Ob',
#   '##jem',
#   'vodní',
#   '##ch',
#   'ná',
#   '##dr',
#   '##ží',
#   'v',
#   'ČR',
#   'je',
#   '336',
#   '##0',
#   'milionů',
#   'metrů',
#   'kr',
#   '##ych',
#   '##lov',
#   '##ých'],
#  ['V', 'České', 'republice', 'je', 'méně', 'než', '160', 'ná', '##dr', '##ží'],
#  ['Ob',
#   '##jem',
#   'všech',
#   'ry',
#   '##bník',
#   '##ů',
#   'je',
#   'menší',
#   'než',
#   'ob',
#   '##jem',
#   'všech',
#   'vodní',
#   '##ch',
#   'ná',
#   '##dr',
#   '##ží',
#   'v',
#   'ČR'],
#  ['Um',
#   '##ěl',
#   '##é',
#   'vodní',
#   'ná',
#   '##dr',
#   '##že',
#   'mají',
#   'větší',
#   'ob',
#   '##jem',
#   'než',
#   'ry',
#   '##bník',
#   '##y',
#   'na',
#   'území',
#   'ČR'],
#  ['R',
#   '##y',
#   '##bník',
#   '##y',
#   'jsou',
#   'ho',
#   '##r',
#   '##ší',
#   'na',
#   'sk',
#   '##lado',
#   '##vání',
#   'vody',
#   'než',
#   'vodní',
#   'ná',
#   '##dr',
#   '##že'],
#  ['R',
#   '##y',
#   '##bník',
#   '##y',
#   'jsou',
#   'ho',
#   '##r',
#   '##ší',
#   'na',
#   'sk',
#   '##lado',
#   '##vání',
#   'vody',
#   'než',
#   'vodní',
#   'ná',
#   '##dr',
#   '##že'],
#  ['R',
#   '##y',
#   '##bník',
#   '##y',
#   'v',
#   'ČR',
#   'ud',
#   '##r',
#   '##žu',
#   '##jí',
#   'více',
#   'vody',
#   'než',
#   'vodní',
#   'ná',
#   '##dr',
#   '##že'],
#  ['R',
#   '##y',
#   '##bník',
#   '##y',
#   'v',
#   'ČR',
#   'ud',
#   '##r',
#   '##žu',
#   '##jí',
#   'více',
#   'vody',
#   'než',
#   'vodní',
#   'ná',
#   '##dr',
#   '##že'],
#  ['V', 'Pol', '##sku', 'byl', 'The', 'Devil', 'za', '##ká', '##zán'],
#  ['V', 'Pol', '##sku', 'byl', 'The', 'Devil', 'za', '##ká', '##zán'],
#  ['V', 'Pol', '##sku', 'byl', 'The', 'Devil', 'za', '##ká', '##zán'],
#  ['V', 'Pol', '##sku', 'za', '##ká', '##zali', 'pot', '##rat', '##y'],
#  ['V', 'Pol', '##sku', 'za', '##ká', '##zali', 'pot', '##rat', '##y'],
#  ['V', 'Pol', '##sku', 'za', '##ká', '##zali', 'pot', '##rat', '##y'],
#  ['V', 'Pol', '##sku', 'se', 'pro', '##mí', '##tal', 'film', 'The', 'Devil'],
#  ['V', 'Pol', '##sku', 'se', 'pro', '##mí', '##tal', 'film', 'The', 'Devil'],
#  ['V', 'Pol', '##sku', 'se', 'pro', '##mí', '##tal', 'film', 'The', 'Devil'],
#  ['V', 'Pol', '##sku', 'se', 'pro', '##mí', '##tal', 'film', 'The', 'Devil'],
#  ['V', 'Pol', '##sku', 'se', 'pro', '##mí', '##tal', 'film', 'The', 'Devil'],
#  ['Ve', 'věku', '75', 'let', 'zemřel', 'Andrzej', 'Ž', '##ula', '##wski'],
#  ['Andrzej', 'Ž', '##ula', '##wski', 'zemřel', 've', 'věku', '53', 'let'],
#  ['Andrzej', 'Ž', '##ula', '##wski', 'zemřel', 've', 'věku', '53', 'let'],
#  ['Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zemřel',
#   'v',
#   'Pol',
#   '##sku',
#   've',
#   'věku',
#   '75',
#   'let'],
#  ['Andrzej', 'Ž', '##ula', '##wski', 'zemřel'],
#  ['Andrzej', 'Ž', '##ula', '##wski', 'os', '##lav', '##il', '80', 'let'],
#  ['Ž', '##ula', '##wski', 'je', 'slovenský', 'režisér'],
#  ['Ž', '##ula', '##wski', 'je', 'slovenský', 'režisér'],
#  ['Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'se',
#   'narodil',
#   'v',
#   'Ra',
#   '##kou',
#   '##sku'],
#  ['Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'se',
#   'narodil',
#   'v',
#   'Ra',
#   '##kou',
#   '##sku'],
#  ['Andrzej', 'Ž', '##ula', '##wski', 'zemřel', 'na', 'rak', '##ovi', '##nu'],
#  ['Andrzej',
#   'Zu',
#   '##law',
#   '##ski',
#   'ut',
#   '##rp',
#   '##ěl',
#   'in',
#   '##far',
#   '##kt'],
#  ['Andrzej',
#   'Zu',
#   '##law',
#   '##ski',
#   'ut',
#   '##rp',
#   '##ěl',
#   'in',
#   '##far',
#   '##kt'],
#  ['Andrzej',
#   'Zu',
#   '##law',
#   '##ski',
#   'ut',
#   '##rp',
#   '##ěl',
#   'in',
#   '##far',
#   '##kt'],
#  ['Obama', 'zemřel', 'na', 'rak', '##ovi', '##nu'],
#  ['Andrzej', 'Ž', '##ula', '##wski', 'zemřel'],
#  ['Ž', '##ula', '##wski', 'zemřel', 'na', 'CO', '##VI', '##D', '-', '19'],
#  ['Ž', '##ula', '##wski', 'zemřel', 'na', 'CO', '##VI', '##D', '-', '19'],
#  ['Ž', '##ula', '##wski', 'zemřel', 'na', 'CO', '##VI', '##D', '-', '19'],
#  ['Ž', '##ula', '##wski', 'zemřel', 'na', 'CO', '##VI', '##D', '-', '19'],
#  ['Ve',
#   'druhé',
#   'polovině',
#   'roku',
#   '2008',
#   'se',
#   'v',
#   'Praze',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##lo',
#   'téměř',
#   '7',
#   '000',
#   'demo',
#   '##nst',
#   '##rac',
#   '##í'],
#  ['Ve',
#   'druhé',
#   'polovině',
#   'roku',
#   '2008',
#   'se',
#   'v',
#   'Praze',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##lo',
#   'téměř',
#   '7',
#   '000',
#   'demo',
#   '##nst',
#   '##rac',
#   '##í'],
#  ['V',
#   'Praze',
#   'se',
#   'v',
#   'druhé',
#   'polovině',
#   'roku',
#   '2018',
#   'kon',
#   '##alo',
#   'více',
#   'než',
#   '670',
#   '##0',
#   'oz',
#   '##ná',
#   '##men',
#   '##ých',
#   'demo',
#   '##nst',
#   '##rac',
#   '##í'],
#  ['Za',
#   'rok',
#   '2008',
#   'bylo',
#   'v',
#   'Praze',
#   'asi',
#   '8',
#   '.',
#   '000',
#   'protest',
#   '##ních',
#   'shromáždění'],
#  ['Za',
#   'rok',
#   '2008',
#   'bylo',
#   'v',
#   'Praze',
#   'asi',
#   '8',
#   '.',
#   '000',
#   'protest',
#   '##ních',
#   'shromáždění'],
#  ['V',
#   'roce',
#   '2008',
#   'pro',
#   '##běh',
#   '##lo',
#   'v',
#   'Praze',
#   'ne',
#   '##cel',
#   '##ých',
#   '8',
#   '000',
#   'protest',
#   '##ních',
#   'shromáždění'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'a',
#   'Lech',
#   'Ka',
#   '##czyński',
#   'jsou',
#   'd',
#   '##voj',
#   '##ča',
#   '##ta'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'a',
#   'Lech',
#   'Ka',
#   '##czyński',
#   'jsou',
#   'd',
#   '##voj',
#   '##ča',
#   '##ta'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'má',
#   'brat',
#   '##ra',
#   '-',
#   'Lech',
#   '##a',
#   'Ka',
#   '##czy',
#   '##ń',
#   '##ského'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'je',
#   'starší',
#   'než',
#   'Lech',
#   'Ka',
#   '##czyński'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'podporu',
#   '##je',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'podporu',
#   '##je',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'podporu',
#   '##je',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'je',
#   'za',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Jaroslav', 'Ka', '##czyński', 'je', 'pro', 'při', '##jetí', 'eu', '##ra'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'je',
#   'za',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'G',
#   '##dans',
#   '##ku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'je',
#   'za',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'G',
#   '##dans',
#   '##ku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'je',
#   'za',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'G',
#   '##dans',
#   '##ku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'je',
#   'za',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'G',
#   '##dans',
#   '##ku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'ne',
#   '##ví',
#   'o',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'ne',
#   '##ví',
#   'o',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'ne',
#   '##ví',
#   'o',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'ne',
#   '##ví',
#   'o',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Jaroslav',
#   'Ka',
#   '##czyński',
#   'ne',
#   '##ví',
#   'o',
#   'um',
#   '##ís',
#   '##tě',
#   '##ní',
#   'americké',
#   'proti',
#   '##rak',
#   '##eto',
#   '##vé',
#   'z',
#   '##ák',
#   '##lad',
#   '##ny',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Pre',
#   '##zid',
#   '##ent',
#   'Salvador',
#   'Allende',
#   'byl',
#   'us',
#   '##m',
#   '##rce',
#   '##n',
#   'při',
#   'vojenské',
#   '##m',
#   'př',
#   '##ev',
#   '##ratu',
#   'organi',
#   '##zov',
#   '##ané',
#   '##m',
#   'Augusto',
#   'Pino',
#   '##chet',
#   '##em'],
#  ['Pre',
#   '##zid',
#   '##ent',
#   'Salvador',
#   'Allende',
#   'byl',
#   'us',
#   '##m',
#   '##rce',
#   '##n',
#   'při',
#   'vojenské',
#   '##m',
#   'př',
#   '##ev',
#   '##ratu',
#   'organi',
#   '##zov',
#   '##ané',
#   '##m',
#   'Augusto',
#   'Pino',
#   '##chet',
#   '##em'],
#  ['Pre',
#   '##zid',
#   '##ent',
#   'Salvador',
#   'Allende',
#   'byl',
#   'us',
#   '##m',
#   '##rce',
#   '##n',
#   'při',
#   'vojenské',
#   '##m',
#   'př',
#   '##ev',
#   '##ratu',
#   'organi',
#   '##zov',
#   '##ané',
#   '##m',
#   'Augusto',
#   'Pino',
#   '##chet',
#   '##em'],
#  ['Pre',
#   '##zid',
#   '##ent',
#   'Salvador',
#   'Allende',
#   'zemřel',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu'],
#  ['Pre',
#   '##zid',
#   '##ent',
#   'Salvador',
#   'Allende',
#   'zemřel',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'byl',
#   'za',
#   '##bit',
#   'prezident'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'byl',
#   'za',
#   '##bit',
#   'prezident'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'byl',
#   'za',
#   '##bit',
#   'prezident'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'byl',
#   'za',
#   '##bit',
#   'prezident'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'byl',
#   'za',
#   '##bit',
#   'prezident'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'byl',
#   'jmenován',
#   'prezident',
#   '##em',
#   'Salvador',
#   'Allende',
#   '.'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'byl',
#   'jmenován',
#   'prezident',
#   '##em',
#   'Salvador',
#   'Allende',
#   '.'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'byl',
#   'jmenován',
#   'prezident',
#   '##em',
#   'Salvador',
#   'Allende',
#   '.'],
#  ['Augusto',
#   'Pino',
#   '##chet',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##l',
#   'vo',
#   '##jen',
#   '##ský',
#   'př',
#   '##ev',
#   '##rat',
#   ',',
#   'při',
#   'kterém',
#   'ni',
#   '##k',
#   '##do',
#   'ne',
#   '##zem',
#   '##řel'],
#  ['U', '##čená', 'společnost', 'existuje', 'od', 'roku', '1994'],
#  ['U', '##čená', 'společnost', 'existuje', 'od', 'roku', '1994'],
#  ['U', '##čená', 'společnost', 'existuje', 'od', 'roku', '1994'],
#  ['U', '##čená', 'společnost', 'existuje', 'od', 'roku', '2004'],
#  ['Č',
#   '##lene',
#   '##m',
#   'U',
#   '##čené',
#   'společnosti',
#   'se',
#   'může',
#   'stát',
#   'ú',
#   '##pl',
#   '##ně',
#   'každý'],
#  ['U', '##čená', 'společnost', 'existuje', 'od', 'roku', '1900'],
#  ['U', '##čená', 'společnost', 'existuje', 'od', 'roku', '1900'],
#  ['U', '##čená', 'společnost', 'existuje', 'od', 'roku', '1900'],
#  ['U', '##čená', 'společnost', 'existuje', 'od', 'roku', '1900'],
#  ['M',
#   '##lad',
#   '##í',
#   'aka',
#   '##demi',
#   '##ci',
#   'a',
#   'studenti',
#   'mají',
#   'také',
#   'š',
#   '##anc',
#   '##i',
#   'být',
#   'o',
#   '##cen',
#   '##ěn',
#   '##i',
#   'U',
#   '##čeno',
#   '##u',
#   'společností'],
#  ['U',
#   '##čená',
#   'společnost',
#   'v',
#   '##y',
#   '##znam',
#   '##ená',
#   '##vá',
#   'kad',
#   '##e',
#   '##ř',
#   '##nice'],
#  ['U',
#   '##čená',
#   'společnost',
#   'v',
#   '##y',
#   '##znam',
#   '##ená',
#   '##vá',
#   'kad',
#   '##e',
#   '##ř',
#   '##nice'],
#  ['U',
#   '##čená',
#   'společnost',
#   'v',
#   '##y',
#   '##znam',
#   '##ená',
#   '##vá',
#   'kad',
#   '##e',
#   '##ř',
#   '##nice'],
#  ['U',
#   '##čená',
#   'společnost',
#   'hod',
#   '##not',
#   '##í',
#   'k',
#   '##vali',
#   '##tu',
#   'str',
#   '##avo',
#   '##vání',
#   'na',
#   'š',
#   '##kol',
#   '##ách'],
#  ['U',
#   '##čená',
#   'společnost',
#   'hod',
#   '##not',
#   '##í',
#   'k',
#   '##vali',
#   '##tu',
#   'str',
#   '##avo',
#   '##vání',
#   'na',
#   'š',
#   '##kol',
#   '##ách'],
#  ['U',
#   '##čená',
#   'společnost',
#   'o',
#   '##ce',
#   '##ňuje',
#   'pouze',
#   'senior',
#   '##ní',
#   'akademik',
#   '##y',
#   'a',
#   'v',
#   '##ě',
#   '##dce'],
#  ['U', '##čená', 'společnost', 'neo', '##ce', '##ňuje', 'student', '##y'],
#  ['U', '##čená', 'společnost', 'neo', '##ce', '##ňuje', 'student', '##y'],
#  ['Mis',
#   '##e',
#   'rak',
#   '##eto',
#   '##pl',
#   '##ánů',
#   'Challenger',
#   'i',
#   'Col',
#   '##um',
#   '##bie',
#   'skončila',
#   'ne',
#   '##ús',
#   '##p',
#   '##ěch',
#   '##em',
#   'a',
#   'ha',
#   '##vári',
#   '##í'],
#  ['P',
#   '##ří',
#   '##činy',
#   'ha',
#   '##vári',
#   '##e',
#   'rak',
#   '##eto',
#   '##pl',
#   '##ánů',
#   'Challenger',
#   'a',
#   'Col',
#   '##um',
#   '##bie',
#   'byly',
#   'rozdíl',
#   '##né'],
#  ['Diva',
#   '##dlo',
#   'Rok',
#   '##oko',
#   'hrál',
#   '##o',
#   'po',
#   '##há',
#   '##dku',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ové'],
#  ['Ž',
#   '##ád',
#   '##ná',
#   'drama',
#   '##ti',
#   '##za',
#   '##ce',
#   'po',
#   '##há',
#   '##dky',
#   'nebyla',
#   'v',
#   'Praze',
#   'u',
#   '##vedena'],
#  ['Ž',
#   '##ád',
#   '##ná',
#   'drama',
#   '##ti',
#   '##za',
#   '##ce',
#   'po',
#   '##há',
#   '##dky',
#   'nebyla',
#   'v',
#   'Praze',
#   'u',
#   '##vedena'],
#  ['Ž',
#   '##ád',
#   '##ná',
#   'drama',
#   '##ti',
#   '##za',
#   '##ce',
#   'po',
#   '##há',
#   '##dky',
#   'nebyla',
#   'v',
#   'Praze',
#   'u',
#   '##vedena'],
#  ['Ž',
#   '##ád',
#   '##ná',
#   'drama',
#   '##ti',
#   '##za',
#   '##ce',
#   'po',
#   '##há',
#   '##dky',
#   'nebyla',
#   'v',
#   'Praze',
#   'u',
#   '##vedena'],
#  ['Šv',
#   '##éd',
#   '##ka',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'byla',
#   'spisovatel',
#   '##ka'],
#  ['Šv',
#   '##éd',
#   '##ka',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'byla',
#   'spisovatel',
#   '##ka'],
#  ['Šv',
#   '##éd',
#   '##ka',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'byla',
#   'spisovatel',
#   '##ka'],
#  ['Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'ps',
#   '##ala',
#   'své',
#   'knihy',
#   'š',
#   '##véd',
#   '##sky'],
#  ['Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'ps',
#   '##ala',
#   'své',
#   'knihy',
#   'š',
#   '##véd',
#   '##sky'],
#  ['Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'ps',
#   '##ala',
#   'své',
#   'knihy',
#   'š',
#   '##véd',
#   '##sky'],
#  ['Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'ps',
#   '##ala',
#   'své',
#   'knihy',
#   'š',
#   '##véd',
#   '##sky'],
#  ['Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'ps',
#   '##ala',
#   'své',
#   'knihy',
#   'š',
#   '##véd',
#   '##sky'],
#  ['Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'ps',
#   '##ala',
#   'své',
#   'knihy',
#   'š',
#   '##véd',
#   '##sky'],
#  ['Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'byla',
#   'finsk',
#   '##á',
#   'spisovatel',
#   '##ka'],
#  ['Šv',
#   '##éd',
#   '##ka',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'napsal',
#   '##a',
#   'D',
#   '##ět',
#   '##i',
#   'z',
#   'Bull',
#   '##er',
#   '##byn',
#   '##u'],
#  ['Šv',
#   '##éd',
#   '##ka',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'napsal',
#   '##a',
#   'D',
#   '##ět',
#   '##i',
#   'z',
#   'Bull',
#   '##er',
#   '##byn',
#   '##u'],
#  ['Šv',
#   '##éd',
#   '##ka',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'napsal',
#   '##a',
#   'D',
#   '##ět',
#   '##i',
#   'z',
#   'Bull',
#   '##er',
#   '##byn',
#   '##u'],
#  ['Astrid',
#   'Lin',
#   '##dgren',
#   '##ová',
#   'nen',
#   '##aps',
#   '##ala',
#   'ž',
#   '##ád',
#   '##nou',
#   'kn',
#   '##ih',
#   '##u'],
#  ['Jedno',
#   'z',
#   'dětí',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ové',
#   'byla',
#   'd',
#   '##cera',
#   'Karin'],
#  ['Jedno',
#   'z',
#   'dětí',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ové',
#   'byla',
#   'd',
#   '##cera',
#   'Karin'],
#  ['Jedno',
#   'z',
#   'dětí',
#   'Astrid',
#   'Lin',
#   '##dgren',
#   '##ové',
#   'byla',
#   'd',
#   '##cera',
#   'Karin'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'měla', 'syna'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'měla', 'syna'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'nem', '##ěla', 'žádné', 'děti'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'nem', '##ěla', 'žádné', 'děti'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'nem', '##ěla', 'žádné', 'děti'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'nem', '##ěla', 'žádné', 'děti'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'nem', '##ěla', 'žádné', 'děti'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'nem', '##ěla', 'žádné', 'děti'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'byla', 'bez', '##dě', '##tná'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'byla', 'bez', '##dě', '##tná'],
#  ['Astrid', 'Lin', '##dgren', '##ová', 'byla', 'bez', '##dě', '##tná'],
#  ['V',
#   'hlavním',
#   'městě',
#   'České',
#   'republiky',
#   'se',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##lo',
#   'více',
#   'než',
#   '10000',
#   'demo',
#   '##nst',
#   '##rac',
#   '##í',
#   'v',
#   'roce',
#   '2008'],
#  ['V',
#   'hlavním',
#   'městě',
#   'České',
#   'republiky',
#   'se',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##lo',
#   'více',
#   'než',
#   '10000',
#   'demo',
#   '##nst',
#   '##rac',
#   '##í',
#   'v',
#   'roce',
#   '2008'],
#  ['V',
#   'hlavním',
#   'městě',
#   'České',
#   'republiky',
#   'se',
#   'us',
#   '##kut',
#   '##e',
#   '##čni',
#   '##lo',
#   'více',
#   'než',
#   '10000',
#   'demo',
#   '##nst',
#   '##rac',
#   '##í',
#   'v',
#   'roce',
#   '2008'],
#  ['V',
#   'roce',
#   '2008',
#   'pro',
#   '##běh',
#   '##lo',
#   'v',
#   'Praze',
#   'okolo',
#   '5000',
#   'demo',
#   '##nst',
#   '##rac',
#   '##í'],
#  ['V',
#   'České',
#   'republice',
#   'pro',
#   '##běh',
#   '##lo',
#   'více',
#   'než',
#   '10000',
#   'protest',
#   '##ních',
#   'ak',
#   '##cí',
#   'v',
#   'roce',
#   '2008'],
#  ['V',
#   'České',
#   'republice',
#   'pro',
#   '##běh',
#   '##lo',
#   'více',
#   'než',
#   '10000',
#   'protest',
#   '##ních',
#   'ak',
#   '##cí',
#   'v',
#   'roce',
#   '2008'],
#  ['St',
#   '##av',
#   'za',
#   '##mě',
#   '##st',
#   '##nan',
#   '##ců',
#   'kromě',
#   '##říž',
#   '##ské',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'byl',
#   'v',
#   'roce',
#   '2015',
#   'více',
#   'než',
#   'čtyři',
#   'sta'],
#  ['St',
#   '##av',
#   'za',
#   '##mě',
#   '##st',
#   '##nan',
#   '##ců',
#   'kromě',
#   '##říž',
#   '##ské',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'byl',
#   'v',
#   'roce',
#   '2015',
#   'více',
#   'než',
#   'čtyři',
#   'sta'],
#  ['St',
#   '##av',
#   'za',
#   '##mě',
#   '##st',
#   '##nan',
#   '##ců',
#   'kromě',
#   '##říž',
#   '##ské',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'byl',
#   'v',
#   'roce',
#   '2015',
#   'více',
#   'než',
#   'čtyři',
#   'sta'],
#  ['St',
#   '##av',
#   'za',
#   '##mě',
#   '##st',
#   '##nan',
#   '##ců',
#   'kromě',
#   '##říž',
#   '##ské',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'byl',
#   'v',
#   'roce',
#   '2015',
#   'více',
#   'než',
#   'čtyři',
#   'sta'],
#  ['Podle',
#   'ú',
#   '##čet',
#   '##ních',
#   'v',
#   '##ý',
#   '##kaz',
#   '##ů',
#   'za',
#   '##mě',
#   '##st',
#   '##ná',
#   '##vala',
#   'v',
#   'roce',
#   '2015',
#   'firma',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'více',
#   'než',
#   '400',
#   'osob'],
#  ['St',
#   '##av',
#   'za',
#   '##mě',
#   '##st',
#   '##nan',
#   '##ců',
#   'kromě',
#   '##říž',
#   '##ské',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'byl',
#   'v',
#   'roce',
#   '2015',
#   'méně',
#   'než',
#   'tři',
#   'sta'],
#  ['Firma',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'z',
#   'Kromě',
#   '##říže',
#   'byla',
#   'v',
#   'roce',
#   '2015',
#   'v',
#   'lik',
#   '##vida',
#   '##ci'],
#  ['Firma',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'z',
#   'Kromě',
#   '##říže',
#   'byla',
#   'v',
#   'roce',
#   '2015',
#   'v',
#   'lik',
#   '##vida',
#   '##ci'],
#  ['Hlavní',
#   '##m',
#   'od',
#   '##bě',
#   '##rate',
#   '##lem',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'z',
#   'Kromě',
#   '##říže',
#   'je',
#   'auto',
#   '##mobil',
#   '##ový',
#   'pr',
#   '##ům',
#   '##ys',
#   '##l'],
#  ['Kromě',
#   '##říž',
#   '##ská',
#   'firma',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'do',
#   '##dá',
#   '##vá',
#   'své',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ky',
#   'zejména',
#   'do',
#   'ene',
#   '##rge',
#   '##tické',
#   '##ho',
#   'od',
#   '##vě',
#   '##tví'],
#  ['Hlavní',
#   '##mi',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ky',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'z',
#   'Kromě',
#   '##říže',
#   'jsou',
#   'panel',
#   '##y',
#   'autor',
#   '##ád',
#   '##ií',
#   ',',
#   'navi',
#   '##ga',
#   '##ční',
#   'systém',
#   '##y',
#   'v',
#   'automobile',
#   '##ch',
#   'a',
#   'auto',
#   '##klimat',
#   '##izace'],
#  ['Hlavní',
#   '##mi',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ky',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'z',
#   'Kromě',
#   '##říže',
#   'jsou',
#   'panel',
#   '##y',
#   'autor',
#   '##ád',
#   '##ií',
#   ',',
#   'navi',
#   '##ga',
#   '##ční',
#   'systém',
#   '##y',
#   'v',
#   'automobile',
#   '##ch',
#   'a',
#   'auto',
#   '##klimat',
#   '##izace'],
#  ['Hlavní',
#   '##mi',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ky',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'z',
#   'Kromě',
#   '##říže',
#   'jsou',
#   'panel',
#   '##y',
#   'autor',
#   '##ád',
#   '##ií',
#   ',',
#   'navi',
#   '##ga',
#   '##ční',
#   'systém',
#   '##y',
#   'v',
#   'automobile',
#   '##ch',
#   'a',
#   'auto',
#   '##klimat',
#   '##izace'],
#  ['Hlavní',
#   '##mi',
#   'v',
#   '##ýr',
#   '##ob',
#   '##ky',
#   'firmy',
#   'Fr',
#   '##ema',
#   '##ch',
#   'Mora',
#   '##va',
#   'z',
#   'Kromě',
#   '##říže',
#   'jsou',
#   'panel',
#   '##y',
#   'autor',
#   '##ád',
#   '##ií',
#   ',',
#   'navi',
#   '##ga',
#   '##ční',
#   'systém',
#   '##y',
#   'v',
#   'automobile',
#   '##ch',
#   'a',
#   'auto',
#   '##klimat',
#   '##izace'],
#  ['K',
#   '##ře',
#   '##če',
#   'a',
#   'v',
#   '##y',
#   '##če',
#   '##rp',
#   '##ání',
#   'hr',
#   '##oz',
#   '##í',
#   'lid',
#   '##em',
#   'při',
#   'ho',
#   '##rk',
#   '##ém',
#   'počas',
#   '##í',
#   'a',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í'],
#  ['V',
#   'ho',
#   '##rk',
#   '##ém',
#   'počas',
#   '##í',
#   'může',
#   'nas',
#   '##tat',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'organi',
#   '##smu',
#   'do',
#   '##pro',
#   '##vá',
#   '##zené',
#   'k',
#   '##ře',
#   '##čem',
#   '##i',
#   'nebo',
#   'v',
#   '##y',
#   '##če',
#   '##rp',
#   '##ání',
#   '##m'],
#  ['V',
#   'ho',
#   '##rk',
#   '##ém',
#   'počas',
#   '##í',
#   'může',
#   'nas',
#   '##tat',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'organi',
#   '##smu',
#   'do',
#   '##pro',
#   '##vá',
#   '##zené',
#   'k',
#   '##ře',
#   '##čem',
#   '##i',
#   'nebo',
#   'v',
#   '##y',
#   '##če',
#   '##rp',
#   '##ání',
#   '##m'],
#  ['V',
#   'ho',
#   '##rk',
#   '##ém',
#   'počas',
#   '##í',
#   'může',
#   'nas',
#   '##tat',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'organi',
#   '##smu',
#   'do',
#   '##pro',
#   '##vá',
#   '##zené',
#   'k',
#   '##ře',
#   '##čem',
#   '##i',
#   'nebo',
#   'v',
#   '##y',
#   '##če',
#   '##rp',
#   '##ání',
#   '##m'],
#  ['K',
#   '##ře',
#   '##če',
#   'ne',
#   '##v',
#   '##znika',
#   '##jí',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í'],
#  ['K',
#   '##ře',
#   '##če',
#   'ne',
#   '##v',
#   '##znika',
#   '##jí',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í'],
#  ['K',
#   '##ře',
#   '##če',
#   'ne',
#   '##v',
#   '##znika',
#   '##jí',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í'],
#  ['K',
#   '##ře',
#   '##če',
#   'ne',
#   '##v',
#   '##znika',
#   '##jí',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í'],
#  ['Denver', '##ský', 'st', '##řel', '##ec', 'byl', 'u', 'sou', '##du'],
#  ['St',
#   '##řel',
#   '##ec',
#   'z',
#   'Denver',
#   '##u',
#   'byl',
#   'za',
#   '##st',
#   '##řel',
#   '##en',
#   'při',
#   'zat',
#   '##ý',
#   '##kání'],
#  ['Z',
#   'Al',
#   '##ží',
#   '##rska',
#   'při',
#   '##šlo',
#   'do',
#   'Evropy',
#   'více',
#   'než',
#   '1000',
#   'lidí'],
#  ['V',
#   'září',
#   'při',
#   '##šlo',
#   'z',
#   'Tunis',
#   '##ka',
#   'do',
#   'jižní',
#   'Evropy',
#   'přes',
#   'tisíc',
#   'lidí'],
#  ['V',
#   'září',
#   'při',
#   '##šlo',
#   'z',
#   'Afrik',
#   '##y',
#   'do',
#   'Evropy',
#   'přes',
#   '1000',
#   'lidí'],
#  ['V',
#   'září',
#   'při',
#   '##šlo',
#   'z',
#   'Afrik',
#   '##y',
#   'do',
#   'Evropy',
#   'přes',
#   '1000',
#   'lidí'],
#  ['V',
#   'září',
#   'z',
#   '##ůstal',
#   '##i',
#   'lidé',
#   'v',
#   'Tunis',
#   '##ku',
#   'a',
#   'počet',
#   'im',
#   '##ig',
#   '##rant',
#   '##ů',
#   'v',
#   'Evropě',
#   'z',
#   '##ůstal',
#   'st',
#   '##ej',
#   '##ný'],
#  ['V',
#   'září',
#   'z',
#   '##ůstal',
#   '##i',
#   'lidé',
#   'v',
#   'Tunis',
#   '##ku',
#   'a',
#   'počet',
#   'im',
#   '##ig',
#   '##rant',
#   '##ů',
#   'v',
#   'Evropě',
#   'z',
#   '##ůstal',
#   'st',
#   '##ej',
#   '##ný'],
#  ['Rad',
#   '##nice',
#   'v',
#   'Post',
#   '##olo',
#   '##pr',
#   '##tech',
#   'za',
#   '##ch',
#   '##ra',
#   '##ňuje',
#   'místní',
#   'kap',
#   '##li'],
#  ['Rad',
#   '##nice',
#   'v',
#   'Post',
#   '##olo',
#   '##pr',
#   '##tech',
#   'za',
#   '##ch',
#   '##ra',
#   '##ňuje',
#   'místní',
#   'kap',
#   '##li'],
#  ['Rad',
#   '##nice',
#   'Br',
#   '##na',
#   'za',
#   '##ch',
#   '##ra',
#   '##ňuje',
#   'kap',
#   '##li',
#   'č',
#   '##tr',
#   '##ná',
#   '##cti',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků'],
#  ['Rad',
#   '##nice',
#   'Post',
#   '##olo',
#   '##pr',
#   '##t',
#   'ot',
#   '##ev',
#   '##ír',
#   '##á',
#   'městské',
#   'kino'],
#  ['Rad',
#   '##nice',
#   'Post',
#   '##olo',
#   '##pr',
#   '##t',
#   'ot',
#   '##ev',
#   '##ír',
#   '##á',
#   'městské',
#   'kino'],
#  ['Rad',
#   '##nice',
#   'Post',
#   '##olo',
#   '##pr',
#   '##t',
#   'za',
#   '##ch',
#   '##ra',
#   '##ňuje',
#   'tym',
#   '##pan',
#   '##on',
#   'kaple',
#   'č',
#   '##tr',
#   '##ná',
#   '##cti',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků'],
#  ['Rad',
#   '##nice',
#   'Post',
#   '##olo',
#   '##pr',
#   '##t',
#   'za',
#   '##ch',
#   '##ra',
#   '##ňuje',
#   'tym',
#   '##pan',
#   '##on',
#   'kaple',
#   'č',
#   '##tr',
#   '##ná',
#   '##cti',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků'],
#  ['Rad',
#   '##nice',
#   'Post',
#   '##olo',
#   '##pr',
#   '##t',
#   'za',
#   '##ch',
#   '##ra',
#   '##ňuje',
#   'tym',
#   '##pan',
#   '##on',
#   'kaple',
#   'č',
#   '##tr',
#   '##ná',
#   '##cti',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků'],
#  ['Rad',
#   '##nice',
#   'Post',
#   '##olo',
#   '##pr',
#   '##t',
#   'za',
#   '##ch',
#   '##ra',
#   '##ňuje',
#   'c',
#   '##ír',
#   '##ke',
#   '##vní',
#   'pa',
#   '##mát',
#   '##ku'],
#  ['Rad',
#   '##nice',
#   'Post',
#   '##olo',
#   '##pr',
#   '##t',
#   'ne',
#   '##ch',
#   '##ává',
#   'ch',
#   '##át',
#   '##rat',
#   'kap',
#   '##li',
#   'č',
#   '##tr',
#   '##ná',
#   '##cti',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků'],
#  ['Rad',
#   '##nice',
#   'Post',
#   '##olo',
#   '##pr',
#   '##t',
#   'ne',
#   '##ch',
#   '##ává',
#   'ch',
#   '##át',
#   '##rat',
#   'kap',
#   '##li',
#   'č',
#   '##tr',
#   '##ná',
#   '##cti',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kaple',
#   'z',
#   'poloviny',
#   '19',
#   '.',
#   'století',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kaple',
#   'z',
#   'poloviny',
#   '19',
#   '.',
#   'století',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Star',
#   '##osta',
#   'P',
#   '##ís',
#   '##ku',
#   'pro',
#   '##hlásil',
#   ',',
#   'že',
#   'kaple',
#   'z',
#   'roku',
#   '1841',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Star',
#   '##osta',
#   'P',
#   '##ís',
#   '##ku',
#   'pro',
#   '##hlásil',
#   ',',
#   'že',
#   'kaple',
#   'z',
#   'roku',
#   '1841',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Star',
#   '##osta',
#   'P',
#   '##ís',
#   '##ku',
#   'pro',
#   '##hlásil',
#   ',',
#   'že',
#   'kaple',
#   'z',
#   'roku',
#   '1841',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'divadlo',
#   'bude',
#   'op',
#   '##raven',
#   '##o',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'divadlo',
#   'bude',
#   'op',
#   '##raven',
#   '##o',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'divadlo',
#   'bude',
#   'op',
#   '##raven',
#   '##o',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kaple',
#   'z',
#   'roku',
#   '1841',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'ro',
#   '##z',
#   '##po',
#   '##č',
#   '##tu',
#   'na',
#   'kultur',
#   '##u',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kaple',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kaple',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kaple',
#   'bude',
#   'op',
#   '##raven',
#   '##a',
#   'z',
#   'pen',
#   '##ěz',
#   'města'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kap',
#   '##li',
#   'z',
#   'roku',
#   '1841',
#   'ne',
#   '##ch',
#   '##á',
#   'město',
#   'v',
#   'dez',
#   '##ol',
#   '##átní',
#   '##m',
#   'stavu'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kap',
#   '##li',
#   'z',
#   'roku',
#   '1841',
#   'ne',
#   '##ch',
#   '##á',
#   'město',
#   'v',
#   'dez',
#   '##ol',
#   '##átní',
#   '##m',
#   'stavu'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kap',
#   '##li',
#   'z',
#   'roku',
#   '1841',
#   'ne',
#   '##ch',
#   '##á',
#   'město',
#   'v',
#   'dez',
#   '##ol',
#   '##átní',
#   '##m',
#   'stavu'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kap',
#   '##li',
#   'z',
#   'roku',
#   '1841',
#   'ne',
#   '##ch',
#   '##á',
#   'město',
#   'v',
#   'dez',
#   '##ol',
#   '##átní',
#   '##m',
#   'stavu'],
#  ['Post',
#   '##olo',
#   '##pr',
#   '##ts',
#   '##ká',
#   'starost',
#   '##ka',
#   'pro',
#   '##hlásil',
#   '##a',
#   ',',
#   'že',
#   'kap',
#   '##li',
#   'z',
#   'roku',
#   '1841',
#   'ne',
#   '##ch',
#   '##á',
#   'město',
#   'v',
#   'dez',
#   '##ol',
#   '##átní',
#   '##m',
#   'stavu'],
#  ['Kap',
#   '##le',
#   '14',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků',
#   'v',
#   'Cho',
#   '##mut',
#   '##ově',
#   'je',
#   'v',
#   'majetku',
#   'církve',
#   ',',
#   'ale',
#   'op',
#   '##ra',
#   '##ví',
#   'ji',
#   'město'],
#  ['Kap',
#   '##le',
#   '14',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků',
#   'v',
#   'Cho',
#   '##mut',
#   '##ově',
#   'je',
#   'v',
#   'majetku',
#   'církve',
#   ',',
#   'ale',
#   'op',
#   '##ra',
#   '##ví',
#   'ji',
#   'město'],
#  ['Kap',
#   '##le',
#   '14',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků',
#   'v',
#   'Post',
#   '##olo',
#   '##pr',
#   '##tech',
#   'má',
#   'sou',
#   '##kro',
#   '##mé',
#   '##ho',
#   'maji',
#   '##tele',
#   ',',
#   'ale',
#   'op',
#   '##ra',
#   '##ví',
#   'ji',
#   'město'],
#  ['Kap',
#   '##le',
#   '14',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků',
#   'v',
#   'Post',
#   '##olo',
#   '##pr',
#   '##tech',
#   'má',
#   'sou',
#   '##kro',
#   '##mé',
#   '##ho',
#   'maji',
#   '##tele',
#   ',',
#   'ale',
#   'op',
#   '##ra',
#   '##ví',
#   'ji',
#   'město'],
#  ['Kap',
#   '##le',
#   '14',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků',
#   'v',
#   'Ú',
#   '##ste',
#   '##cké',
#   '##m',
#   'kraji',
#   'je',
#   'v',
#   'majetku',
#   'církve',
#   ',',
#   'ale',
#   'op',
#   '##ra',
#   '##ví',
#   'ji',
#   'město'],
#  ['Kap',
#   '##le',
#   '14',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků',
#   'v',
#   'Ú',
#   '##ste',
#   '##cké',
#   '##m',
#   'kraji',
#   'je',
#   'v',
#   'majetku',
#   'církve',
#   ',',
#   'ale',
#   'op',
#   '##ra',
#   '##ví',
#   'ji',
#   'město'],
#  ['Kap',
#   '##le',
#   '14',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků',
#   'v',
#   'Ú',
#   '##ste',
#   '##cké',
#   '##m',
#   'kraji',
#   'je',
#   'v',
#   'majetku',
#   'církve',
#   ',',
#   'ale',
#   'op',
#   '##ra',
#   '##ví',
#   'ji',
#   'město'],
#  ['Kap',
#   '##le',
#   '14',
#   'sva',
#   '##tých',
#   'pomoc',
#   '##níků',
#   'v',
#   'Post',
#   '##olo',
#   '##pr',
#   '##tech',
#   'je',
#   'v',
#   'majetku',
#   'města',
#   ',',
#   'kterého',
#   'op',
#   '##ra',
#   '##ví'],
#  ['Richard',
#   'Los',
#   '##kot',
#   'v',
#   '##ysta',
#   '##vuje',
#   'v',
#   'gal',
#   '##erii',
#   've',
#   'východní',
#   '##ch',
#   'Čechách'],
#  ['Richard',
#   'Los',
#   '##kot',
#   'v',
#   '##ysta',
#   '##vuje',
#   'v',
#   'gal',
#   '##erii',
#   've',
#   'východní',
#   '##ch',
#   'Čechách'],
#  ['Richard',
#   'Los',
#   '##kot',
#   'nat',
#   '##á',
#   '##čí',
#   'film',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Richard',
#   'Los',
#   '##kot',
#   'nat',
#   '##á',
#   '##čí',
#   'film',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Autor',
#   'audio',
#   '##vi',
#   '##zu',
#   '##álních',
#   'instal',
#   '##ací',
#   'Richard',
#   'Los',
#   '##kot',
#   'v',
#   '##ysta',
#   '##vuje',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Autor',
#   'audio',
#   '##vi',
#   '##zu',
#   '##álních',
#   'instal',
#   '##ací',
#   'v',
#   '##ysta',
#   '##vuje',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Autor',
#   'audio',
#   '##vi',
#   '##zu',
#   '##álních',
#   'instal',
#   '##ací',
#   'v',
#   '##ysta',
#   '##vuje',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Autor',
#   'audio',
#   '##vi',
#   '##zu',
#   '##álních',
#   'instal',
#   '##ací',
#   'v',
#   '##ysta',
#   '##vuje',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Richard',
#   'Los',
#   '##kot',
#   'od',
#   '##mí',
#   '##tl',
#   'v',
#   '##ysta',
#   '##vo',
#   '##vat',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Richard',
#   'Los',
#   '##kot',
#   'od',
#   '##mí',
#   '##tl',
#   'v',
#   '##ysta',
#   '##vo',
#   '##vat',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['Richard',
#   'Los',
#   '##kot',
#   'od',
#   '##mí',
#   '##tl',
#   'v',
#   '##ysta',
#   '##vo',
#   '##vat',
#   'v',
#   'gal',
#   '##erii',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci',
#   'Králové'],
#  ['V',
#   '##ý',
#   '##stava',
#   'Velké',
#   'ti',
#   '##cho',
#   'před',
#   '##stavuje',
#   'os',
#   '##m',
#   'sou',
#   '##čas',
#   '##ných',
#   'autore',
#   '##k'],
#  ['V',
#   '##ý',
#   '##stava',
#   'Velké',
#   'ti',
#   '##cho',
#   'před',
#   '##stavuje',
#   'os',
#   '##m',
#   'sou',
#   '##čas',
#   '##ných',
#   'autore',
#   '##k'],
#  ['V',
#   '##ý',
#   '##stava',
#   'Velké',
#   'ti',
#   '##cho',
#   'před',
#   '##stavuje',
#   'os',
#   '##m',
#   'sou',
#   '##čas',
#   '##ných',
#   'mal',
#   '##íř',
#   '##ů'],
#  ['V',
#   '##ý',
#   '##stava',
#   'Velké',
#   'ti',
#   '##cho',
#   'před',
#   '##stavuje',
#   'os',
#   '##m',
#   'sou',
#   '##čas',
#   '##ných',
#   'mal',
#   '##íř',
#   '##ů'],
#  ['V',
#   '##ý',
#   '##stava',
#   'Velké',
#   'ti',
#   '##cho',
#   'před',
#   '##stavuje',
#   'os',
#   '##m',
#   'autor',
#   '##ů'],
#  ['V',
#   '##ý',
#   '##stava',
#   'Velké',
#   'ti',
#   '##cho',
#   'před',
#   '##stavuje',
#   'os',
#   '##m',
#   'autor',
#   '##ů'],
#  ['V', '##ý', '##stava', 'Velké', 'ti', '##cho', 'je', 'uz', '##av', '##řena'],
#  ['Tema',
#   '##tic',
#   '##ká',
#   'v',
#   '##ý',
#   '##stava',
#   'minimal',
#   '##ismu',
#   'za',
#   '##číná',
#   'v',
#   'hrad',
#   '##ecké',
#   'Gale',
#   '##rii',
#   'Modern',
#   '##ího',
#   'umění'],
#  ['Tema',
#   '##tic',
#   '##ká',
#   'v',
#   '##ý',
#   '##stava',
#   'minimal',
#   '##ismu',
#   'za',
#   '##číná',
#   'v',
#   'Gale',
#   '##rii',
#   'Modern',
#   '##ího',
#   'umění',
#   'v',
#   'Ost',
#   '##ra',
#   '##vě'],
#  ['Tema',
#   '##tic',
#   '##ká',
#   'v',
#   '##ý',
#   '##stava',
#   'minimal',
#   '##ismu',
#   'za',
#   '##číná',
#   'v',
#   'Gale',
#   '##rii',
#   'Modern',
#   '##ího',
#   'umění',
#   'v',
#   'Ost',
#   '##ra',
#   '##vě'],
#  ['Tema',
#   '##tic',
#   '##ká',
#   'v',
#   '##ý',
#   '##stava',
#   'architektury',
#   'za',
#   '##číná',
#   'v',
#   'Gale',
#   '##rii',
#   'Modern',
#   '##ího',
#   'umění',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci'],
#  ['Tema',
#   '##tic',
#   '##ká',
#   'v',
#   '##ý',
#   '##stava',
#   'architektury',
#   'za',
#   '##číná',
#   'v',
#   'Gale',
#   '##rii',
#   'Modern',
#   '##ího',
#   'umění',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci'],
#  ['Tema',
#   '##tic',
#   '##ká',
#   'v',
#   '##ý',
#   '##stava',
#   'architektury',
#   'za',
#   '##číná',
#   'v',
#   'Gale',
#   '##rii',
#   'Modern',
#   '##ího',
#   'umění',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci'],
#  ['Tema',
#   '##tic',
#   '##ká',
#   'v',
#   '##ý',
#   '##stava',
#   'architektury',
#   'za',
#   '##číná',
#   'v',
#   'Gale',
#   '##rii',
#   'Modern',
#   '##ího',
#   'umění',
#   'v',
#   'Hr',
#   '##ad',
#   '##ci'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'sk',
#   '##onal',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'sk',
#   '##onal',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'sk',
#   '##onal',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'sk',
#   '##onal',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zemřel',
#   'na',
#   'in',
#   '##far',
#   '##kt'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zemřel',
#   'na',
#   'in',
#   '##far',
#   '##kt'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zm',
#   '##ize',
#   '##l'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zm',
#   '##ize',
#   '##l'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zemřel',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu',
#   'sl',
#   '##ini',
#   '##vky'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zemřel',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu',
#   'sl',
#   '##ini',
#   '##vky'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'polsk',
#   '##ý',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zemřel',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu',
#   'sl',
#   '##ini',
#   '##vky'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'ev',
#   '##rop',
#   '##ský',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zemřel',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu'],
#  ['O',
#   '##ce',
#   '##ň',
#   '##ovaný',
#   'ev',
#   '##rop',
#   '##ský',
#   'režisér',
#   'Andrzej',
#   'Ž',
#   '##ula',
#   '##wski',
#   'zemřel',
#   'na',
#   'rak',
#   '##ovi',
#   '##nu'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'kon',
#   '##tro',
#   '##ver',
#   '##zní',
#   '##ho',
#   's',
#   '##ním',
#   '##ku',
#   'T',
#   '##ře',
#   '##tí',
#   'část',
#   'noci',
#   '(',
#   '1971',
#   ')',
#   'zemřel',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'kon',
#   '##tro',
#   '##ver',
#   '##zní',
#   '##ho',
#   's',
#   '##ním',
#   '##ku',
#   'T',
#   '##ře',
#   '##tí',
#   'část',
#   'noci',
#   '(',
#   '1971',
#   ')',
#   'zemřel',
#   'v',
#   'Pol',
#   '##sku'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'kon',
#   '##tro',
#   '##ver',
#   '##zní',
#   '##ho',
#   's',
#   '##ním',
#   '##ku',
#   'T',
#   '##ře',
#   '##tí',
#   'část',
#   'noci',
#   '(',
#   '1971',
#   ')',
#   'zemřel',
#   've',
#   'L',
#   '##vo',
#   '##vě'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'kon',
#   '##tro',
#   '##ver',
#   '##zní',
#   '##ho',
#   's',
#   '##ním',
#   '##ku',
#   'T',
#   '##ře',
#   '##tí',
#   'část',
#   'noci',
#   '(',
#   '1971',
#   ')',
#   'zemřel',
#   've',
#   'L',
#   '##vo',
#   '##vě'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'nek',
#   '##one',
#   '##čného',
#   'seriálu',
#   'Or',
#   '##dina',
#   '##ce',
#   'zemřel',
#   've',
#   'Var',
#   '##ša',
#   '##vě'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'nek',
#   '##one',
#   '##čného',
#   'seriálu',
#   'Or',
#   '##dina',
#   '##ce',
#   'zemřel',
#   've',
#   'Var',
#   '##ša',
#   '##vě'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'kon',
#   '##tro',
#   '##ver',
#   '##zní',
#   '##ho',
#   's',
#   '##ním',
#   '##ku',
#   'T',
#   '##ře',
#   '##tí',
#   'část',
#   'noci',
#   '(',
#   '1971',
#   ')',
#   'zemřel',
#   've',
#   'svém',
#   'var',
#   '##ša',
#   '##vské',
#   '##m',
#   'by',
#   '##tě'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'kon',
#   '##tro',
#   '##ver',
#   '##zní',
#   '##ho',
#   's',
#   '##ním',
#   '##ku',
#   'T',
#   '##ře',
#   '##tí',
#   'část',
#   'noci',
#   '(',
#   '1971',
#   ')',
#   'zemřel',
#   've',
#   'svém',
#   'var',
#   '##ša',
#   '##vské',
#   '##m',
#   'by',
#   '##tě'],
#  ['Re',
#   '##ži',
#   '##sé',
#   '##r',
#   'kon',
#   '##tro',
#   '##ver',
#   '##zní',
#   '##ch',
#   'film',
# ...
#   '##í',
#   'po',
#   '##ško',
#   '##zení',
#   'organi',
#   '##smu'],
#  ['Ho',
#   '##rko',
#   'má',
#   'vždy',
#   'po',
#   '##zit',
#   '##ivní',
#   'vliv',
#   'na',
#   'lid',
#   '##ské',
#   't',
#   '##ělo'],
#  ['Ho',
#   '##rko',
#   'má',
#   'vždy',
#   'po',
#   '##zit',
#   '##ivní',
#   'vliv',
#   'na',
#   'lid',
#   '##ské',
#   't',
#   '##ělo'],
#  ['K',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'se',
#   'ob',
#   '##jev',
#   '##ují',
#   've',
#   'sp',
#   '##odní',
#   'části',
#   'tr',
#   '##upu'],
#  ['K',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'se',
#   'ob',
#   '##jev',
#   '##ují',
#   've',
#   'sp',
#   '##odní',
#   'části',
#   'tr',
#   '##upu'],
#  ['K',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'se',
#   'ob',
#   '##jev',
#   '##ují',
#   'v',
#   'ž',
#   '##alu',
#   '##dku'],
#  ['K',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'se',
#   'ob',
#   '##jev',
#   '##ují',
#   'v',
#   'ž',
#   '##alu',
#   '##dku'],
#  ['K',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'se',
#   'ob',
#   '##jev',
#   '##ují',
#   'v',
#   'ž',
#   '##alu',
#   '##dku'],
#  ['K',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'se',
#   'ob',
#   '##jev',
#   '##ují',
#   'po',
#   'celé',
#   '##m',
#   't',
#   '##ěl',
#   '##e'],
#  ['K',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   'se',
#   'ob',
#   '##jev',
#   '##ují',
#   'pouze',
#   'v',
#   'do',
#   '##lní',
#   '##ch',
#   'kon',
#   '##čet',
#   '##in',
#   '##ách'],
#  ['Pokud',
#   'k',
#   '##ře',
#   '##če',
#   'do',
#   'še',
#   '##des',
#   '##át',
#   '##i',
#   'minut',
#   'ne',
#   '##pole',
#   '##ví',
#   ',',
#   'je',
#   'pot',
#   '##ře',
#   '##ba',
#   'v',
#   '##y',
#   '##hle',
#   '##dat',
#   'l',
#   '##éka',
#   '##ř',
#   '##skou',
#   'pomoc'],
#  ['Pokud',
#   'k',
#   '##ře',
#   '##če',
#   'do',
#   'še',
#   '##des',
#   '##át',
#   '##i',
#   'minut',
#   'ne',
#   '##pole',
#   '##ví',
#   ',',
#   'je',
#   'pot',
#   '##ře',
#   '##ba',
#   'v',
#   '##y',
#   '##hle',
#   '##dat',
#   'l',
#   '##éka',
#   '##ř',
#   '##skou',
#   'pomoc'],
#  ['Pokud',
#   'k',
#   '##ře',
#   '##če',
#   'do',
#   'hodin',
#   '##y',
#   'neu',
#   '##sto',
#   '##up',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tno',
#   'vol',
#   '##at',
#   'z',
#   '##dra',
#   '##vot',
#   '##nick',
#   '##ou',
#   'z',
#   '##ách',
#   '##ranno',
#   '##u',
#   'službu'],
#  ['Pokud',
#   'k',
#   '##ře',
#   '##če',
#   'neu',
#   '##stup',
#   '##ují',
#   ',',
#   'je',
#   'nu',
#   '##tno',
#   'pro',
#   '##vá',
#   '##dě',
#   '##t',
#   'sva',
#   '##lov',
#   '##ou',
#   'mas',
#   '##á',
#   '##ž'],
#  ['Pokud',
#   'k',
#   '##ře',
#   '##če',
#   'do',
#   'hodin',
#   '##y',
#   'neu',
#   '##sto',
#   '##up',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tno',
#   'vol',
#   '##at',
#   'pra',
#   '##kti',
#   '##cké',
#   '##mu',
#   'l',
#   '##éka',
#   '##ři'],
#  ['Pokud',
#   'k',
#   '##ře',
#   '##če',
#   'do',
#   'hodin',
#   '##y',
#   'neu',
#   '##sto',
#   '##up',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tno',
#   'vol',
#   '##at',
#   'ob',
#   '##orno',
#   '##u',
#   'pomoc'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'pot',
#   '##ře',
#   '##ba',
#   'za',
#   '##stav',
#   '##it',
#   'činnost',
#   'a',
#   'ne',
#   '##vy',
#   '##stav',
#   '##ovat',
#   'se',
#   'ho',
#   '##rku'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tné',
#   'od',
#   '##po',
#   '##čí',
#   '##vat'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tné',
#   'od',
#   '##po',
#   '##čí',
#   '##vat'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tné',
#   'od',
#   '##po',
#   '##čí',
#   '##vat'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tné',
#   'p',
#   '##ít',
#   'dosta',
#   '##tek',
#   'tek',
#   '##uti',
#   '##n'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tné',
#   'od',
#   '##po',
#   '##čí',
#   '##vat',
#   'v',
#   'klima',
#   '##ti',
#   '##zov',
#   '##ané',
#   'mí',
#   '##st',
#   '##nosti'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tné',
#   'od',
#   '##po',
#   '##čí',
#   '##vat',
#   'v',
#   'klima',
#   '##ti',
#   '##zov',
#   '##ané',
#   'mí',
#   '##st',
#   '##nosti'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'nu',
#   '##tné',
#   'se',
#   'v',
#   '##y',
#   '##hn',
#   '##out',
#   'aktiv',
#   '##itě',
#   'na',
#   'př',
#   '##ím',
#   '##ém',
#   'sl',
#   '##un',
#   '##ci'],
#  ['Když',
#   'se',
#   'ob',
#   '##jev',
#   '##í',
#   'k',
#   '##ře',
#   '##če',
#   'z',
#   'př',
#   '##eh',
#   '##ř',
#   '##át',
#   '##í',
#   ',',
#   'je',
#   'dob',
#   '##ré',
#   'z',
#   '##ů',
#   '##stat',
#   'v',
#   'ho',
#   '##rku',
#   'a',
#   'dále',
#   'se',
#   'v',
#   '##ěn',
#   '##ovat',
#   'před',
#   '##eš',
#   '##lé',
#   'aktiv',
#   '##itě'],
#  ['12',
#   '.',
#   'května',
#   '1945',
#   'pro',
#   '##běh',
#   '##la',
#   'bit',
#   '##va',
#   'u',
#   'S',
#   '##liv',
#   '##ice'],
#  ['Na',
#   'Brně',
#   '##nsku',
#   'se',
#   '24',
#   '.',
#   'dubna',
#   '1945',
#   'odehrál',
#   '##a',
#   'tank',
#   '##ová',
#   'bit',
#   '##va'],
#  ['Na',
#   'Brně',
#   '##nsku',
#   'se',
#   '24',
#   '.',
#   'dubna',
#   '1945',
#   'odehrál',
#   '##a',
#   'tank',
#   '##ová',
#   'bit',
#   '##va'],
#  ['24',
#   '.',
#   'dubna',
#   '1945',
#   'pan',
#   '##oval',
#   'u',
#   'O',
#   '##řech',
#   '##ova',
#   'kl',
#   '##id',
#   'z',
#   '##bran',
#   '##í'],
#  ['V',
#   'době',
#   'druhé',
#   'světové',
#   'války',
#   'se',
#   'poslední',
#   'bit',
#   '##va',
#   'na',
#   'Brně',
#   '##nsku',
#   'odehrál',
#   '##a',
#   'u',
#   'O',
#   '##řech',
#   '##ova'],
#  ['V',
#   'tank',
#   '##ové',
#   'bitvě',
#   'u',
#   'O',
#   '##řech',
#   '##ova',
#   'bylo',
#   'z',
#   '##bo',
#   '##řen',
#   '##o',
#   '176',
#   'domů'],
#  ['Tank',
#   '##ová',
#   'bit',
#   '##va',
#   'u',
#   'O',
#   '##řech',
#   '##ova',
#   'na',
#   'Brně',
#   '##nsku',
#   'z',
#   '24',
#   '.',
#   'dubna',
#   '1945',
#   'byla',
#   'poslední',
#   '##m',
#   'boje',
#   '##m',
#   'v',
#   'regionu',
#   'za',
#   'druhé',
#   'světové',
#   'války'],
#  ['Tank',
#   '##ová',
#   'bit',
#   '##va',
#   'u',
#   'O',
#   '##řech',
#   '##ova',
#   'na',
#   'Brně',
#   '##nsku',
#   'z',
#   '24',
#   '.',
#   'dubna',
#   '1945',
#   'byla',
#   'poslední',
#   '##m',
#   'boje',
#   '##m',
#   'v',
#   'regionu',
#   'za',
#   'druhé',
#   'světové',
#   'války'],
#  ['Na',
#   'Brně',
#   '##nsku',
#   'pro',
#   '##běh',
#   '##la',
#   'poslední',
#   'bit',
#   '##va',
#   'druhé',
#   'světové',
#   'války',
#   '24',
#   '.',
#   'dubna',
#   '1945'],
#  ['Na',
#   'Brně',
#   '##nsku',
#   'pro',
#   '##běh',
#   '##la',
#   'poslední',
#   'bit',
#   '##va',
#   'druhé',
#   'světové',
#   'války',
#   '24',
#   '.',
#   'dubna',
#   '1945'],
#  ['Tank',
#   '##ová',
#   'bit',
#   '##va',
#   'u',
#   'O',
#   '##řech',
#   '##ova',
#   'pod',
#   '##ní',
#   '##tila',
#   'další',
#   'boje',
#   'na',
#   'Brně',
#   '##nsku',
#   'v',
#   'době',
#   'druhé',
#   'světové',
#   'války'],
#  ['Tank',
#   '##ová',
#   'bit',
#   '##va',
#   'u',
#   'O',
#   '##řech',
#   '##ova',
#   'pod',
#   '##ní',
#   '##tila',
#   'další',
#   'boje',
#   'na',
#   'Brně',
#   '##nsku',
#   'v',
#   'době',
#   'druhé',
#   'světové',
#   'války'],
#  ['So',
#   '##ut',
#   '##ěž',
#   'filma',
#   '##ř',
#   '##ů',
#   'má',
#   'trad',
#   '##ici',
#   'už',
#   'še',
#   '##des',
#   '##átých',
#   'let',
#   '20',
#   '.',
#   'století'],
#  ['Tra',
#   '##di',
#   '##ční',
#   'festival',
#   'amat',
#   '##ér',
#   '##ských',
#   'filma',
#   '##ř',
#   '##ů',
#   'sp',
#   '##ad',
#   '##á',
#   'do',
#   'sed',
#   '##mde',
#   '##s',
#   '##átých',
#   'let',
#   '20',
#   '.',
#   'století'],
#  ['Festival',
#   'amat',
#   '##ér',
#   '##ských',
#   'film',
#   '##ů',
#   'se',
#   'trad',
#   '##ič',
#   '##ně',
#   'po',
#   '##ř',
#   '##ád',
#   '##á',
#   'od',
#   'roku',
#   '1960'],
#  ['Festival',
#   'amat',
#   '##ér',
#   '##ských',
#   'film',
#   '##ů',
#   'se',
#   'trad',
#   '##ič',
#   '##ně',
#   'po',
#   '##ř',
#   '##ád',
#   '##á',
#   'od',
#   'roku',
#   '1960'],
#  ['Festival',
#   'amat',
#   '##ér',
#   '##ských',
#   'film',
#   '##ů',
#   'se',
#   'trad',
#   '##ič',
#   '##ně',
#   'po',
#   '##ř',
#   '##ád',
#   '##á',
#   'od',
#   'roku',
#   '1960'],
#  ['Festival',
#   'amat',
#   '##ér',
#   '##ských',
#   'film',
#   '##ů',
#   'se',
#   'trad',
#   '##ič',
#   '##ně',
#   'po',
#   '##ř',
#   '##ád',
#   '##á',
#   'od',
#   'roku',
#   '1960'],
#  ['Festival',
#   'amat',
#   '##ér',
#   '##ských',
#   'film',
#   '##ů',
#   'se',
#   'trad',
#   '##ič',
#   '##ně',
#   'po',
#   '##ř',
#   '##ád',
#   '##á',
#   'od',
#   'roku',
#   '1960'],
#  ['Ama',
#   '##tér',
#   '##ští',
#   'filma',
#   '##ři',
#   'sou',
#   '##tě',
#   '##ží',
#   'se',
#   'svými',
#   'filmy',
#   'už',
#   '60',
#   'let'],
#  ['So',
#   '##ut',
#   '##ěž',
#   'Brně',
#   '##nská',
#   'šest',
#   '##ná',
#   '##ct',
#   '##ka',
#   'bu',
#   '##dí',
#   'po',
#   '##zor',
#   '##nost',
#   'u',
#   'filma',
#   '##ř',
#   '##ů',
#   'ze',
#   'států',
#   'Jižní',
#   'Amer',
#   '##iky'],
#  ['V',
#   '##ý',
#   '##stava',
#   'Brně',
#   '##nské',
#   'šest',
#   '##ná',
#   '##ct',
#   '##ky',
#   'v',
#   '##z',
#   '##bud',
#   '##ila',
#   'z',
#   '##á',
#   '##jem',
#   'u',
#   'Ji',
#   '##ho',
#   '##amer',
#   '##ič',
#   '##an',
#   '##ů'],
#  ['O',
#   'Brně',
#   '##nské',
#   'šest',
#   '##ná',
#   '##ct',
#   '##ky',
#   'mají',
#   'z',
#   '##á',
#   '##jem',
#   'lidé',
#   'z',
#   'Jižní',
#   'Amer',
#   '##iky'],
#  ['Ú',
#   '##čas',
#   '##t',
#   'v',
#   'soutěži',
#   'Brně',
#   '##nské',
#   'šest',
#   '##ná',
#   '##ct',
#   '##ky',
#   'od',
#   '##mí',
#   '##tli',
#   'jih',
#   '##oa',
#   '##meri',
#   '##č',
#   '##tí',
#   'filma',
#   '##ři'],
#  ['Po',
#   '##řad',
#   '##ate',
#   '##lem',
#   'soutěže',
#   'Brně',
#   '##nská',
#   'šest',
#   '##ná',
#   '##ct',
#   '##ka',
#   'je',
#   'městské',
#   'informa',
#   '##ční',
#   'st',
#   '##řed',
#   '##isko'],
#  ['So',
#   '##ut',
#   '##ěž',
#   'Brně',
#   '##nská',
#   'šest',
#   '##ná',
#   '##ct',
#   '##ka',
#   'se',
#   'kon',
#   '##á',
#   'v',
#   'prostor',
#   '##ách',
#   'městské',
#   '##ho',
#   'divadla',
#   '.'],
#  ['Festival',
#   'film',
#   '##ů',
#   'se',
#   'kon',
#   '##á',
#   'v',
#   'informa',
#   '##čním',
#   'st',
#   '##řed',
#   '##isku'],
#  ['Festival',
#   'film',
#   '##ů',
#   'se',
#   'kon',
#   '##á',
#   'v',
#   'informa',
#   '##čním',
#   'st',
#   '##řed',
#   '##isku'],
#  ['Prost',
#   '##ory',
#   'pro',
#   'po',
#   '##ř',
#   '##ád',
#   '##ání',
#   'festivalu',
#   'Brně',
#   '##nská',
#   'šest',
#   '##ná',
#   '##ct',
#   '##ka',
#   'leto',
#   '##s',
#   'na',
#   '##bí',
#   '##dne',
#   'místo',
#   'Tur',
#   '##istické',
#   '##ho',
#   'informa',
#   '##čního',
#   'centra',
#   'městské',
#   'divadlo'],
#  ['Š',
#   '##pan',
#   '##ěl',
#   '##ská',
#   'bank',
#   '##a',
#   'Santander',
#   'a',
#   'š',
#   '##vý',
#   '##cars',
#   '##ká',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'uz',
#   '##av',
#   '##řel',
#   '##y',
#   'novou',
#   'do',
#   '##hodu'],
#  ['Po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'a',
#   'General',
#   '##i',
#   'Česká',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'před',
#   '##stav',
#   '##ily',
#   'nové',
#   'sp',
#   '##ole',
#   '##čné',
#   'pod',
#   '##nik',
#   '##ání'],
#  ['Po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'a',
#   'General',
#   '##i',
#   'Česká',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'před',
#   '##stav',
#   '##ily',
#   'nové',
#   'sp',
#   '##ole',
#   '##čné',
#   'pod',
#   '##nik',
#   '##ání'],
#  ['Po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'a',
#   'General',
#   '##i',
#   'Česká',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'před',
#   '##stav',
#   '##ily',
#   'nové',
#   'sp',
#   '##ole',
#   '##čné',
#   'pod',
#   '##nik',
#   '##ání'],
#  ['Po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'a',
#   'General',
#   '##i',
#   'Česká',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'před',
#   '##stav',
#   '##ily',
#   'nové',
#   'sp',
#   '##ole',
#   '##čné',
#   'pod',
#   '##nik',
#   '##ání'],
#  ['Šv',
#   '##ý',
#   '##cars',
#   '##ká',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'a',
#   'š',
#   '##pan',
#   '##ěl',
#   '##ská',
#   'bank',
#   '##a',
#   'Santander',
#   'před',
#   '##stav',
#   '##ily',
#   'nové',
#   'sp',
#   '##ole',
#   '##čné',
#   'pod',
#   '##nik',
#   '##ání',
#   'v',
#   'Latin',
#   '##ské',
#   'Amer',
#   '##ice'],
#  ['Po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'bude',
#   'mít',
#   'př',
#   '##ístup',
#   'k',
#   'latin',
#   '##sko',
#   '##amer',
#   '##ické',
#   '##mu',
#   'ob',
#   '##chodu',
#   'díky',
#   'do',
#   '##hod',
#   '##ě',
#   's',
#   'bank',
#   '##ou',
#   'Santander',
#   '.'],
#  ['Po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'bude',
#   'mít',
#   'př',
#   '##ístup',
#   'k',
#   'latin',
#   '##sko',
#   '##amer',
#   '##ické',
#   '##mu',
#   'ob',
#   '##chodu',
#   'díky',
#   'do',
#   '##hod',
#   '##ě',
#   's',
#   'bank',
#   '##ou',
#   'Santander',
#   '.'],
#  ['Po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'se',
#   'díky',
#   'spolupráci',
#   's',
#   'bank',
#   '##ou',
#   'Santander',
#   'za',
#   '##mě',
#   '##ří',
#   'na',
#   'na',
#   '##bí',
#   '##dku',
#   'fina',
#   '##nční',
#   '##ch',
#   'sl',
#   '##u',
#   '##že',
#   '##b',
#   'v',
#   'Amer',
#   '##ice',
#   '.'],
#  ['Po',
#   '##ji',
#   '##šť',
#   '##ovna',
#   'Zurich',
#   'se',
#   'díky',
#   'spolupráci',
#   's',
#   'bank',
#   '##ou',
#   'Santander',
#   'za',
#   '##mě',
#   '##ří',
#   'na',
#   'na',
#   '##bí',
#   '##dku',
#   'fina',
#   '##nční',
#   '##ch',
#   'sl',
#   '##u',
#   '##že',
#   '##b',
#   'v',
#   'Amer',
#   '##ice',
#   '.'],
#  ['Sp',
#   '##olu',
#   '##pr',
#   '##áce',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovny',
#   'Zurich',
#   'a',
#   'banky',
#   'Santander',
#   'z',
#   '##p',
#   '##ří',
#   '##stup',
#   '##ní',
#   'š',
#   '##vý',
#   '##cars',
#   '##ké',
#   'skupině',
#   'rychle',
#   'ros',
#   '##tou',
#   '##cí',
#   'tr',
#   '##hy',
#   'a',
#   'š',
#   '##pan',
#   '##ěl',
#   '##ské',
#   'ins',
#   '##tit',
#   '##uc',
#   '##i',
#   'kap',
#   '##it',
#   '##ál',
#   'na',
#   'další',
#   'ak',
#   '##vi',
#   '##zice',
#   'v',
#   'Latin',
#   '##ské',
#   'Amer',
#   '##ice'],
#  ['Sp',
#   '##olu',
#   '##pr',
#   '##áce',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovny',
#   'Zurich',
#   'a',
#   'banky',
#   'Santander',
#   'z',
#   '##p',
#   '##ří',
#   '##stup',
#   '##ní',
#   'š',
#   '##vý',
#   '##cars',
#   '##ké',
#   'skupině',
#   'rychle',
#   'ros',
#   '##tou',
#   '##cí',
#   'tr',
#   '##hy',
#   'a',
#   'š',
#   '##pan',
#   '##ěl',
#   '##ské',
#   'ins',
#   '##tit',
#   '##uc',
#   '##i',
#   'kap',
#   '##it',
#   '##ál',
#   'na',
#   'další',
#   'ak',
#   '##vi',
#   '##zice',
#   'v',
#   'Latin',
#   '##ské',
#   'Amer',
#   '##ice'],
#  ['Do',
#   '##hoda',
#   'mezi',
#   'po',
#   '##ji',
#   '##šť',
#   '##ov',
#   '##nou',
#   'Zurich',
#   'a',
#   'bank',
#   '##ou',
#   'Santander',
#   'um',
#   '##o',
#   '##žní',
#   'š',
#   '##vý',
#   '##cars',
#   '##ké',
#   'skupině',
#   'př',
#   '##ístup',
#   'k',
#   'tr',
#   '##hů',
#   '##m',
#   'zemí',
#   'amerického',
#   'kon',
#   '##tinent',
#   '##u',
#   'již',
#   '##ně',
#   'od',
#   'USA'],
#  ['Do',
#   '##hoda',
#   'mezi',
#   'po',
#   '##ji',
#   '##šť',
#   '##ov',
#   '##nou',
#   'Zurich',
#   'a',
#   'bank',
#   '##ou',
#   'Santander',
#   'um',
#   '##o',
#   '##žní',
#   'š',
#   '##vý',
#   '##cars',
#   '##ké',
#   'skupině',
#   'př',
#   '##ístup',
#   'k',
#   'tr',
#   '##hů',
#   '##m',
#   'zemí',
#   'amerického',
#   'kon',
#   '##tinent',
#   '##u',
#   'již',
#   '##ně',
#   'od',
#   'USA'],
#  ['Sp',
#   '##olu',
#   '##pr',
#   '##áce',
#   'po',
#   '##ji',
#   '##šť',
#   '##ovny',
#   'Zurich',
#   'a',
#   'banky',
#   'Santander',
#   'za',
#   '##mez',
#   '##ila',
#   'př',
#   '##ístup',
#   'š',
#   '##vý',
#   '##cars',
#   '##ké',
#   'skupiny',
#   'k',
#   'tr',
#   '##hů',
#   '##m',
#   'v',
#   'Latin',
#   '##ské',
#   'Amer',
#   '##ice'],
#  ['Do',
#   '##hoda',
#   'ins',
#   '##tit',
#   '##uc',
#   '##í',
#   'v',
#   '##y',
#   '##šla',
#   'zhruba',
#   'na',
#   '40',
#   'mil',
#   '##iard',
#   'kor',
#   '##un'],
#  ['Do',
#   '##hoda',
#   'ins',
#   '##tit',
#   '##uc',
#   '##í',
#   'v',
#   '##y',
#   '##šla',
#   'zhruba',
#   'na',
#   '40',
#   'mil',
#   '##iard',
#   'kor',
#   '##un'],
#  ['Sp',
#   '##olu',
#   '##pr',
#   '##áce',
#   'fina',
#   '##nční',
#   '##ch',
#   'skupin',
#   'v',
#   '##y',
#   '##šla',
#   'zhruba',
#   'na',
#   '30',
#   ',',
#   '2',
#   'mil',
#   '##iard',
#   'kor',
#   '##un'],
#  ['Do',
#   '##hoda',
#   'přes',
#   '##áhl',
#   '##a',
#   'tři',
#   '##cet',
#   'mil',
#   '##iard',
#   'kor',
#   '##un'],
#  ['So',
#   '##upe',
#   '##ření',
#   'ins',
#   '##tit',
#   '##uc',
#   '##í',
#   'v',
#   '##yšlo',
#   'ka',
#   '##ž',
#   '##dou',
#   'z',
#   'fire',
#   '##m',
#   'zhruba',
#   'na',
#   '30',
#   ',',
#   '2',
#   'mil',
#   '##iard',
#   'kor',
#   '##un'],
#  ...]

# %%
wordpieces = []
for sample in SAMPLES:
    wordpieces.append([tokenizer.tokenize(claim.rstrip('.')) 
                       for claim in sample['claim'] if isinstance(claim, str)])

# %%
# for simplicity use bigrams variable for wordpieces
bigrams = wordpieces

# %% [markdown]
# ## Cue Applicability =  the absolute number of claims in the dataset that contain the cue irrespective of their label = v kolika claimech je cue pritomna

# %%
# all data
tmp = []
for ii in [set(i) for i in unigrams_all]:
    tmp += ii
applicability_uni_all = Counter(tmp)

tmp = []
for ii in [set(i) for i in bigrams_all]:
    tmp += ii
applicability_big_all = Counter(tmp)


# per samples / k-fold cross validation like
applicability_uni = []
for u in unigrams:
    tmp = []
    for ii in [set(i) for i in u]:
        tmp += ii
    applicability_uni.append(Counter(tmp))

applicability_big = []
for b in bigrams:
    tmp = []
    for ii in [set(i) for i in b]:
        tmp += ii
    applicability_big.append(Counter(tmp))

# %%
applicability_uni[0]
# Out:
# Counter({'nižší': 2,
#          'v': 185,
#          'Internetový': 2,
#          'se': 88,
#          'srovnání': 3,
#          'západní': 4,
#          'Evropou': 3,
#          've': 31,
#          'obchod': 4,
#          'je': 61,
#          'ČR': 10,
#          'bude': 21,
#          'parlamentu': 5,
#          'dětského': 1,
#          'městským': 1,
#          '25': 1,
#          'nápomocno': 1,
#          'radním': 1,
#          'členů': 1,
#          'Postoloprtech': 3,
#          'zachraňuje': 5,
#          'kapli': 7,
#          'Radnice': 11,
#          'místní': 2,
#          'od': 14,
#          'pořádá': 2,
#          '1960': 1,
#          'Festival': 2,
#          'roku': 19,
#          'tradičně': 1,
#          'filmů': 4,
#          'amatérských': 1,
#          'dále': 1,
#          'dobré': 1,
#          'zůstat': 1,
#          'Když': 3,
#          'předešlé': 1,
#          'objeví': 3,
#          'z': 44,
#          'přehřátí,': 3,
#          'horku': 3,
#          'věnovat': 1,
#          'aktivitě': 2,
#          'a': 43,
#          'křeče': 5,
#          'použití': 1,
#          'systém': 1,
#          'podle': 1,
#          'plně': 1,
#          'NATO': 4,
#          'k': 17,
#          'Slovenska': 2,
#          'Zuzana': 3,
#          'způsobilý': 1,
#          'rámci': 1,
#          'Zbraňový': 1,
#          '2': 2,
#          'Ivaščenka': 2,
#          'na': 71,
#          'podmínku': 2,
#          'exministra': 4,
#          'změnil': 1,
#          'Odvolací': 5,
#          'Kyjevě': 2,
#          'soud': 5,
#          'trest': 5,
#          'obrany': 3,
#          'roční': 2,
#          'František': 4,
#          'peněz': 6,
#          'ukradl': 2,
#          '2007': 5,
#          'roce': 25,
#          'Procházka': 4,
#          'hodně': 2,
#          'kandidáta': 1,
#          'průzkumů': 1,
#          'Podle': 14,
#          '27,7': 1,
#          'voličů': 6,
#          'procenta': 4,
#          'volebních': 1,
#          'pro': 19,
#          'hlasovat': 2,
#          'svobodu': 1,
#          'vězněného': 1,
#          'propustil': 4,
#          'Nigérii': 1,
#          'ukrýval': 1,
#          'diktátor': 1,
#          'Bývalý': 11,
#          'liberijský': 1,
#          'představitelé': 2,
#          'sejdou': 1,
#          'pražském': 1,
#          'V': 71,
#          'Evropské': 6,
#          'Světové': 3,
#          'Hilton': 1,
#          'plavecké': 5,
#          'federace': 5,
#          'hotelu': 2,
#          'výlet': 2,
#          'propagandou': 2,
#          'poznamenány': 2,
#          '1961': 2,
#          'Neználek': 2,
#          'města': 6,
#          'jsou': 16,
#          'Neználkův': 2,
#          'komunistickou': 2,
#          'do': 17,
#          '1968': 2,
#          'Slunečního': 2,
#          'Knihy': 2,
#          'Měsíci': 2,
#          'jsme': 1,
#          'mohli': 1,
#          'hrozných': 1,
#          'vidět': 2,
#          'jeho': 3,
#          'dříve': 1,
#          'Osm': 1,
#          'webových': 1,
#          'Na': 10,
#          'film': 5,
#          'než': 24,
#          'stránkách': 1,
#          'premiéře': 1,
#          'zákon': 3,
#          'téměř': 3,
#          'vstoupil': 2,
#          'lety': 3,
#          '10': 1,
#          'Před': 4,
#          'Maďarsku': 1,
#          'mediální': 2,
#          'činnost': 1,
#          'upravující': 1,
#          'platnost': 2,
#          'Jozef': 3,
#          'byl': 19,
#          'za': 25,
#          'popraven': 2,
#          'Tiso': 3,
#          'zločiny': 2,
#          'přehřátí': 7,
#          'může': 2,
#          'horkém': 3,
#          'organismu': 3,
#          'vyčerpáním': 2,
#          'nebo': 2,
#          'nastat': 2,
#          'doprovázené': 2,
#          'křečemi': 2,
#          'počasí': 3,
#          'cestu': 1,
#          'svou': 1,
#          '2009': 1,
#          'sprna': 1,
#          'neodcestoval': 1,
#          'prezident': 23,
#          'Maďarský': 1,
#          'soukromou': 1,
#          '21': 1,
#          'Sólyom': 1,
#          'Lulek': 1,
#          'republice': 8,
#          'Posledním': 1,
#          'Vladimír': 1,
#          'popravným': 1,
#          'České': 18,
#          'chystá': 3,
#          'případě': 2,
#          'šetření': 1,
#          'zahájit': 1,
#          'OSN': 11,
#          'potřeby': 1,
#          'Izraele': 1,
#          'hrozbu': 2,
#          'strany': 3,
#          'útoku': 2,
#          'ze': 3,
#          'nepovažuje': 2,
#          'pravděpodobnou': 2,
#          'Írán': 4,
#          'Evropě': 4,
#          'USA': 4,
#          'oproti': 1,
#          'Zásilkový': 2,
#          'zaostává': 2,
#          'Mladé': 2,
#          'divadlo': 6,
#          'Přehlídka': 6,
#          'pokračovala': 4,
#          'Praze': 21,
#          'divadla': 2,
#          'Městského': 1,
#          'Boleslavi': 2,
#          'hostováním': 3,
#          'vody': 4,
#          'skladování': 1,
#          'Rybníky': 2,
#          'nádrže': 2,
#          'vodní': 2,
#          'horší': 1,
#          'Agrofert': 4,
#          '100.000': 1,
#          'symbolický': 1,
#          'Matula': 5,
#          'navrhoval': 5,
#          'korun': 12,
#          'Pro': 1,
#          'snižování': 3,
#          'plynů': 2,
#          'protokol': 2,
#          'nefunguje': 2,
#          'emisí': 2,
#          'o': 20,
#          'kanadského': 1,
#          'politika': 4,
#          'skleníkových': 2,
#          'Rasmussen': 2,
#          'Fogh': 2,
#          'premiér': 10,
#          'být': 2,
#          'EU': 5,
#          'tajemníkem': 2,
#          'Anders': 2,
#          'generálním': 2,
#          'Dánský': 2,
#          'chce': 5,
#          'Fremach': 5,
#          'odběratelem': 1,
#          'automobilový': 1,
#          'firmy': 8,
#          'průmysl': 1,
#          'Morava': 5,
#          'Kroměříže': 1,
#          'Hlavním': 1,
#          'novou': 1,
#          'Španělská': 1,
#          'banka': 2,
#          'Santander': 6,
#          'švýcarská': 1,
#          'pojišťovna': 5,
#          'uzavřely': 1,
#          'dohodu': 1,
#          'Zurich': 9,
#          'Astrid': 13,
#          'Bullerbynu': 1,
#          'napsala': 1,
#          'Děti': 1,
#          'Švédka': 3,
#          'Lindgrenová': 12,
#          'převozu': 4,
#          'při': 23,
#          'Muslimského': 3,
#          'příznivců': 6,
#          'Africe': 1,
#          'zemřelo': 4,
#          'bratrstva': 3,
#          '37': 5,
#          'vězení': 4,
#          'národní': 1,
#          'TOP09': 1,
#          'viceguvernér': 1,
#          'Evropského': 1,
#          'kandidátku': 1,
#          'Luděk': 2,
#          'povede': 1,
#          'banky': 2,
#          'Niedermayer': 2,
#          'teplotách': 1,
#          'vysokých': 1,
#          'dochází': 1,
#          'Při': 1,
#          'větších': 1,
#          'těžších': 1,
#          'stále': 6,
#          'Ruzyně': 3,
#          'zaznamenává': 1,
#          'Letiště': 1,
#          'letadel': 2,
#          'výskyt': 1,
#          'napětí': 2,
#          'maďarským': 3,
#          'vztazích': 2,
#          'slovenským': 2,
#          'Roste': 2,
#          'mezi': 7,
#          'prezidentem': 2,
#          'čínského': 1,
#          'ostrova': 1,
#          'městem': 2,
#          'hlavním': 8,
#          'Tchaj-pej': 1,
#          'Noam': 3,
#          'lingvistiky': 3,
#          'technologickém': 1,
#          'institutu': 2,
#          'profesorem': 3,
#          'emeritním': 1,
#          'Chomsky': 5,
#          'Massachusettském': 1,
#          'Spojených': 1,
#          'státech': 1,
#          'latinskoamerickému': 1,
#          'obchodu': 2,
#          'Pojišťovna': 5,
#          'díky': 4,
#          'mít': 4,
#          's': 18,
#          'dohodě': 1,
#          'bankou': 3,
#          'přístup': 2,
#          'syna': 2,
#          'měla': 4,
#          'Sochař': 2,
#          'Gabriel': 4,
#          'Prahu': 2,
#          'vytvoří': 2,
#          'sochu': 4,
#          'Freuda': 5,
#          'komorou': 2,
#          'Senát': 5,
#          '70%': 3,
#          'bylo': 6,
#          'Fiat': 2,
#          'montovnách': 1,
#          'vyrobeno': 3,
#          'vozů': 3,
#          'polských': 1,
#          'všech': 4,
#          '126': 2,
#          'Přes': 2,
#          'George': 1,
#          'uvažuje': 1,
#          'Bush': 1,
#          'volbách': 3,
#          'změnách': 1,
#          'personálních': 1,
#          'svém': 3,
#          'kabinetu': 1,
#          'po': 9,
#          'dezolátním': 3,
#          'město': 9,
#          'stavu': 4,
#          'že': 19,
#          '1841': 5,
#          'nechá': 3,
#          'starostka': 6,
#          'Postoloprtská': 6,
#          'prohlásila,': 6,
#          'de': 3,
#          'pochodu': 5,
#          'lidé': 7,
#          'Santiagu': 3,
#          'demonstrovali': 6,
#          'Chile': 4,
#          'mírovém': 5,
#          'volat': 1,
#          'Pokud': 2,
#          'praktickému': 1,
#          'lékaři': 2,
#          'hodiny': 1,
#          'neustoupí,': 1,
#          'nutno': 2,
#          'republika': 2,
#          'situací': 1,
#          'Česká': 10,
#          'krizovou': 2,
#          'vypořádat': 1,
#          'Česko': 6,
#          'snadněji': 2,
#          'čerpat': 2,
#          'evropské': 2,
#          'dotace': 2,
#          'praktičtí': 1,
#          'ledna': 1,
#          '18': 1,
#          'Německu': 1,
#          'svůj': 3,
#          'mandát': 1,
#          'Irácký': 1,
#          'Aláví': 1,
#          'Ajád': 1,
#          'obhájit': 1,
#          'Žulawski': 10,
#          'zemřel': 15,
#          'Andrzej': 9,
#          'Pardubickém': 4,
#          'první': 9,
#          'člověk': 4,
#          'kraji': 6,
#          'metanolem': 4,
#          'otravu': 2,
#          'Mradicích': 1,
#          'čeká': 1,
#          'renovace': 1,
#          'Kapli': 1,
#          'španělská': 1,
#          'nové': 6,
#          'Latinské': 2,
#          'společné': 4,
#          'Švýcarská': 1,
#          'podnikání': 5,
#          'Americe': 5,
#          'představily': 4,
#          'Bühler': 7,
#          'miliónů': 4,
#          'Králové': 12,
#          'Hradci': 13,
#          'výrobní': 3,
#          'halu': 3,
#          '90': 6,
#          'Společnost': 5,
#          'otevřela': 2,
#          'Motor': 7,
#          'uskutečnil': 5,
#          'vojenský': 5,
#          'zabit': 5,
#          'převrat,': 5,
#          'kterém': 5,
#          'Augusto': 6,
#          'Pinochet': 5,
#          'španělského': 3,
#          'hlasovalo': 2,
#          'procent': 2,
#          'regionu': 1,
#          'nezávislost': 1,
#          'Přibližně': 2,
#          'střediska': 3,
#          'Ředitelem': 3,
#          'Jiří': 4,
#          'Krkonoších': 1,
#          'Beran': 1,
#          'lyžařského': 1,
#          'ocenění': 2,
#          'státní': 1,
#          'Kundera': 1,
#          'Milan': 1,
#          'dostal': 3,
#          'Kocianovo': 2,
#          'cenu': 5,
#          'získalo': 2,
#          'kvarteto': 2,
#          'Donald': 2,
#          'Předseda': 2,
#          'instituce': 1,
#          'Tusk': 2,
#          'Diplomatické': 3,
#          'zeměmi': 1,
#          'asijskými': 1,
#          'dvěma': 1,
#          'nebyly': 3,
#          'ideální': 2,
#          'vztahy': 3,
#          'vyloučeny': 4,
#          'Třebíči': 6,
#          'Záplavy': 4,
#          'funkci': 2,
#          'proti,': 1,
#          'vykonával': 1,
#          'ústavního': 2,
#          'soudce': 2,
#          'aby': 4,
#          'státu': 1,
#          'figurují': 1,
#          'Bývalí': 1,
#          'řízení': 2,
#          'soudním': 1,
#          'zmizeli': 1,
#          'zoo': 1,
#          'jihlavské': 1,
#          'víkendu': 1,
#          'O': 1,
#          'zlatí': 1,
#          'dva': 4,
#          'kaloni': 1,
#          'území': 4,
#          'vstup': 2,
#          'gruzínský': 2,
#          'Ukrajiny': 2,
#          'má': 10,
#          'Někdejší': 1,
#          'zakázaný': 2,
#          'žije': 3,
#          'Tchaj-wanu': 2,
#          'neobyčejně': 1,
#          'obyvatel': 7,
#          'mnoho': 2,
#          'Sovětském': 1,
#          'rozpadat': 1,
#          'východního': 1,
#          'začaly': 1,
#          'zemí': 2,
#          'svazu': 1,
#          'let': 4,
#          'režimy': 1,
#          'bloku,': 1,
#          'osmdesátých': 1,
#          'konci': 1,
#          'závislých': 1,
#          'základny': 10,
#          'protiraketové': 10,
#          'Umístění': 9,
#          'odmítá': 8,
#          'většina': 8,
#          'Poláků': 2,
#          'Polsku': 18,
#          'americké': 14,
#          'režíruje': 1,
#          'seriály': 1,
#          'Quentin': 1,
#          'televizní': 2,
#          'pouze': 3,
#          'Tarantino': 2,
#          'Moravou': 2,
#          'Řekou': 2,
#          'protéká': 2,
#          'méně': 6,
#          'varoval': 1,
#          'před': 5,
#          'Václav': 6,
#          'Havel': 3,
#          'Ruské': 2,
#          'ústupky': 1,
#          'federaci': 1,
#          'zakázali': 2,
#          'potraty': 2,
#          'jmenuje': 2,
#          'Jednatel': 2,
#          'Christof': 2,
#          'Furtwängler': 2,
#          'studia': 4,
#          'uvedla': 3,
#          '2002': 4,
#          '15': 3,
#          'pokračování': 4,
#          'Hollywoodská': 4,
#          'filmových': 2,
#          'zaměří': 1,
#          'spolupráci': 1,
#          'služeb': 1,
#          'finančních': 2,
#          'nabídku': 1,
#          'milion': 3,
#          'cestujících': 2,
#          'pražské': 2,
#          'více': 14,
#          'odbavilo': 3,
#          'letiště': 3,
#          'poprvé': 7,
#          'červenci': 3,
#          'nejezdil': 1,
#          'Slovenský': 4,
#          'den': 3,
#          'vojsk': 3,
#          'smlouvy': 4,
#          'Bratislavy': 1,
#          'vpádu': 3,
#          'Varšavské': 3,
#          'maďarský': 3,
#          'protějšek,': 2,
#          'výročí': 3,
#          'vyzval': 4,
#          'Nejen': 2,
#          'Lidovci': 2,
#          'Tomia': 7,
#          'volají': 4,
#          'místopředsedy': 7,
#          'pozice': 7,
#          'Okamury': 7,
#          'Sněmovny': 4,
#          'odvolání': 7,
#          'vlastní': 1,
#          'Hradec': 2,
#          'Národnímu': 2,
#          'miliony': 3,
#          'Mecenášové': 1,
#          'darovali': 3,
#          'přes': 5,
#          'divadlu': 1,
#          'vystavuje': 4,
#          'instalací': 2,
#          'Autor': 2,
#          'galerii': 6,
#          'audiovizuálních': 2,
#          'obrněných': 4,
#          'vozidel': 2,
#          'osmnáctitunových': 4,
#          '500': 5,
#          'Stryker': 1,
#          'vojáky': 4,
#          'Humvee': 1,
#          'americkými': 3,
#          'dorazilo': 3,
#          'terénních': 1,
#          'Do': 7,
#          '115': 4,
#          'politik': 3,
#          'amerického': 1,
#          'švýcarské': 2,
#          'kontinentu': 1,
#          'skupině': 2,
#          'pojišťovnou': 1,
#          'jižně': 1,
#          'trhům': 1,
#          'Dohoda': 2,
#          'umožní': 1,
#          'hrozí': 5,
#          'lidem': 1,
#          'vyčerpání': 1,
#          'Křeče': 4,
#          'mimopražských': 1,
#          'regionálních': 1,
#          'divadel': 1,
#          'českých': 1,
#          'červnu': 2,
#          '1989': 2,
#          'kterým': 1,
#          'Svitek': 1,
#          'Československu': 1,
#          'Štefan': 1,
#          'Bratislavě': 1,
#          'posledního': 2,
#          'vraha,': 1,
#          'popravili': 2,
#          'Freudových': 2,
#          'květen': 1,
#          'odhalení': 3,
#          'plánuje': 6,
#          '151': 3,
#          'příštího': 1,
#          'oslav': 1,
#          'příležitosti': 4,
#          'plácku': 2,
#          'Kozím': 2,
#          'sochy': 4,
#          'Sigmunda': 3,
#          'Oficiální': 1,
#          'tedy': 1,
#          'narozenin': 4,
#          'roku,': 1,
#          'Tisa': 1,
#          'zdravotnictví': 3,
#          'visí': 2,
#          'ministerstva': 3,
#          'portrét': 2,
#          'slovenského': 2,
#          'Jozefa': 1,
#          'budově': 3,
#          'Režisér': 4,
#          'kontroverzních': 1,
#          'Varšavě': 2,
#          'otrávil': 3,
#          'Národní': 1,
#          'dary,': 1,
#          'finanční': 1,
#          'které': 5,
#          'přesahovaly': 1,
#          '2016': 1,
#          'obdrželo': 1,
#          'umění': 7,
#          'Od': 1,
#          'pěněžitou': 2,
#          'újmu': 2,
#          'Nejmírnější': 2,
#          '10000': 5,
#          'republiky': 4,
#          'městě': 9,
#          'uskutečnilo': 3,
#          'demonstrací': 3,
#          '2008': 10,
#          'Kaloňům': 1,
#          'dvě': 1,
#          'narodila': 1,
#          'zlatým': 1,
#          'mláďata': 1,
#          'ligy': 1,
#          'Mezinárodní': 2,
#          'nezúčastnil': 2,
#          'ceny': 2,
#          'humanistů': 1,
#          'předání': 1,
#          'sídle': 1,
#          'Spojeného': 1,
#          'království': 2,
#          'unie': 4,
#          'vztah': 3,
#          'definovat': 1,
#          'Nicolas': 3,
#          'Sarkozy': 3,
#          'počet': 6,
#          'Francie': 1,
#          'cizinců,': 1,
#          'ochotna': 1,
#          'přijmout': 1,
#          'Prezident': 7,
#          'omezit': 1,
#          'otravě': 1,
#          'podlehlo': 1,
#          'lidí': 6,
#          '23': 2,
#          'Česku': 5,
#          'začnou': 1,
#          'ropným': 3,
#          'předpokladů': 3,
#          'proti': 9,
#          'Iráku': 4,
#          'zařízením': 3,
#          'sabotáže': 2,
#          'soupeřů': 1,
#          '17': 1,
#          'Novák': 1,
#          'porazil': 2,
#          'výběrovém': 1,
#          'představení': 2,
#          'naplánováno': 1,
#          'slavnostní': 2,
#          'K': 1,
#          'řádech': 1,
#          'Odklon': 1,
#          'milionů': 6,
#          'dopravy': 2,
#          'zavinil': 1,
#          'škodu': 1,
#          'nepožaduje': 3,
#          'Nikdo': 3,
#          'koná': 3,
#          'slezském': 2,
#          'Květinová': 2,
#          'slavnost': 2,
#          '1973': 3,
#          'pravidelně': 2,
#          'Havířově': 3,
#          'Všeobecné': 1,
#          'hrozí,': 1,
#          'odvolán': 1,
#          'Šéfovi': 1,
#          'pojišťovny': 2,
#          'zdravotní': 1,
#          'Horákovi': 1,
#          'Pavlu': 1,
#          'Evo': 3,
#          'země': 7,
#          'stojí': 4,
#          'deset': 1,
#          'Morales': 5,
#          'Bolívie': 1,
#          'své': 13,
#          'čele': 1,
#          'už': 3,
#          'vodních': 1,
#          'menší': 3,
#          'nádrží': 1,
#          'objem': 1,
#          'rybníků': 1,
#          'Objem': 1,
#          'černošskému': 2,
#          'brutálně': 2,
#          'Kingovi,': 1,
#          'kteří': 2,
#          '14': 3,
#          'zasáhli': 2,
#          'Angeles,': 1,
#          '1994': 3,
#          'Rozsudek': 2,
#          'Los': 2,
#          'policistů': 2,
#          'Rodneymu': 1,
#          'května': 1,
#          'prupuštění': 2,
#          'padl': 2,
#          'motorkáři': 1,
#          'sboru': 1,
#          'začal': 2,
#          'běžce': 2,
#          'veletrh': 6,
#          'Kladno': 1,
#          'Mimo': 1,
#          'Petr': 2,
#          'Gandalovič': 1,
#          'oznámil': 4,
#          'šéfa': 1,
#          'Lesy': 1,
#          'zemědělství': 1,
#          'podniku': 1,
#          'nového': 2,
#          'Ministr': 2,
#          'státního': 1,
#          'dnes': 4,
#          'Střelec': 1,
#          'Denveru': 1,
#          'zastřelen': 1,
#          'zatýkání': 1,
#          'vyhnout': 1,
#          'slunci': 1,
#          'nutné': 2,
#          'přímém': 1,
#          'evropský': 1,
#          'Oceňovaný': 5,
#          'rakovinu': 6,
#          'režisér': 6,
#          'osamostatnění': 1,
#          'Katalánska': 1,
#          'i': 5,
#          'Okamura': 2,
#          'považuje': 1,
#          'kritiku': 1,
#          'přímé': 1,
#          'zabránit': 1,
#          'Tomio': 2,
#          'účasti': 1,
#          'němu': 1,
#          'sestavování': 1,
#          'SPD': 1,
#          'vedené': 1,
#          'součást': 1,
#          'cílem': 1,
#          'nepřímé': 1,
#          'vlády': 3,
#          'kampaně': 1,
#          'dcera': 1,
#          'byla': 10,
#          'dětí': 2,
#          'Lindgrenové': 1,
#          'Karin': 1,
#          'Jedno': 1,
#          'organizovaném': 1,
#          'vojenském': 1,
#          'Pinochetem': 1,
#          'usmrcen': 1,
#          'Salvador': 2,
#          'Allende': 2,
#          'převratu': 1,
#          'Stav': 3,
#          '2015': 4,
#          'zaměstnanců': 4,
#          'čtyři': 3,
#          'sta': 3,
#          'kroměřížské': 3,
#          'narušili': 1,
#          'mírový': 1,
#          'pochod': 1,
#          'demonstranti': 1,
#          'částečně': 1,
#          'vinu': 1,
#          'člen': 1,
#          'přiznal': 1,
#          'oteplování': 4,
#          'bezpečné': 1,
#          'netvrdil,': 1,
#          'vědec': 2,
#          'Britský': 6,
#          'Houghton': 1,
#          'planety': 4,
#          'John': 1,
#          'Oblíbenosti': 1,
#          'těší': 1,
#          'víno': 1,
#          'květnu': 1,
#          'vystavena': 5,
#          'Epopej': 7,
#          '1919': 1,
#          'Massachusetts': 1,
#          'univerzitě': 1,
#          'náboženství': 1,
#          'hlava': 1,
#          'II': 3,
#          'Jan': 5,
#          'katolické': 1,
#          'Pavel': 3,
#          'církve': 1,
#          'jiných': 1,
#          'svatostánků': 1,
#          'nepodíval': 1,
#          'jako': 3,
#          'nikdy': 1,
#          'konala': 1,
#          'Slavnost': 1,
#          'květin': 1,
#          'Oscar': 5,
#          'není': 1,
#          'Espinosa': 5,
#          'již': 1,
#          'Chepe': 9,
#          'živými': 1,
#          'disident': 9,
#          'Kubánský': 2,
#          'španělské': 1,
#          'rychle': 1,
#          'trhy': 1,
#          'kapitál': 1,
#          'další': 1,
#          'zpřístupní': 1,
#          'Spolupráce': 1,
#          'rostoucí': 1,
#          'instituci': 1,
#          'akvizice': 1,
#          'Moderního': 5,
#          'výstava': 7,
#          'minimalismu': 2,
#          'začíná': 5,
#          'Tematická': 5,
#          'Ostravě': 2,
#          'Galerii': 5,
#          'měří': 3,
#          'meteorologické': 1,
#          'Rekordní': 3,
#          'stanici': 1,
#          'teploty': 3,
#          '1775': 3,
#          '1235': 1,
#          'bitvě': 1,
#          'vojáků': 1,
#          'zahynulo': 1,
#          'civilistů': 1,
#          'zabito': 1,
#          '20': 2,
#          'zbraň': 2,
#          'ničení': 4,
#          'pokládá': 1,
#          'hromadného': 4,
#          'opravena': 4,
#          'kaple': 10,
#          'jiné': 2,
#          'Kaloni': 1,
#          'netopýři': 1,
#          'mají': 4,
#          'vlastnosti': 1,
#          'zabavila': 2,
#          'drog': 1,
#          'Armáda': 1,
#          'velké': 1,
#          'množství': 1,
#          'existuje': 3,
#          'společnost': 10,
#          'Učená': 7,
#          'ke': 3,
#          'Díky': 3,
#          'nedošlo': 2,
#          'škodám': 1,
#          'protipovodňovým': 1,
#          'opatřením': 1,
#          'gymnastice': 1,
#          'mistrovství': 3,
#          'zúčastní': 1,
#          'Konečný': 4,
#          'Martin': 4,
#          'Evropy': 5,
#          'Gymnasta': 4,
#          'žízeň': 1,
#          'Ostrava': 3,
#          'kouření': 2,
#          'ArcelorMittal': 3,
#          'u': 5,
#          'odvykání': 2,
#          'svých': 1,
#          'finančně': 1,
#          'podpoří': 3,
#          'Největší': 2,
#          'hutní': 1,
#          'závislé': 1,
#          'zaměstnance': 1,
#          'ukrajinkského': 1,
#          'Polska': 3,
#          'Ruský': 1,
#          'plynovody': 1,
#          'plynárenský': 1,
#          'gigant': 1,
#          'Gazprom': 1,
#          'zavede': 1,
#          'Polský': 3,
#          'zastánci': 1,
#          'umístění': 3,
#          'Egyptě': 3,
#          'Talibánu': 2,
#          'počtvrté': 3,
#          'Latinskoamerický': 2,
#          'kandidovat': 5,
#          'kubánský': 7,
#          'Španělska': 1,
#          'Richard': 4,
#          'Loskot': 4,
#          'východních': 2,
#          'Čechách': 2,
#          'Kolumbii': 2,
#          'roste': 1,
#          'Zločinnost': 1,
#          'podporují': 3,
#          'SD': 2,
#          'ČEZ': 1,
#          'soutěži': 2,
#          'Odboráři': 3,
#          'výstavě': 1,
#          'věnoval': 1,
#          'Bučovický': 1,
#          'restaurování': 2,
#          ...})

# %% [markdown]
# ## Cue Productivity = is the frequency of the most common label across the claims that contain the cue = cetnost nejcastejsiho labelu pro cue
#
# Productivity in range [1/3, 1] for 3 possible labels
#
# In practical terms, the productivity is the chance that a model correctly labels a claim by assigning it the most common label of a given cue in the claim.

# %%
productivity_uni_all = []
productivity_big_all = []

productivity_uni = []
productivity_big = []

# from collections import Counter
# from itertools import islice

# def count_ngrams(iterable,n=2):
#     return Counter(zip(*[islice(iterable,i,None) for i in range(n)]))

# %%
# counts = {}
# for i, words in enumerate([set(i) for i in unigrams]):
#     for w in words:
#         if w not in counts:
#             counts[w] = {}
#         if df['label'][i] not in counts[w]:
#             counts[w][df['label'][i]] = 1
#         else:
#             counts[w][df['label'][i]] += 1

# %%
def get_max(values: dict) -> (str, int):
    label, max_count = None, 0
    for k, v in values.items():
        if v > max_count:
            max_count = v
            label = k
    return label, max_count

# %%
# all data
counts_uni_all = {}  # rozdeleni labelu pro jednotlive cues
for i, words in enumerate([set(i) for i in unigrams_all]):
    for w in words:
        if w not in counts_uni_all:
            counts_uni_all[w] = {}
        if df['label'][i] not in counts_uni_all[w]:
            counts_uni_all[w][df['label'][i]] = 1
        else:
            counts_uni_all[w][df['label'][i]] += 1
max_counts_uni_all = {k: get_max(v) for k, v in counts_uni_all.items()}

counts_big_all = {}  # rozdeleni labelu pro jednotlive cues
for i, words in enumerate([set(i) for i in bigrams_all]):
    for w in words:
        if w not in counts_big_all:
            counts_big_all[w] = {}
        if df['label'][i] not in counts_big_all[w]:
            counts_big_all[w][df['label'][i]] = 1
        else:
            counts_big_all[w][df['label'][i]] += 1
max_counts_big_all = {k: get_max(v) for k, v in counts_big_all.items()}


# per samples / k-fold cross validation like
max_counts_uni = []
for s, sample in enumerate(SAMPLES):
    counts = {}
    for i, words in enumerate([set(i) for i in unigrams[s]]):
        for w in words:
            if w not in counts:
                counts[w] = {}
            if sample['label'][i] not in counts[w]:
                counts[w][sample['label'][i]] = 1
            else:
                counts[w][sample['label'][i]] += 1
    
    max_counts_uni.append({k: get_max(v) for k, v in counts.items()})
    
max_counts_big = []
for s, sample in enumerate(SAMPLES):
    counts = {}
    for i, words in enumerate([set(i) for i in bigrams[s]]):
        for w in words:
            if w not in counts:
                counts[w] = {}
            if sample['label'][i] not in counts[w]:
                counts[w][sample['label'][i]] = 1
            else:
                counts[w][sample['label'][i]] += 1

    max_counts_big.append({k: get_max(v) for k, v in counts.items()})

# %%
max_counts_uni[0]
# Out:
# {'nižší': ('SUPPORTS', 1),
#  'v': ('SUPPORTS', 67),
#  'Internetový': ('SUPPORTS', 1),
#  'se': ('REFUTES', 33),
#  'srovnání': ('SUPPORTS', 1),
#  'západní': ('SUPPORTS', 2),
#  'Evropou': ('SUPPORTS', 1),
#  've': ('NOT ENOUGH INFO', 13),
#  'obchod': ('SUPPORTS', 2),
#  'je': ('REFUTES', 26),
#  'ČR': ('SUPPORTS', 5),
#  'bude': ('SUPPORTS', 9),
#  'parlamentu': ('SUPPORTS', 3),
#  'dětského': ('SUPPORTS', 1),
#  'městským': ('SUPPORTS', 1),
#  '25': ('SUPPORTS', 1),
#  'nápomocno': ('SUPPORTS', 1),
#  'radním': ('SUPPORTS', 1),
#  'členů': ('SUPPORTS', 1),
#  'Postoloprtech': ('REFUTES', 2),
#  'zachraňuje': ('NOT ENOUGH INFO', 4),
#  'kapli': ('REFUTES', 4),
#  'Radnice': ('NOT ENOUGH INFO', 5),
#  'místní': ('SUPPORTS', 1),
#  'od': ('SUPPORTS', 6),
#  'pořádá': ('SUPPORTS', 1),
#  '1960': ('SUPPORTS', 1),
#  'Festival': ('SUPPORTS', 1),
#  'roku': ('SUPPORTS', 8),
#  'tradičně': ('SUPPORTS', 1),
#  'filmů': ('SUPPORTS', 2),
#  'amatérských': ('SUPPORTS', 1),
#  'dále': ('SUPPORTS', 1),
#  'dobré': ('SUPPORTS', 1),
#  'zůstat': ('SUPPORTS', 1),
#  'Když': ('SUPPORTS', 2),
#  'předešlé': ('SUPPORTS', 1),
#  'objeví': ('SUPPORTS', 2),
#  'z': ('SUPPORTS', 21),
#  'přehřátí,': ('SUPPORTS', 2),
#  'horku': ('SUPPORTS', 2),
#  'věnovat': ('SUPPORTS', 1),
#  'aktivitě': ('SUPPORTS', 2),
#  'a': ('SUPPORTS', 19),
#  'křeče': ('SUPPORTS', 3),
#  'použití': ('SUPPORTS', 1),
#  'systém': ('SUPPORTS', 1),
#  'podle': ('SUPPORTS', 1),
#  'plně': ('SUPPORTS', 1),
#  'NATO': ('REFUTES', 2),
#  'k': ('REFUTES', 9),
#  'Slovenska': ('SUPPORTS', 2),
#  'Zuzana': ('REFUTES', 2),
#  'způsobilý': ('SUPPORTS', 1),
#  'rámci': ('SUPPORTS', 1),
#  'Zbraňový': ('SUPPORTS', 1),
#  '2': ('SUPPORTS', 1),
#  'Ivaščenka': ('SUPPORTS', 1),
#  'na': ('SUPPORTS', 25),
#  'podmínku': ('SUPPORTS', 1),
#  'exministra': ('SUPPORTS', 3),
#  'změnil': ('SUPPORTS', 1),
#  'Odvolací': ('SUPPORTS', 3),
#  'Kyjevě': ('SUPPORTS', 2),
#  'soud': ('SUPPORTS', 3),
#  'trest': ('SUPPORTS', 2),
#  'obrany': ('SUPPORTS', 2),
#  'roční': ('SUPPORTS', 1),
#  'František': ('SUPPORTS', 2),
#  'peněz': ('SUPPORTS', 3),
#  'ukradl': ('SUPPORTS', 2),
#  '2007': ('SUPPORTS', 3),
#  'roce': ('SUPPORTS', 11),
#  'Procházka': ('SUPPORTS', 2),
#  'hodně': ('SUPPORTS', 2),
#  'kandidáta': ('SUPPORTS', 1),
#  'průzkumů': ('SUPPORTS', 1),
#  'Podle': ('NOT ENOUGH INFO', 6),
#  '27,7': ('SUPPORTS', 1),
#  'voličů': ('SUPPORTS', 3),
#  'procenta': ('NOT ENOUGH INFO', 2),
#  'volebních': ('SUPPORTS', 1),
#  'pro': ('REFUTES', 8),
#  'hlasovat': ('SUPPORTS', 2),
#  'svobodu': ('SUPPORTS', 1),
#  'vězněného': ('SUPPORTS', 1),
#  'propustil': ('SUPPORTS', 2),
#  'Nigérii': ('SUPPORTS', 1),
#  'ukrýval': ('SUPPORTS', 1),
#  'diktátor': ('SUPPORTS', 1),
#  'Bývalý': ('REFUTES', 5),
#  'liberijský': ('SUPPORTS', 1),
#  'představitelé': ('SUPPORTS', 2),
#  'sejdou': ('SUPPORTS', 1),
#  'pražském': ('SUPPORTS', 1),
#  'V': ('SUPPORTS', 28),
#  'Evropské': ('SUPPORTS', 3),
#  'Světové': ('SUPPORTS', 2),
#  'Hilton': ('SUPPORTS', 1),
#  'plavecké': ('SUPPORTS', 2),
#  'federace': ('SUPPORTS', 2),
#  'hotelu': ('SUPPORTS', 2),
#  'výlet': ('SUPPORTS', 2),
#  'propagandou': ('SUPPORTS', 2),
#  'poznamenány': ('SUPPORTS', 2),
#  '1961': ('SUPPORTS', 2),
#  'Neználek': ('SUPPORTS', 2),
#  'města': ('SUPPORTS', 3),
#  'jsou': ('NOT ENOUGH INFO', 7),
#  'Neználkův': ('SUPPORTS', 2),
#  'komunistickou': ('SUPPORTS', 2),
#  'do': ('SUPPORTS', 10),
#  '1968': ('SUPPORTS', 2),
#  'Slunečního': ('SUPPORTS', 2),
#  'Knihy': ('SUPPORTS', 2),
#  'Měsíci': ('SUPPORTS', 2),
#  'jsme': ('SUPPORTS', 1),
#  'mohli': ('SUPPORTS', 1),
#  'hrozných': ('SUPPORTS', 1),
#  'vidět': ('SUPPORTS', 1),
#  'jeho': ('SUPPORTS', 2),
#  'dříve': ('SUPPORTS', 1),
#  'Osm': ('SUPPORTS', 1),
#  'webových': ('SUPPORTS', 1),
#  'Na': ('SUPPORTS', 4),
#  'film': ('REFUTES', 3),
#  'než': ('SUPPORTS', 10),
#  'stránkách': ('SUPPORTS', 1),
#  'premiéře': ('SUPPORTS', 1),
#  'zákon': ('NOT ENOUGH INFO', 2),
#  'téměř': ('NOT ENOUGH INFO', 2),
#  'vstoupil': ('SUPPORTS', 1),
#  'lety': ('NOT ENOUGH INFO', 2),
#  '10': ('SUPPORTS', 1),
#  'Před': ('NOT ENOUGH INFO', 2),
#  'Maďarsku': ('SUPPORTS', 1),
#  'mediální': ('SUPPORTS', 1),
#  'činnost': ('SUPPORTS', 1),
#  'upravující': ('SUPPORTS', 1),
#  'platnost': ('SUPPORTS', 1),
#  'Jozef': ('REFUTES', 2),
#  'byl': ('SUPPORTS', 11),
#  'za': ('REFUTES', 11),
#  'popraven': ('SUPPORTS', 1),
#  'Tiso': ('REFUTES', 2),
#  'zločiny': ('SUPPORTS', 1),
#  'přehřátí': ('SUPPORTS', 4),
#  'může': ('SUPPORTS', 2),
#  'horkém': ('SUPPORTS', 3),
#  'organismu': ('SUPPORTS', 3),
#  'vyčerpáním': ('SUPPORTS', 2),
#  'nebo': ('SUPPORTS', 2),
#  'nastat': ('SUPPORTS', 2),
#  'doprovázené': ('SUPPORTS', 2),
#  'křečemi': ('SUPPORTS', 2),
#  'počasí': ('SUPPORTS', 3),
#  'cestu': ('SUPPORTS', 1),
#  'svou': ('SUPPORTS', 1),
#  '2009': ('SUPPORTS', 1),
#  'sprna': ('SUPPORTS', 1),
#  'neodcestoval': ('SUPPORTS', 1),
#  'prezident': ('REFUTES', 9),
#  'Maďarský': ('SUPPORTS', 1),
#  'soukromou': ('SUPPORTS', 1),
#  '21': ('SUPPORTS', 1),
#  'Sólyom': ('SUPPORTS', 1),
#  'Lulek': ('SUPPORTS', 1),
#  'republice': ('NOT ENOUGH INFO', 5),
#  'Posledním': ('SUPPORTS', 1),
#  'Vladimír': ('SUPPORTS', 1),
#  'popravným': ('SUPPORTS', 1),
#  'České': ('SUPPORTS', 7),
#  'chystá': ('SUPPORTS', 1),
#  'případě': ('SUPPORTS', 1),
#  'šetření': ('SUPPORTS', 1),
#  'zahájit': ('SUPPORTS', 1),
#  'OSN': ('REFUTES', 7),
#  'potřeby': ('SUPPORTS', 1),
#  'Izraele': ('SUPPORTS', 1),
#  'hrozbu': ('SUPPORTS', 2),
#  'strany': ('SUPPORTS', 2),
#  'útoku': ('SUPPORTS', 2),
#  'ze': ('SUPPORTS', 2),
#  'nepovažuje': ('SUPPORTS', 2),
#  'pravděpodobnou': ('SUPPORTS', 2),
#  'Írán': ('SUPPORTS', 2),
#  'Evropě': ('SUPPORTS', 2),
#  'USA': ('SUPPORTS', 3),
#  'oproti': ('SUPPORTS', 1),
#  'Zásilkový': ('SUPPORTS', 1),
#  'zaostává': ('SUPPORTS', 1),
#  'Mladé': ('SUPPORTS', 2),
#  'divadlo': ('SUPPORTS', 3),
#  'Přehlídka': ('SUPPORTS', 3),
#  'pokračovala': ('SUPPORTS', 3),
#  'Praze': ('NOT ENOUGH INFO', 8),
#  'divadla': ('SUPPORTS', 1),
#  'Městského': ('SUPPORTS', 1),
#  'Boleslavi': ('SUPPORTS', 2),
#  'hostováním': ('SUPPORTS', 3),
#  'vody': ('SUPPORTS', 2),
#  'skladování': ('SUPPORTS', 1),
#  'Rybníky': ('SUPPORTS', 1),
#  'nádrže': ('SUPPORTS', 1),
#  'vodní': ('SUPPORTS', 1),
#  'horší': ('SUPPORTS', 1),
#  'Agrofert': ('SUPPORTS', 2),
#  '100.000': ('SUPPORTS', 1),
#  'symbolický': ('SUPPORTS', 1),
#  'Matula': ('SUPPORTS', 2),
#  'navrhoval': ('SUPPORTS', 2),
#  'korun': ('SUPPORTS', 8),
#  'Pro': ('SUPPORTS', 1),
#  'snižování': ('SUPPORTS', 2),
#  'plynů': ('SUPPORTS', 1),
#  'protokol': ('SUPPORTS', 1),
#  'nefunguje': ('SUPPORTS', 1),
#  'emisí': ('SUPPORTS', 1),
#  'o': ('REFUTES', 9),
#  'kanadského': ('SUPPORTS', 1),
#  'politika': ('SUPPORTS', 3),
#  'skleníkových': ('SUPPORTS', 1),
#  'Rasmussen': ('SUPPORTS', 1),
#  'Fogh': ('SUPPORTS', 1),
#  'premiér': ('REFUTES', 4),
#  'být': ('SUPPORTS', 1),
#  'EU': ('SUPPORTS', 2),
#  'tajemníkem': ('SUPPORTS', 1),
#  'Anders': ('SUPPORTS', 1),
#  'generálním': ('SUPPORTS', 1),
#  'Dánský': ('SUPPORTS', 1),
#  'chce': ('SUPPORTS', 3),
#  'Fremach': ('SUPPORTS', 3),
#  'odběratelem': ('SUPPORTS', 1),
#  'automobilový': ('SUPPORTS', 1),
#  'firmy': ('SUPPORTS', 5),
#  'průmysl': ('SUPPORTS', 1),
#  'Morava': ('SUPPORTS', 3),
#  'Kroměříže': ('SUPPORTS', 1),
#  'Hlavním': ('SUPPORTS', 1),
#  'novou': ('SUPPORTS', 1),
#  'Španělská': ('SUPPORTS', 1),
#  'banka': ('SUPPORTS', 2),
#  'Santander': ('SUPPORTS', 6),
#  'švýcarská': ('SUPPORTS', 1),
#  'pojišťovna': ('SUPPORTS', 2),
#  'uzavřely': ('SUPPORTS', 1),
#  'dohodu': ('SUPPORTS', 1),
#  'Zurich': ('SUPPORTS', 6),
#  'Astrid': ('SUPPORTS', 6),
#  'Bullerbynu': ('SUPPORTS', 1),
#  'napsala': ('SUPPORTS', 1),
#  'Děti': ('SUPPORTS', 1),
#  'Švédka': ('SUPPORTS', 3),
#  'Lindgrenová': ('SUPPORTS', 5),
#  'převozu': ('SUPPORTS', 2),
#  'při': ('SUPPORTS', 13),
#  'Muslimského': ('REFUTES', 2),
#  'příznivců': ('SUPPORTS', 3),
#  'Africe': ('SUPPORTS', 1),
#  'zemřelo': ('SUPPORTS', 2),
#  'bratrstva': ('REFUTES', 2),
#  '37': ('REFUTES', 3),
#  'vězení': ('SUPPORTS', 2),
#  'národní': ('SUPPORTS', 1),
#  'TOP09': ('SUPPORTS', 1),
#  'viceguvernér': ('SUPPORTS', 1),
#  'Evropského': ('SUPPORTS', 1),
#  'kandidátku': ('SUPPORTS', 1),
#  'Luděk': ('SUPPORTS', 1),
#  'povede': ('SUPPORTS', 1),
#  'banky': ('SUPPORTS', 2),
#  'Niedermayer': ('SUPPORTS', 1),
#  'teplotách': ('SUPPORTS', 1),
#  'vysokých': ('SUPPORTS', 1),
#  'dochází': ('SUPPORTS', 1),
#  'Při': ('SUPPORTS', 1),
#  'větších': ('SUPPORTS', 1),
#  'těžších': ('SUPPORTS', 1),
#  'stále': ('REFUTES', 4),
#  'Ruzyně': ('SUPPORTS', 2),
#  'zaznamenává': ('SUPPORTS', 1),
#  'Letiště': ('SUPPORTS', 1),
#  'letadel': ('SUPPORTS', 1),
#  'výskyt': ('SUPPORTS', 1),
#  'napětí': ('SUPPORTS', 1),
#  'maďarským': ('SUPPORTS', 1),
#  'vztazích': ('SUPPORTS', 1),
#  'slovenským': ('SUPPORTS', 1),
#  'Roste': ('SUPPORTS', 1),
#  'mezi': ('SUPPORTS', 4),
#  'prezidentem': ('SUPPORTS', 1),
#  'čínského': ('SUPPORTS', 1),
#  'ostrova': ('SUPPORTS', 1),
#  'městem': ('SUPPORTS', 1),
#  'hlavním': ('SUPPORTS', 6),
#  'Tchaj-pej': ('SUPPORTS', 1),
#  'Noam': ('SUPPORTS', 1),
#  'lingvistiky': ('SUPPORTS', 2),
#  'technologickém': ('SUPPORTS', 1),
#  'institutu': ('SUPPORTS', 1),
#  'profesorem': ('SUPPORTS', 2),
#  'emeritním': ('SUPPORTS', 1),
#  'Chomsky': ('SUPPORTS', 2),
#  'Massachusettském': ('SUPPORTS', 1),
#  'Spojených': ('SUPPORTS', 1),
#  'státech': ('SUPPORTS', 1),
#  'latinskoamerickému': ('SUPPORTS', 1),
#  'obchodu': ('SUPPORTS', 1),
#  'Pojišťovna': ('SUPPORTS', 2),
#  'díky': ('SUPPORTS', 3),
#  'mít': ('REFUTES', 2),
#  's': ('REFUTES', 9),
#  'dohodě': ('SUPPORTS', 1),
#  'bankou': ('SUPPORTS', 3),
#  'přístup': ('SUPPORTS', 2),
#  'syna': ('SUPPORTS', 2),
#  'měla': ('SUPPORTS', 3),
#  'Sochař': ('SUPPORTS', 2),
#  'Gabriel': ('SUPPORTS', 2),
#  'Prahu': ('SUPPORTS', 2),
#  'vytvoří': ('SUPPORTS', 2),
#  'sochu': ('SUPPORTS', 2),
#  'Freuda': ('SUPPORTS', 4),
#  'komorou': ('SUPPORTS', 1),
#  'Senát': ('SUPPORTS', 2),
#  '70%': ('SUPPORTS', 1),
#  'bylo': ('SUPPORTS', 2),
#  'Fiat': ('SUPPORTS', 1),
#  'montovnách': ('SUPPORTS', 1),
#  'vyrobeno': ('SUPPORTS', 1),
#  'vozů': ('SUPPORTS', 1),
#  'polských': ('SUPPORTS', 1),
#  'všech': ('SUPPORTS', 2),
#  '126': ('SUPPORTS', 1),
#  'Přes': ('SUPPORTS', 1),
#  'George': ('SUPPORTS', 1),
#  'uvažuje': ('SUPPORTS', 1),
#  'Bush': ('SUPPORTS', 1),
#  'volbách': ('SUPPORTS', 1),
#  'změnách': ('SUPPORTS', 1),
#  'personálních': ('SUPPORTS', 1),
#  'svém': ('NOT ENOUGH INFO', 2),
#  'kabinetu': ('SUPPORTS', 1),
#  'po': ('SUPPORTS', 4),
#  'dezolátním': ('REFUTES', 2),
#  'město': ('REFUTES', 5),
#  'stavu': ('REFUTES', 2),
#  'že': ('REFUTES', 9),
#  '1841': ('SUPPORTS', 2),
#  'nechá': ('REFUTES', 2),
#  'starostka': ('REFUTES', 3),
#  'Postoloprtská': ('REFUTES', 3),
#  'prohlásila,': ('REFUTES', 3),
#  'de': ('SUPPORTS', 3),
#  'pochodu': ('SUPPORTS', 4),
#  'lidé': ('SUPPORTS', 4),
#  'Santiagu': ('SUPPORTS', 3),
#  'demonstrovali': ('SUPPORTS', 5),
#  'Chile': ('SUPPORTS', 4),
#  'mírovém': ('SUPPORTS', 4),
#  'volat': ('SUPPORTS', 1),
#  'Pokud': ('SUPPORTS', 1),
#  'praktickému': ('SUPPORTS', 1),
#  'lékaři': ('SUPPORTS', 2),
#  'hodiny': ('SUPPORTS', 1),
#  'neustoupí,': ('SUPPORTS', 1),
#  'nutno': ('SUPPORTS', 1),
#  'republika': ('SUPPORTS', 1),
#  'situací': ('SUPPORTS', 1),
#  'Česká': ('REFUTES', 5),
#  'krizovou': ('SUPPORTS', 1),
#  'vypořádat': ('SUPPORTS', 1),
#  'Česko': ('SUPPORTS', 2),
#  'snadněji': ('SUPPORTS', 2),
#  'čerpat': ('SUPPORTS', 2),
#  'evropské': ('SUPPORTS', 2),
#  'dotace': ('SUPPORTS', 2),
#  'praktičtí': ('SUPPORTS', 1),
#  'ledna': ('SUPPORTS', 1),
#  '18': ('SUPPORTS', 1),
#  'Německu': ('SUPPORTS', 1),
#  'svůj': ('SUPPORTS', 2),
#  'mandát': ('SUPPORTS', 1),
#  'Irácký': ('SUPPORTS', 1),
#  'Aláví': ('SUPPORTS', 1),
#  'Ajád': ('SUPPORTS', 1),
#  'obhájit': ('SUPPORTS', 1),
#  'Žulawski': ('REFUTES', 4),
#  'zemřel': ('SUPPORTS', 6),
#  'Andrzej': ('SUPPORTS', 3),
#  'Pardubickém': ('SUPPORTS', 3),
#  'první': ('REFUTES', 4),
#  'člověk': ('SUPPORTS', 3),
#  'kraji': ('SUPPORTS', 3),
#  'metanolem': ('SUPPORTS', 2),
#  'otravu': ('SUPPORTS', 1),
#  'Mradicích': ('SUPPORTS', 1),
#  'čeká': ('SUPPORTS', 1),
#  'renovace': ('SUPPORTS', 1),
#  'Kapli': ('SUPPORTS', 1),
#  'španělská': ('SUPPORTS', 1),
#  'nové': ('REFUTES', 3),
#  'Latinské': ('SUPPORTS', 2),
#  'společné': ('NOT ENOUGH INFO', 2),
#  'Švýcarská': ('SUPPORTS', 1),
#  'podnikání': ('NOT ENOUGH INFO', 2),
#  'Americe': ('SUPPORTS', 3),
#  'představily': ('NOT ENOUGH INFO', 2),
#  'Bühler': ('SUPPORTS', 6),
#  'miliónů': ('SUPPORTS', 4),
#  'Králové': ('SUPPORTS', 6),
#  'Hradci': ('SUPPORTS', 5),
#  'výrobní': ('SUPPORTS', 3),
#  'halu': ('SUPPORTS', 3),
#  '90': ('SUPPORTS', 6),
#  'Společnost': ('SUPPORTS', 4),
#  'otevřela': ('SUPPORTS', 2),
#  'Motor': ('SUPPORTS', 6),
#  'uskutečnil': ('SUPPORTS', 3),
#  'vojenský': ('SUPPORTS', 3),
#  'zabit': ('SUPPORTS', 3),
#  'převrat,': ('SUPPORTS', 3),
#  'kterém': ('SUPPORTS', 3),
#  'Augusto': ('SUPPORTS', 4),
#  'Pinochet': ('SUPPORTS', 3),
#  'španělského': ('SUPPORTS', 2),
#  'hlasovalo': ('SUPPORTS', 2),
#  'procent': ('SUPPORTS', 2),
#  'regionu': ('SUPPORTS', 1),
#  'nezávislost': ('SUPPORTS', 1),
#  'Přibližně': ('SUPPORTS', 2),
#  'střediska': ('REFUTES', 2),
#  'Ředitelem': ('REFUTES', 2),
#  'Jiří': ('SUPPORTS', 2),
#  'Krkonoších': ('SUPPORTS', 1),
#  'Beran': ('SUPPORTS', 1),
#  'lyžařského': ('SUPPORTS', 1),
#  'ocenění': ('SUPPORTS', 1),
#  'státní': ('SUPPORTS', 1),
#  'Kundera': ('SUPPORTS', 1),
#  'Milan': ('SUPPORTS', 1),
#  'dostal': ('NOT ENOUGH INFO', 2),
#  'Kocianovo': ('SUPPORTS', 1),
#  'cenu': ('REFUTES', 3),
#  'získalo': ('SUPPORTS', 1),
#  'kvarteto': ('SUPPORTS', 1),
#  'Donald': ('SUPPORTS', 1),
#  'Předseda': ('SUPPORTS', 1),
#  'instituce': ('SUPPORTS', 1),
#  'Tusk': ('SUPPORTS', 1),
#  'Diplomatické': ('REFUTES', 2),
#  'zeměmi': ('SUPPORTS', 1),
#  'asijskými': ('SUPPORTS', 1),
#  'dvěma': ('SUPPORTS', 1),
#  'nebyly': ('SUPPORTS', 1),
#  'ideální': ('SUPPORTS', 1),
#  'vztahy': ('REFUTES', 2),
#  'vyloučeny': ('REFUTES', 2),
#  'Třebíči': ('SUPPORTS', 3),
#  'Záplavy': ('REFUTES', 2),
#  'funkci': ('SUPPORTS', 1),
#  'proti,': ('SUPPORTS', 1),
#  'vykonával': ('SUPPORTS', 1),
#  'ústavního': ('SUPPORTS', 1),
#  'soudce': ('SUPPORTS', 1),
#  'aby': ('SUPPORTS', 2),
#  'státu': ('SUPPORTS', 1),
#  'figurují': ('SUPPORTS', 1),
#  'Bývalí': ('SUPPORTS', 1),
#  'řízení': ('SUPPORTS', 2),
#  'soudním': ('SUPPORTS', 1),
#  'zmizeli': ('SUPPORTS', 1),
#  'zoo': ('SUPPORTS', 1),
#  'jihlavské': ('SUPPORTS', 1),
#  'víkendu': ('SUPPORTS', 1),
#  'O': ('SUPPORTS', 1),
#  'zlatí': ('SUPPORTS', 1),
#  'dva': ('SUPPORTS', 3),
#  'kaloni': ('SUPPORTS', 1),
#  'území': ('SUPPORTS', 3),
#  'vstup': ('SUPPORTS', 2),
#  'gruzínský': ('SUPPORTS', 2),
#  'Ukrajiny': ('SUPPORTS', 2),
#  'má': ('NOT ENOUGH INFO', 4),
#  'Někdejší': ('SUPPORTS', 1),
#  'zakázaný': ('SUPPORTS', 2),
#  'žije': ('NOT ENOUGH INFO', 2),
#  'Tchaj-wanu': ('SUPPORTS', 1),
#  'neobyčejně': ('SUPPORTS', 1),
#  'obyvatel': ('SUPPORTS', 3),
#  'mnoho': ('SUPPORTS', 1),
#  'Sovětském': ('SUPPORTS', 1),
#  'rozpadat': ('SUPPORTS', 1),
#  'východního': ('SUPPORTS', 1),
#  'začaly': ('SUPPORTS', 1),
#  'zemí': ('SUPPORTS', 2),
#  'svazu': ('SUPPORTS', 1),
#  'let': ('SUPPORTS', 2),
#  'režimy': ('SUPPORTS', 1),
#  'bloku,': ('SUPPORTS', 1),
#  'osmdesátých': ('SUPPORTS', 1),
#  'konci': ('SUPPORTS', 1),
#  'závislých': ('SUPPORTS', 1),
#  'základny': ('NOT ENOUGH INFO', 5),
#  'protiraketové': ('NOT ENOUGH INFO', 5),
#  'Umístění': ('NOT ENOUGH INFO', 5),
#  'odmítá': ('NOT ENOUGH INFO', 5),
#  'většina': ('NOT ENOUGH INFO', 5),
#  'Poláků': ('SUPPORTS', 2),
#  'Polsku': ('NOT ENOUGH INFO', 9),
#  'americké': ('NOT ENOUGH INFO', 8),
#  'režíruje': ('SUPPORTS', 1),
#  'seriály': ('SUPPORTS', 1),
#  'Quentin': ('SUPPORTS', 1),
#  'televizní': ('SUPPORTS', 1),
#  'pouze': ('REFUTES', 2),
#  'Tarantino': ('SUPPORTS', 1),
#  'Moravou': ('SUPPORTS', 1),
#  'Řekou': ('SUPPORTS', 1),
#  'protéká': ('SUPPORTS', 1),
#  'méně': ('REFUTES', 4),
#  'varoval': ('SUPPORTS', 1),
#  'před': ('NOT ENOUGH INFO', 2),
#  'Václav': ('SUPPORTS', 2),
#  'Havel': ('SUPPORTS', 2),
#  'Ruské': ('SUPPORTS', 1),
#  'ústupky': ('SUPPORTS', 1),
#  'federaci': ('SUPPORTS', 1),
#  'zakázali': ('SUPPORTS', 1),
#  'potraty': ('SUPPORTS', 1),
#  'jmenuje': ('SUPPORTS', 2),
#  'Jednatel': ('SUPPORTS', 2),
#  'Christof': ('SUPPORTS', 2),
#  'Furtwängler': ('SUPPORTS', 2),
#  'studia': ('NOT ENOUGH INFO', 3),
#  'uvedla': ('NOT ENOUGH INFO', 2),
#  '2002': ('NOT ENOUGH INFO', 3),
#  '15': ('SUPPORTS', 1),
#  'pokračování': ('NOT ENOUGH INFO', 3),
#  'Hollywoodská': ('NOT ENOUGH INFO', 3),
#  'filmových': ('SUPPORTS', 1),
#  'zaměří': ('SUPPORTS', 1),
#  'spolupráci': ('SUPPORTS', 1),
#  'služeb': ('SUPPORTS', 1),
#  'finančních': ('SUPPORTS', 1),
#  'nabídku': ('SUPPORTS', 1),
#  'milion': ('REFUTES', 2),
#  'cestujících': ('SUPPORTS', 1),
#  'pražské': ('SUPPORTS', 2),
#  'více': ('SUPPORTS', 6),
#  'odbavilo': ('REFUTES', 2),
#  'letiště': ('REFUTES', 2),
#  'poprvé': ('SUPPORTS', 3),
#  'červenci': ('REFUTES', 2),
#  'nejezdil': ('SUPPORTS', 1),
#  'Slovenský': ('REFUTES', 2),
#  'den': ('SUPPORTS', 1),
#  'vojsk': ('SUPPORTS', 1),
#  'smlouvy': ('REFUTES', 2),
#  'Bratislavy': ('SUPPORTS', 1),
#  'vpádu': ('SUPPORTS', 1),
#  'Varšavské': ('SUPPORTS', 1),
#  'maďarský': ('REFUTES', 2),
#  'protějšek,': ('SUPPORTS', 1),
#  'výročí': ('SUPPORTS', 1),
#  'vyzval': ('REFUTES', 2),
#  'Nejen': ('SUPPORTS', 2),
#  'Lidovci': ('SUPPORTS', 2),
#  'Tomia': ('SUPPORTS', 4),
#  'volají': ('SUPPORTS', 3),
#  'místopředsedy': ('SUPPORTS', 4),
#  'pozice': ('SUPPORTS', 4),
#  'Okamury': ('SUPPORTS', 4),
#  'Sněmovny': ('SUPPORTS', 3),
#  'odvolání': ('SUPPORTS', 4),
#  'vlastní': ('SUPPORTS', 1),
#  'Hradec': ('SUPPORTS', 1),
#  'Národnímu': ('SUPPORTS', 1),
#  'miliony': ('SUPPORTS', 2),
#  'Mecenášové': ('SUPPORTS', 1),
#  'darovali': ('SUPPORTS', 1),
#  'přes': ('SUPPORTS', 2),
#  'divadlu': ('SUPPORTS', 1),
#  'vystavuje': ('SUPPORTS', 3),
#  'instalací': ('SUPPORTS', 2),
#  'Autor': ('SUPPORTS', 2),
#  'galerii': ('SUPPORTS', 3),
#  'audiovizuálních': ('SUPPORTS', 2),
#  'obrněných': ('REFUTES', 2),
#  'vozidel': ('SUPPORTS', 1),
#  'osmnáctitunových': ('REFUTES', 2),
#  '500': ('SUPPORTS', 2),
#  'Stryker': ('SUPPORTS', 1),
#  'vojáky': ('REFUTES', 2),
#  'Humvee': ('SUPPORTS', 1),
#  'americkými': ('REFUTES', 2),
#  'dorazilo': ('SUPPORTS', 1),
#  'terénních': ('SUPPORTS', 1),
#  'Do': ('NOT ENOUGH INFO', 3),
#  '115': ('REFUTES', 2),
#  'politik': ('NOT ENOUGH INFO', 2),
#  'amerického': ('SUPPORTS', 1),
#  'švýcarské': ('SUPPORTS', 2),
#  'kontinentu': ('SUPPORTS', 1),
#  'skupině': ('SUPPORTS', 2),
#  'pojišťovnou': ('SUPPORTS', 1),
#  'jižně': ('SUPPORTS', 1),
#  'trhům': ('SUPPORTS', 1),
#  'Dohoda': ('SUPPORTS', 2),
#  'umožní': ('SUPPORTS', 1),
#  'hrozí': ('NOT ENOUGH INFO', 3),
#  'lidem': ('SUPPORTS', 1),
#  'vyčerpání': ('SUPPORTS', 1),
#  'Křeče': ('REFUTES', 2),
#  'mimopražských': ('SUPPORTS', 1),
#  'regionálních': ('SUPPORTS', 1),
#  'divadel': ('SUPPORTS', 1),
#  'českých': ('SUPPORTS', 1),
#  'červnu': ('SUPPORTS', 1),
#  '1989': ('SUPPORTS', 1),
#  'kterým': ('SUPPORTS', 1),
#  'Svitek': ('SUPPORTS', 1),
#  'Československu': ('SUPPORTS', 1),
#  'Štefan': ('SUPPORTS', 1),
#  'Bratislavě': ('SUPPORTS', 1),
#  'posledního': ('SUPPORTS', 1),
#  'vraha,': ('SUPPORTS', 1),
#  'popravili': ('SUPPORTS', 1),
#  'Freudových': ('SUPPORTS', 1),
#  'květen': ('SUPPORTS', 1),
#  'odhalení': ('REFUTES', 2),
#  'plánuje': ('SUPPORTS', 2),
#  '151': ('SUPPORTS', 2),
#  'příštího': ('SUPPORTS', 1),
#  'oslav': ('SUPPORTS', 1),
#  'příležitosti': ('SUPPORTS', 2),
#  'plácku': ('SUPPORTS', 1),
#  'Kozím': ('SUPPORTS', 1),
#  'sochy': ('SUPPORTS', 2),
#  'Sigmunda': ('SUPPORTS', 2),
#  'Oficiální': ('SUPPORTS', 1),
#  'tedy': ('SUPPORTS', 1),
#  'narozenin': ('SUPPORTS', 2),
#  'roku,': ('SUPPORTS', 1),
#  'Tisa': ('SUPPORTS', 1),
#  'zdravotnictví': ('SUPPORTS', 2),
#  'visí': ('SUPPORTS', 2),
#  'ministerstva': ('SUPPORTS', 2),
#  'portrét': ('SUPPORTS', 2),
#  'slovenského': ('SUPPORTS', 2),
#  'Jozefa': ('SUPPORTS', 1),
#  'budově': ('SUPPORTS', 2),
#  'Režisér': ('NOT ENOUGH INFO', 3),
#  'kontroverzních': ('SUPPORTS', 1),
#  'Varšavě': ('SUPPORTS', 1),
#  'otrávil': ('SUPPORTS', 2),
#  'Národní': ('SUPPORTS', 1),
#  'dary,': ('SUPPORTS', 1),
#  'finanční': ('SUPPORTS', 1),
#  'které': ('SUPPORTS', 2),
#  'přesahovaly': ('SUPPORTS', 1),
#  '2016': ('SUPPORTS', 1),
#  'obdrželo': ('SUPPORTS', 1),
#  'umění': ('NOT ENOUGH INFO', 3),
#  'Od': ('SUPPORTS', 1),
#  'pěněžitou': ('SUPPORTS', 1),
#  'újmu': ('SUPPORTS', 1),
#  'Nejmírnější': ('SUPPORTS', 1),
#  '10000': ('SUPPORTS', 3),
#  'republiky': ('SUPPORTS', 2),
#  'městě': ('SUPPORTS', 5),
#  'uskutečnilo': ('SUPPORTS', 2),
#  'demonstrací': ('SUPPORTS', 2),
#  '2008': ('NOT ENOUGH INFO', 5),
#  'Kaloňům': ('SUPPORTS', 1),
#  'dvě': ('SUPPORTS', 1),
#  'narodila': ('SUPPORTS', 1),
#  'zlatým': ('SUPPORTS', 1),
#  'mláďata': ('SUPPORTS', 1),
#  'ligy': ('SUPPORTS', 1),
#  'Mezinárodní': ('SUPPORTS', 1),
#  'nezúčastnil': ('SUPPORTS', 1),
#  'ceny': ('SUPPORTS', 1),
#  'humanistů': ('SUPPORTS', 1),
#  'předání': ('SUPPORTS', 1),
#  'sídle': ('SUPPORTS', 1),
#  'Spojeného': ('SUPPORTS', 1),
#  'království': ('SUPPORTS', 1),
#  'unie': ('REFUTES', 3),
#  'vztah': ('SUPPORTS', 1),
#  'definovat': ('SUPPORTS', 1),
#  'Nicolas': ('NOT ENOUGH INFO', 2),
#  'Sarkozy': ('NOT ENOUGH INFO', 2),
#  'počet': ('NOT ENOUGH INFO', 4),
#  'Francie': ('SUPPORTS', 1),
#  'cizinců,': ('SUPPORTS', 1),
#  'ochotna': ('SUPPORTS', 1),
#  'přijmout': ('SUPPORTS', 1),
#  'Prezident': ('SUPPORTS', 3),
#  'omezit': ('SUPPORTS', 1),
#  'otravě': ('SUPPORTS', 1),
#  'podlehlo': ('SUPPORTS', 1),
#  'lidí': ('NOT ENOUGH INFO', 4),
#  '23': ('SUPPORTS', 1),
#  'Česku': ('SUPPORTS', 3),
#  'začnou': ('SUPPORTS', 1),
#  'ropným': ('NOT ENOUGH INFO', 2),
#  'předpokladů': ('NOT ENOUGH INFO', 2),
#  'proti': ('SUPPORTS', 4),
#  'Iráku': ('SUPPORTS', 2),
#  'zařízením': ('NOT ENOUGH INFO', 2),
#  'sabotáže': ('SUPPORTS', 1),
#  'soupeřů': ('SUPPORTS', 1),
#  '17': ('SUPPORTS', 1),
#  'Novák': ('SUPPORTS', 1),
#  'porazil': ('SUPPORTS', 2),
#  'výběrovém': ('SUPPORTS', 1),
#  'představení': ('SUPPORTS', 1),
#  'naplánováno': ('SUPPORTS', 1),
#  'slavnostní': ('SUPPORTS', 1),
#  'K': ('SUPPORTS', 1),
#  'řádech': ('SUPPORTS', 1),
#  'Odklon': ('SUPPORTS', 1),
#  'milionů': ('NOT ENOUGH INFO', 5),
#  'dopravy': ('SUPPORTS', 1),
#  'zavinil': ('SUPPORTS', 1),
#  'škodu': ('SUPPORTS', 1),
#  'nepožaduje': ('REFUTES', 2),
#  'Nikdo': ('REFUTES', 2),
#  'koná': ('REFUTES', 2),
#  'slezském': ('SUPPORTS', 1),
#  'Květinová': ('SUPPORTS', 1),
#  'slavnost': ('SUPPORTS', 1),
#  '1973': ('SUPPORTS', 2),
#  'pravidelně': ('SUPPORTS', 1),
#  'Havířově': ('SUPPORTS', 2),
#  'Všeobecné': ('SUPPORTS', 1),
#  'hrozí,': ('SUPPORTS', 1),
#  'odvolán': ('SUPPORTS', 1),
#  'Šéfovi': ('SUPPORTS', 1),
#  'pojišťovny': ('SUPPORTS', 2),
#  'zdravotní': ('SUPPORTS', 1),
#  'Horákovi': ('SUPPORTS', 1),
#  'Pavlu': ('SUPPORTS', 1),
#  'Evo': ('NOT ENOUGH INFO', 2),
#  'země': ('SUPPORTS', 3),
#  'stojí': ('NOT ENOUGH INFO', 2),
#  'deset': ('SUPPORTS', 1),
#  'Morales': ('NOT ENOUGH INFO', 3),
#  'Bolívie': ('SUPPORTS', 1),
#  'své': ('NOT ENOUGH INFO', 7),
#  'čele': ('SUPPORTS', 1),
#  'už': ('REFUTES', 2),
#  'vodních': ('SUPPORTS', 1),
#  'menší': ('REFUTES', 2),
#  'nádrží': ('SUPPORTS', 1),
#  'objem': ('SUPPORTS', 1),
#  'rybníků': ('SUPPORTS', 1),
#  'Objem': ('SUPPORTS', 1),
#  'černošskému': ('SUPPORTS', 2),
#  'brutálně': ('SUPPORTS', 2),
#  'Kingovi,': ('SUPPORTS', 1),
#  'kteří': ('SUPPORTS', 2),
#  '14': ('NOT ENOUGH INFO', 2),
#  'zasáhli': ('SUPPORTS', 2),
#  'Angeles,': ('SUPPORTS', 1),
#  '1994': ('SUPPORTS', 2),
#  'Rozsudek': ('SUPPORTS', 2),
#  'Los': ('SUPPORTS', 1),
#  'policistů': ('SUPPORTS', 2),
#  'Rodneymu': ('SUPPORTS', 1),
#  'května': ('SUPPORTS', 1),
#  'prupuštění': ('SUPPORTS', 2),
#  'padl': ('SUPPORTS', 2),
#  'motorkáři': ('SUPPORTS', 1),
#  'sboru': ('SUPPORTS', 1),
#  'začal': ('SUPPORTS', 1),
#  'běžce': ('SUPPORTS', 1),
#  'veletrh': ('REFUTES', 4),
#  'Kladno': ('SUPPORTS', 1),
#  'Mimo': ('SUPPORTS', 1),
#  'Petr': ('SUPPORTS', 1),
#  'Gandalovič': ('SUPPORTS', 1),
#  'oznámil': ('REFUTES', 2),
#  'šéfa': ('SUPPORTS', 1),
#  'Lesy': ('SUPPORTS', 1),
#  'zemědělství': ('SUPPORTS', 1),
#  'podniku': ('SUPPORTS', 1),
#  'nového': ('SUPPORTS', 1),
#  'Ministr': ('SUPPORTS', 1),
#  'státního': ('SUPPORTS', 1),
#  'dnes': ('REFUTES', 3),
#  'Střelec': ('SUPPORTS', 1),
#  'Denveru': ('SUPPORTS', 1),
#  'zastřelen': ('SUPPORTS', 1),
#  'zatýkání': ('SUPPORTS', 1),
#  'vyhnout': ('SUPPORTS', 1),
#  'slunci': ('SUPPORTS', 1),
#  'nutné': ('SUPPORTS', 1),
#  'přímém': ('SUPPORTS', 1),
#  'evropský': ('SUPPORTS', 1),
#  'Oceňovaný': ('NOT ENOUGH INFO', 3),
#  'rakovinu': ('NOT ENOUGH INFO', 3),
#  'režisér': ('NOT ENOUGH INFO', 3),
#  'osamostatnění': ('SUPPORTS', 1),
#  'Katalánska': ('SUPPORTS', 1),
#  'i': ('NOT ENOUGH INFO', 2),
#  'Okamura': ('SUPPORTS', 1),
#  'považuje': ('SUPPORTS', 1),
#  'kritiku': ('SUPPORTS', 1),
#  'přímé': ('SUPPORTS', 1),
#  'zabránit': ('SUPPORTS', 1),
#  'Tomio': ('SUPPORTS', 1),
#  'účasti': ('SUPPORTS', 1),
#  'němu': ('SUPPORTS', 1),
#  'sestavování': ('SUPPORTS', 1),
#  'SPD': ('SUPPORTS', 1),
#  'vedené': ('SUPPORTS', 1),
#  'součást': ('SUPPORTS', 1),
#  'cílem': ('SUPPORTS', 1),
#  'nepřímé': ('SUPPORTS', 1),
#  'vlády': ('SUPPORTS', 2),
#  'kampaně': ('SUPPORTS', 1),
#  'dcera': ('SUPPORTS', 1),
#  'byla': ('SUPPORTS', 5),
#  'dětí': ('SUPPORTS', 1),
#  'Lindgrenové': ('SUPPORTS', 1),
#  'Karin': ('SUPPORTS', 1),
#  'Jedno': ('SUPPORTS', 1),
#  'organizovaném': ('SUPPORTS', 1),
#  'vojenském': ('SUPPORTS', 1),
#  'Pinochetem': ('SUPPORTS', 1),
#  'usmrcen': ('SUPPORTS', 1),
#  'Salvador': ('SUPPORTS', 1),
#  'Allende': ('SUPPORTS', 1),
#  'převratu': ('SUPPORTS', 1),
#  'Stav': ('SUPPORTS', 2),
#  '2015': ('SUPPORTS', 2),
#  'zaměstnanců': ('SUPPORTS', 3),
#  'čtyři': ('SUPPORTS', 2),
#  'sta': ('SUPPORTS', 2),
#  'kroměřížské': ('SUPPORTS', 2),
#  'narušili': ('SUPPORTS', 1),
#  'mírový': ('SUPPORTS', 1),
#  'pochod': ('SUPPORTS', 1),
#  'demonstranti': ('SUPPORTS', 1),
#  'částečně': ('SUPPORTS', 1),
#  'vinu': ('SUPPORTS', 1),
#  'člen': ('SUPPORTS', 1),
#  'přiznal': ('SUPPORTS', 1),
#  'oteplování': ('SUPPORTS', 2),
#  'bezpečné': ('SUPPORTS', 1),
#  'netvrdil,': ('SUPPORTS', 1),
#  'vědec': ('SUPPORTS', 2),
#  'Britský': ('SUPPORTS', 2),
#  'Houghton': ('SUPPORTS', 1),
#  'planety': ('SUPPORTS', 2),
#  'John': ('SUPPORTS', 1),
#  'Oblíbenosti': ('SUPPORTS', 1),
#  'těší': ('SUPPORTS', 1),
#  'víno': ('SUPPORTS', 1),
#  'květnu': ('SUPPORTS', 1),
#  'vystavena': ('NOT ENOUGH INFO', 2),
#  'Epopej': ('NOT ENOUGH INFO', 4),
#  '1919': ('SUPPORTS', 1),
#  'Massachusetts': ('SUPPORTS', 1),
#  'univerzitě': ('SUPPORTS', 1),
#  'náboženství': ('SUPPORTS', 1),
#  'hlava': ('SUPPORTS', 1),
#  'II': ('NOT ENOUGH INFO', 2),
#  'Jan': ('NOT ENOUGH INFO', 2),
#  'katolické': ('SUPPORTS', 1),
#  'Pavel': ('NOT ENOUGH INFO', 2),
#  'církve': ('SUPPORTS', 1),
#  'jiných': ('SUPPORTS', 1),
#  'svatostánků': ('SUPPORTS', 1),
#  'nepodíval': ('SUPPORTS', 1),
#  'jako': ('SUPPORTS', 2),
#  'nikdy': ('SUPPORTS', 1),
#  'konala': ('SUPPORTS', 1),
#  'Slavnost': ('SUPPORTS', 1),
#  'květin': ('SUPPORTS', 1),
#  'Oscar': ('REFUTES', 3),
#  'není': ('SUPPORTS', 1),
#  'Espinosa': ('REFUTES', 3),
#  'již': ('SUPPORTS', 1),
#  'Chepe': ('REFUTES', 4),
#  'živými': ('SUPPORTS', 1),
#  'disident': ('REFUTES', 4),
#  'Kubánský': ('SUPPORTS', 1),
#  'španělské': ('SUPPORTS', 1),
#  'rychle': ('SUPPORTS', 1),
#  'trhy': ('SUPPORTS', 1),
#  'kapitál': ('SUPPORTS', 1),
#  'další': ('SUPPORTS', 1),
#  'zpřístupní': ('SUPPORTS', 1),
#  'Spolupráce': ('SUPPORTS', 1),
#  'rostoucí': ('SUPPORTS', 1),
#  'instituci': ('SUPPORTS', 1),
#  'akvizice': ('SUPPORTS', 1),
#  'Moderního': ('NOT ENOUGH INFO', 2),
#  'výstava': ('NOT ENOUGH INFO', 3),
#  'minimalismu': ('SUPPORTS', 1),
#  'začíná': ('NOT ENOUGH INFO', 2),
#  'Tematická': ('NOT ENOUGH INFO', 2),
#  'Ostravě': ('SUPPORTS', 1),
#  'Galerii': ('NOT ENOUGH INFO', 2),
#  'měří': ('SUPPORTS', 1),
#  'meteorologické': ('SUPPORTS', 1),
#  'Rekordní': ('SUPPORTS', 1),
#  'stanici': ('SUPPORTS', 1),
#  'teploty': ('SUPPORTS', 1),
#  '1775': ('SUPPORTS', 1),
#  '1235': ('SUPPORTS', 1),
#  'bitvě': ('SUPPORTS', 1),
#  'vojáků': ('SUPPORTS', 1),
#  'zahynulo': ('SUPPORTS', 1),
#  'civilistů': ('SUPPORTS', 1),
#  'zabito': ('SUPPORTS', 1),
#  '20': ('SUPPORTS', 1),
#  'zbraň': ('SUPPORTS', 1),
#  'ničení': ('REFUTES', 2),
#  'pokládá': ('SUPPORTS', 1),
#  'hromadného': ('REFUTES', 2),
#  'opravena': ('NOT ENOUGH INFO', 2),
#  'kaple': ('NOT ENOUGH INFO', 5),
#  'jiné': ('SUPPORTS', 1),
#  'Kaloni': ('SUPPORTS', 1),
#  'netopýři': ('SUPPORTS', 1),
#  'mají': ('REFUTES', 2),
#  'vlastnosti': ('SUPPORTS', 1),
#  'zabavila': ('SUPPORTS', 1),
#  'drog': ('SUPPORTS', 1),
#  'Armáda': ('SUPPORTS', 1),
#  'velké': ('SUPPORTS', 1),
#  'množství': ('SUPPORTS', 1),
#  'existuje': ('SUPPORTS', 1),
#  'společnost': ('NOT ENOUGH INFO', 4),
#  'Učená': ('NOT ENOUGH INFO', 4),
#  'ke': ('SUPPORTS', 1),
#  'Díky': ('NOT ENOUGH INFO', 2),
#  'nedošlo': ('SUPPORTS', 1),
#  'škodám': ('SUPPORTS', 1),
#  'protipovodňovým': ('SUPPORTS', 1),
#  'opatřením': ('SUPPORTS', 1),
#  'gymnastice': ('SUPPORTS', 1),
#  'mistrovství': ('SUPPORTS', 1),
#  'zúčastní': ('SUPPORTS', 1),
#  'Konečný': ('REFUTES', 2),
#  'Martin': ('REFUTES', 2),
#  'Evropy': ('NOT ENOUGH INFO', 2),
#  'Gymnasta': ('REFUTES', 2),
#  'žízeň': ('SUPPORTS', 1),
#  'Ostrava': ('SUPPORTS', 1),
#  'kouření': ('SUPPORTS', 2),
#  'ArcelorMittal': ('SUPPORTS', 1),
#  'u': ('NOT ENOUGH INFO', 3),
#  'odvykání': ('SUPPORTS', 1),
#  'svých': ('SUPPORTS', 1),
#  'finančně': ('SUPPORTS', 1),
#  'podpoří': ('SUPPORTS', 2),
#  'Největší': ('SUPPORTS', 1),
#  'hutní': ('SUPPORTS', 1),
#  'závislé': ('SUPPORTS', 1),
#  'zaměstnance': ('SUPPORTS', 1),
#  'ukrajinkského': ('SUPPORTS', 1),
#  'Polska': ('SUPPORTS', 2),
#  'Ruský': ('SUPPORTS', 1),
#  'plynovody': ('SUPPORTS', 1),
#  'plynárenský': ('SUPPORTS', 1),
#  'gigant': ('SUPPORTS', 1),
#  'Gazprom': ('SUPPORTS', 1),
#  'zavede': ('SUPPORTS', 1),
#  'Polský': ('SUPPORTS', 1),
#  'zastánci': ('SUPPORTS', 1),
#  'umístění': ('SUPPORTS', 1),
#  'Egyptě': ('REFUTES', 2),
#  'Talibánu': ('SUPPORTS', 1),
#  'počtvrté': ('NOT ENOUGH INFO', 2),
#  'Latinskoamerický': ('SUPPORTS', 1),
#  'kandidovat': ('NOT ENOUGH INFO', 2),
#  'kubánský': ('REFUTES', 4),
#  'Španělska': ('SUPPORTS', 1),
#  'Richard': ('REFUTES', 2),
#  'Loskot': ('REFUTES', 2),
#  'východních': ('SUPPORTS', 1),
#  'Čechách': ('SUPPORTS', 1),
#  'Kolumbii': ('SUPPORTS', 1),
#  'roste': ('SUPPORTS', 1),
#  'Zločinnost': ('SUPPORTS', 1),
#  'podporují': ('SUPPORTS', 1),
#  'SD': ('SUPPORTS', 1),
#  'ČEZ': ('SUPPORTS', 1),
#  'soutěži': ('SUPPORTS', 1),
#  'Odboráři': ('REFUTES', 2),
#  'výstavě': ('SUPPORTS', 1),
#  'věnoval': ('SUPPORTS', 1),
#  'Bučovický': ('SUPPORTS', 1),
#  'restaurování': ('SUPPORTS', 1),
#  ...}

# %%
# all data
productivity_uni_all = {k: v[1] / applicability_uni_all[k] for k, v in max_counts_uni_all.items()} 
productivity_uni_all = OrderedDict(sorted(productivity_uni_all.items(), key=lambda kv: kv[1], reverse=True))

productivity_big_all = {k: v[1] / applicability_big_all[k] for k, v in max_counts_big_all.items()} 
productivity_big_all = OrderedDict(sorted(productivity_big_all.items(), key=lambda kv: kv[1], reverse=True))


# per samples / k-fold cross validation like
productivity_uni = [
                    {k: v[1] / applicability_uni[i][k] for k, v in max_counts_uni[i].items()} 
                    for i in range(NUM_SAMPLES)]
productivity_uni = [
                    OrderedDict(sorted(productivity_uni[i].items(), key=lambda kv: kv[1], reverse=True)) 
                    for i in range(NUM_SAMPLES)]

productivity_big = [
                    {k: v[1] / applicability_big[i][k] for k, v in max_counts_big[i].items()} 
                    for i in range(NUM_SAMPLES)]
productivity_big = [
                    OrderedDict(sorted(productivity_big[i].items(), key=lambda kv: kv[1], reverse=True)) 
                    for i in range(NUM_SAMPLES)]

# %% [markdown]
# ## Cue Coverage = applicability of a cue / total number of claims = v kolika claimech je cue pritomna / pocet claimu

# %%
# all data
coverage_uni_all = {k: v / len(df) for k, v in applicability_uni_all.items()}
sorted_d = OrderedDict(sorted(coverage_uni_all.items(), key=lambda kv: kv[1], reverse=True))

coverage_big_all = {k: v / len(df) for k, v in applicability_big_all.items()}
sorted_d = OrderedDict(sorted(coverage_big_all.items(), key=lambda kv: kv[1], reverse=True))

# per samples / k-fold cross validation like
coverage_uni = [
                {k: v / len(SAMPLES[i]) for k, v in applicability_uni[i].items()} 
                for i in range(NUM_SAMPLES)]

sorted_d = [
            OrderedDict(sorted(coverage_uni[i].items(), key=lambda kv: kv[1], reverse=True)) 
            for i in range(NUM_SAMPLES)]

coverage_big = [
                {k: v / len(SAMPLES[i]) for k, v in applicability_big[i].items()} 
                for i in range(NUM_SAMPLES)]

sorted_d = [
            OrderedDict(sorted(coverage_big[i].items(), key=lambda kv: kv[1], reverse=True)) 
            for i in range(NUM_SAMPLES)]

# %% [markdown]
# ## Cue Utility (for ML algorithm: the higher utility the easier decision for ML alg)
#
# In order to compare above metrics between datasets utility is the metric to go. A cue is only useful to a machine
# learning model if productivity_k > 1 / m, where m is the number of possible labels (=3; supports, refutes, not enough info).

# %%
# all data
utility_uni_all = {k: v - 1/LABELS for k, v in productivity_uni_all.items()}

utility_big_all = {k: v - 1/LABELS for k, v in productivity_big_all.items()}


# per samples / k-fold cross validation like
utility_uni = [{k: v - 1/LABELS for k, v in productivity_uni[i].items()} 
              for i in range(NUM_SAMPLES)]

utility_big = [{k: v - 1/LABELS for k, v in productivity_big[i].items()} 
              for i in range(NUM_SAMPLES)]

# %%
utility_uni[0]['dále']
# Out:
# 0.6666666666666667

# %% [markdown]
# ## Results
#
# How to read it:
# - productivity = how strong the potential bias is; in our case of the 3 labels -- 1/3 is pure randomness
# - utility = adjusted productivity for cross dataset comparison
# - coverage = how common/widespread is the cue
# - harmonic mean = harmonic mean of utility and coverage; the higher harmonic mean the higher risk of bias in the data

# %% [markdown]
# ### Unigrams

# %%
res_uni = []
for i in range(NUM_SAMPLES):
    tmp = pd.DataFrame.from_dict(productivity_uni[i], orient='index', columns=['productivity']).join(
        [pd.DataFrame.from_dict(utility_uni[i], orient='index', columns=['utility']),
         pd.DataFrame.from_dict(coverage_uni[i], orient='index', columns=['coverage'])])

    tmp['harmonic_mean'] = tmp.apply(lambda x: 2 / (1/x['productivity'] + 1/x['coverage']), axis=1)
    res_uni.append(tmp)

# %%
RES = res_uni[0]
for i in range(1, NUM_SAMPLES):
    RES = RES.add(res_uni[i], fill_value=0)
RES = RES.div(NUM_SAMPLES)

# %%
RES.sort_values('harmonic_mean', ascending=False).round(4)[:20]
# Out:
#            productivity  utility  coverage  harmonic_mean
# v                0.3619   0.0286    0.3007         0.3283
# se               0.3840   0.0506    0.1458         0.2109
# na               0.3716   0.0383    0.1258         0.1878
# V                0.3943   0.0609    0.1156         0.1782
# je               0.3987   0.0654    0.1021         0.1624
# a                0.4501   0.1168    0.0821         0.1386
# z                0.4441   0.1108    0.0723         0.1242
# o                0.4670   0.1337    0.0463         0.0841
# ve               0.4912   0.1579    0.0460         0.0837
# za               0.4467   0.1134    0.0450         0.0817
# roce             0.4480   0.1147    0.0405         0.0739
# bude             0.4848   0.1514    0.0369         0.0685
# Polsku           0.4327   0.0994    0.0368         0.0675
# s                0.4637   0.1304    0.0356         0.0659
# že               0.4501   0.1168    0.0345         0.0640
# roku             0.4224   0.0891    0.0338         0.0624
# než              0.4170   0.0836    0.0321         0.0596
# Praze            0.4764   0.1431    0.0318         0.0595
# prezident        0.4080   0.0746    0.0313         0.0579
# do               0.5088   0.1754    0.0306         0.0576

# %%
RES.sort_values('productivity', ascending=False)[:10]
# Out:
#               productivity   utility  coverage  harmonic_mean
# bezpečí                1.0  0.666667  0.001709       0.003413
# Asii,                  1.0  0.666667  0.001709       0.003413
# zvláštní               1.0  0.666667  0.001709       0.003413
# premiéra               1.0  0.666667  0.001709       0.003413
# odstraňuje             1.0  0.666667  0.001709       0.003413
# Brazílii               1.0  0.666667  0.003419       0.006814
# Jihomoravská           1.0  0.666667  0.001709       0.003413
# Opavou                 1.0  0.666667  0.003419       0.006814
# unikla                 1.0  0.666667  0.001709       0.003413
# mimosoudní             1.0  0.666667  0.001709       0.003413

# %%
RES.sort_values('coverage', ascending=False)[:10]
# Out:
#     productivity   utility  coverage  harmonic_mean
# v       0.361934  0.028601  0.300684       0.328295
# se      0.383962  0.050629  0.145812       0.210905
# na      0.371599  0.038266  0.125812       0.187843
# V       0.394264  0.060931  0.115556       0.178248
# je      0.398745  0.065412  0.102051       0.162355
# a       0.450088  0.116755  0.082051       0.138633
# z       0.444085  0.110752  0.072308       0.124166
# o       0.467028  0.133695  0.046325       0.084122
# ve      0.491190  0.157857  0.045983       0.083687
# za      0.446729  0.113395  0.044957       0.081652

# %%
# 
for fold in max_counts_uni:
    for k,v in fold.items():
        if k == 'v': print(v)
# Out:
# ('SUPPORTS', 70)
# ('SUPPORTS', 59)
# ('SUPPORTS', 66)
# ('SUPPORTS', 63)
# ('SUPPORTS', 68)
# ('SUPPORTS', 69)
# ('REFUTES', 62)
# ('REFUTES', 64)
# ('SUPPORTS', 58)
# ('NOT ENOUGH INFO', 58)

# %%
RES_ALL = pd.DataFrame.from_dict(productivity_uni_all, orient='index', columns=['productivity']).join(
        [pd.DataFrame.from_dict(utility_uni_all, orient='index', columns=['utility']),
         pd.DataFrame.from_dict(coverage_uni_all, orient='index', columns=['coverage'])])

RES_ALL['harmonic_mean'] = RES_ALL.apply(lambda x: 2 / (1/x['productivity'] + 1/x['coverage']), axis=1)

# %%
RES_ALL.sort_values('harmonic_mean', ascending=False)
# Out:
#            productivity   utility  coverage  harmonic_mean
# v              0.545267  0.211934  0.305085       0.391256
# se             0.531915  0.198582  0.147520       0.230981
# na             0.526066  0.192733  0.132454       0.211625
# V              0.550562  0.217228  0.111739       0.185774
# je             0.472050  0.138716  0.101067       0.166489
# ...                 ...       ...       ...            ...
# 72             1.000000  0.666667  0.000628       0.001255
# vyšší          1.000000  0.666667  0.000628       0.001255
# dolů           1.000000  0.666667  0.000628       0.001255
# stavět         1.000000  0.666667  0.000628       0.001255
# inklinuje      1.000000  0.666667  0.000628       0.001255
#
# [3539 rows x 4 columns]

# %% [markdown]
# ### Bigrams

# %%
RES_BIG_ALL = pd.DataFrame.from_dict(productivity_big_all, orient='index', columns=['productivity']).join(
        [pd.DataFrame.from_dict(utility_big_all, orient='index', columns=['utility']),
         pd.DataFrame.from_dict(coverage_big_all, orient='index', columns=['coverage'])])

RES_BIG_ALL['harmonic_mean'] = RES_BIG_ALL.apply(lambda x: 2 / (1/x['productivity'] + 1/x['coverage']), axis=1)

# %%
RES_BIG_ALL.sort_values('harmonic_mean', ascending=False)
# Out:
#                         productivity   utility  coverage  harmonic_mean
# v Praze                     0.512195  0.178862  0.025738       0.049012
# v roce                      0.615385  0.282051  0.024482       0.047091
# v Polsku                    0.514286  0.180952  0.021971       0.042142
# od roku                     0.515152  0.181818  0.020716       0.039830
# americké protiraketové      0.600000  0.266667  0.018832       0.036519
# ...                              ...       ...       ...            ...
# v Jemenu                    1.000000  0.666667  0.000628       0.001255
# pro výstavbu                1.000000  0.666667  0.000628       0.001255
# železárny, cementárny       1.000000  0.666667  0.000628       0.001255
# celky pro                   1.000000  0.666667  0.000628       0.001255
# loni u                      1.000000  0.666667  0.000628       0.001255
#
# [5830 rows x 4 columns]

# %%
res_big = []
for i in range(NUM_SAMPLES):
    tmp = pd.DataFrame.from_dict(productivity_big[i], orient='index', columns=['productivity']).join(
        [pd.DataFrame.from_dict(utility_big[i], orient='index', columns=['utility']),
         pd.DataFrame.from_dict(coverage_big[i], orient='index', columns=['coverage'])])

    tmp['harmonic_mean'] = tmp.apply(lambda x: 2 / (1/x['productivity'] + 1/x['coverage']), axis=1)
    res_big.append(tmp)

# %%
RES_BIG = res_big[0]
for i in range(1, NUM_SAMPLES):
    RES_BIG = RES_BIG.add(res_big[i], fill_value=0)
RES_BIG = RES_BIG.div(NUM_SAMPLES)

# %%
RES_BIG.sort_values('harmonic_mean', ascending=False).round(4)[:20]
# Out:
#       productivity  utility  coverage  harmonic_mean
# v           0.3571   0.0237    0.3889         0.3722
# z           0.3897   0.0564    0.1985         0.2629
# .           0.3878   0.0545    0.1559         0.2222
# ##y         0.3795   0.0461    0.1504         0.2151
# se          0.3840   0.0506    0.1458         0.2109
# za          0.4115   0.0782    0.1390         0.2075
# V           0.3815   0.0481    0.1427         0.2069
# na          0.3695   0.0362    0.1311         0.1934
# ,           0.3942   0.0609    0.1265         0.1909
# ##m         0.4052   0.0718    0.1058         0.1676
# ##u         0.4440   0.1106    0.1031         0.1670
# je          0.4018   0.0685    0.1029         0.1637
# pro         0.4349   0.1015    0.0889         0.1474
# ##í         0.4158   0.0825    0.0891         0.1466
# ##ě         0.4590   0.1256    0.0865         0.1453
# od          0.3930   0.0597    0.0879         0.1434
# po          0.4442   0.1108    0.0853         0.1425
# a           0.4409   0.1075    0.0838         0.1406
# ##a         0.3878   0.0545    0.0807         0.1333
# ##ní        0.3887   0.0553    0.0721         0.1215

# %%
RES_BIG.sort_values('productivity', ascending=False)[:10]
# Out:
#            productivity   utility  coverage  harmonic_mean
# tym                 1.0  0.666667  0.005128       0.010204
# Slovensku           1.0  0.666667  0.001709       0.003413
# ##ora               1.0  0.666667  0.001709       0.003413
# Oscara              1.0  0.666667  0.001709       0.003413
# rest                1.0  0.666667  0.001709       0.003413
# Rod                 1.0  0.666667  0.001709       0.003413
# ##bul               1.0  0.666667  0.001709       0.003413
# Sei                 1.0  0.666667  0.001709       0.003413
# trad                1.0  0.666667  0.002393       0.004772
# br                  1.0  0.666667  0.002906       0.005792

# %%
RES_BIG.sort_values('coverage', ascending=False)[:10]
# Out:
#      productivity   utility  coverage  harmonic_mean
# v        0.357075  0.023742  0.388889       0.372160
# z        0.389727  0.056394  0.198462       0.262864
# .        0.387790  0.054457  0.155897       0.222187
# ##y      0.379465  0.046132  0.150427       0.215083
# se       0.383962  0.050629  0.145812       0.210905
# V        0.381455  0.048121  0.142735       0.206908
# za       0.411532  0.078198  0.138974       0.207538
# na       0.369509  0.036176  0.131111       0.193434
# ,        0.394207  0.060873  0.126496       0.190938
# ##m      0.405169  0.071836  0.105812       0.167648

# %% [markdown]
# # Dataset-weighted Cue Information

# %% [markdown]
# ## Calculate skip-grams
#
# http://www.lrec-conf.org/proceedings/lrec2006/pdf/357_pdf.pdf
#
# “Insurgents killed in ongoing fighting.”
#
# Bi-grams = {insurgents killed, killed in, in ongoing, ongoing fighting}.
#
# 2-skip-bi-grams = {insurgents killed, insurgents in, insurgents ongoing, killed in, killed ongoing, killed fighting, in ongoing, in fighting, ongoing fighting}
#
# Tri-grams = {insurgents killed in, killed in ongoing, in ongoing fighting}.
#
# 2-skip-tri-grams = {insurgents killed in, insurgents killed ongoing, insurgents killed fighting, insurgents in ongoing, insurgents in fighting, insurgents ongoing fighting, killed in ongoing, killed in fighting, killed ongoing fighting, in ongoing fighting}.

# %%
from nltk.util import skipgrams
import math

# %%
# all data
unigrams_all = [[ii.strip('.') for ii in c.split()] for c in df['claim'] if isinstance(c, str)]
# unigrams = [([ii.strip('.') for ii in c.split()], df['label'][i]) for i, c in enumerate(df['claim']) if isinstance(c, str)]

# bigrams_all = [[i.strip('.') + ' ' + ii.strip('.') 
#                 for i, ii in zip(c.split()[:-1], c.split()[1:])] 
#                 for c in df['claim'] if isinstance(c, str)]

# trigrams_all = [[i.strip('.') + ' ' + ii.strip('.') + ' ' + iii.strip('.') 
#                 for i, ii, iii in zip(c.split()[:-2], c.split()[1:-1], c.split()[2:])] 
#                 for c in df['claim'] if isinstance(c, str)]

# %%
SKIPS = [0, 1, 2, 3, 4]
def get_skipgram_counts(cue_rep: str, skip: str):
    """
        See the equation (3) in the paper
        skip_label == |D_cue=k and D_class=i|
        skip_total == |D_cue=k|
        total == total number of skipgrams
        
        cue_rep = Cue representation: bigram, trigram
        skip = number of skipped tokens
        
        if skip == 4, then skipgrams function generates all the skipgrams with 0, 1, 2, 3 and 4 skipped tokens
        
        Returns:
            TBD
    """
    skip_label, skip_total, total = {}, {}, 0
    skip_doc_freq, total_docs = {}, len(df.claim)
    rep2int = {'bigram': 2, 'trigram': 3}
    if cue_rep in ['bigram', 'trigram']:
        for i, claim in enumerate(df.claim):
            for skipgram in skipgrams(claim.split(), rep2int[cue_rep], skip):
                skipgram = " ".join(list(skipgram))
                # Count skipgrams per cue
                if skipgram in skip_total:
                    skip_total[skipgram] += 1
                else:
                    skip_total[skipgram] = 1
                if skipgram in skip_label:
                    if df.label[i] in skip_label[skipgram]:
                        skip_label[skipgram][df.label[i]] += 1
                    else:
                        skip_label[skipgram][df.label[i]] = 1
                else:
                    skip_label[skipgram] = {df.label[i]: 1}
                total += 1
                
                # Count document frequency per cue
                if skipgram in skip_doc_freq:
                    skip_doc_freq[skipgram].add(i)
                else:
                    skip_doc_freq[skipgram] = set([i])
                
        # Count the distinct docs         
        for k, v in skip_doc_freq.items():
            skip_doc_freq[k] = len(v)
    else:
        print("Cue representation not valid. Only bigram / trigram are valid.")
    return skip_label, skip_total, total, skip_doc_freq, total_docs

# %%
bi_skip_label, bi_skip_total, total, bi_skip_df, total_docs = get_skipgram_counts('bigram', 4)
tri_skip_label, tri_skip_total, total, tri_skip_df, total_docs = get_skipgram_counts('trigram', 4)

# %%
len(bi_skip_label) == len(bi_skip_total) == total
# Out:
# False

# %%
len(bi_skip_label)
# Out:
# 24549

# %%
total
# Out:
# 115430

# %%
def compute_normalised_dist(nominator: dict, denominator: dict):
    """Returns normalised distribution over cues and labels"""
    return {cue: 
            {label: count / total for label, count in nominator[cue].items()} 
            for cue, total in denominator.items()}


def entropy(x: dict):
    return sum([v * math.log(v, 10) for k, v in x.items()])


def lambda_h(N: dict):
    """Information based factor (entropy)"""
    h = {k: 1 + entropy(v) for k, v in N.items()}
    return h


def lambda_f(s: int, doc_freq_per_cue: dict, total_docs: int):
    """
    Frequency-based scaling factor
    equivalent to normalized/scaled document frequency of a cue 
    = the number of documents in which is the cue present
    """
    f = {k: math.pow((v / total_docs), (1/s)) for k, v in doc_freq_per_cue.items()}
    return f


def DCI(lamh: dict, lamf: dict):
    dci = {k: math.sqrt(vh * lamf[k]) for k, vh in lamh.items()}
    return dci

# %%
N = compute_normalised_dist(bi_skip_label, bi_skip_total)
lambh = lambda_h(N)
lambf = lambda_f(3, bi_skip_df, total_docs)
dci = DCI(lambh, lambf)

# %%
dci['ozonová díra']
# Out:
# 0.2541078455237247

# %%
dci = sorted(dci.items(), key=lambda kv: kv[1], reverse=True)

# %%
dci[:20]
# Out:
# [('Bühler Motor', 0.46539105318290536),
#  ('hlavním městě', 0.45609097785104474),
#  ('se v', 0.44383368472024554),
#  ('V hlavním', 0.43637797057691785),
#  ('v roce', 0.4337396859638323),
#  ('v a', 0.43073199232234977),
#  ('Společnost Bühler', 0.42814000822537124),
#  ('Společnost Motor', 0.42814000822537124),
#  ('se z', 0.42814000822537124),
#  ('Motor výrobní', 0.42202462140113994),
#  ('V městě', 0.42202462140113994),
#  ('V se', 0.4192649005125955),
#  ('v v', 0.41388391647892814),
#  ('Bühler výrobní', 0.4138208500999247),
#  ('od roku', 0.4088054353935084),
#  ('křeče je', 0.4082637974977277),
#  ('90 miliónů', 0.4047128967633357),
#  ('firmy Bühler', 0.4047128967633357),
#  ('V byl', 0.4047128967633357),
#  ('Andrzej rakovinu.', 0.4047128967633357)]

# %%
pd.DataFrame(dci, columns =['Cue', 'DCI'])
# Out:
#                  Cue       DCI
# 0       Bühler Motor  0.465391
# 1      hlavním městě  0.456091
# 2               se v  0.443834
# 3          V hlavním  0.436378
# 4             v roce  0.433740
# ...              ...       ...
# 24544     firma chce  0.254108
# 24545   firma koupit  0.254108
# 24546     Air France  0.254108
# 24547   Díky ozonová  0.254108
# 24548   ozonová díra  0.254108
#
# [24549 rows x 2 columns]

# %%
N['ozonová díra']
# Out:
# {'SUPPORTS': 0.3333333333333333,
#  'NOT ENOUGH INFO': 0.3333333333333333,
#  'REFUTES': 0.3333333333333333}

# %%
dci['ozonová díra']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-a0929852df3e> in <module>
# ----> 1 dci['ozonová díra']
#
# TypeError: list indices must be integers or slices, not str

# %%
a = math.log(1/3, 10) * (1/3)
a
# Out:
# -0.15904041823988746

# %%
3 * a
# Out:
# -0.4771212547196624

# %%
1 - (3*a)
# Out:
# 1.4771212547196624

# %%
for k,v in lambf.items():
    if v < 0:
        print(k, v)

# %%
for k,v in lambh.items():
    if v < 0:
        print(k, v)
# Out:
# v v -0.06039520745013127
# v Králové -0.06085694715802137
# v asi -0.039720770839917874
# Hradci Králové -0.011404264707351786
# Králové v -0.004242473054076434
# Záplavy v -0.054920167986144186
# Záplavy Třebíči -0.054920167986144186
# Záplavy jsou -0.054920167986144186
# Záplavy vyloučeny. -0.054920167986144186
# v jsou -0.07899220787758332
# v vyloučeny. -0.054920167986144186
# Třebíči jsou -0.054920167986144186
# Třebíči vyloučeny. -0.054920167986144186
# jsou vyloučeny. -0.054920167986144186
# v je -0.054920167986144186
# V České -0.06085694715802137
# V republice -0.011404264707351564
# V než -0.09861228866810956
# České republice -0.054920167986144186
# republice než -0.09861228866810956
# V Polsku -0.039720770839917874
# V se -0.0018639073312898269
# Andrzej zemřel -0.09005965871078381
# Žulawski zemřel -0.009613758174038312
# zemřel ve -0.07755632706680093
# v ve -0.039720770839917874
# Žulawski na -0.043353426942290385
# Ve se -0.054920167986144186
# druhé polovině -0.09861228866810956
# druhé roku -0.09861228866810956
# polovině roku -0.09861228866810956
# roku se -0.09861228866810956
# 2008 v -0.057905424703673436
# se Praze -0.09861228866810956
# v 000 -0.054920167986144186
# Praze 000 -0.09861228866810956
# Praze demonstrací. -0.09861228866810956
# v konalo -0.039720770839917874
# asi protestních -0.011404264707351786
# asi shromáždění. -0.011404264707351786
# protestních shromáždění. -0.07899220787758332
# V proběhlo -0.039720770839917874
# roce 2008 -0.028183859332925776
# roce v -0.057905424703673436
# Jaroslav je -0.004242473054076434
# Kaczyński je -0.004242473054076434
# americké v -0.018277605542217135
# je protiraketové -0.039720770839917874
# za protiraketové -0.039720770839917874
# umístění Gdansku. -0.039720770839917874
# americké Gdansku. -0.039720770839917874
# protiraketové Gdansku. -0.039720770839917874
# základny Gdansku. -0.039720770839917874
# v Gdansku. -0.039720770839917874
# Astrid Lindgrenová -0.02096076986011708
# z v -0.028394166714372115
# přišlo do -0.039720770839917874
# přišlo Evropy -0.039720770839917874
# do Evropy -0.039720770839917874
# do 1000 -0.09861228866810956
# do lidí. -0.039720770839917874
# Evropy 1000 -0.09861228866810956
# Evropy lidí. -0.039720770839917874
# 1000 lidí. -0.09861228866810956
# V z -0.09861228866810956
# že kaple -0.06085694715802137
# kaple z -0.06085694715802137
# kaple bude -0.06085694715802137
# z bude -0.06085694715802137
# z opravena -0.09861228866810956
# bude opravena -0.06085694715802137
# bude z -0.028183859332925776
# bude peněz -0.036198784819283736
# bude města. -0.036198784819283736
# opravena z -0.06085694715802137
# opravena peněz -0.08219553003876712
# opravena města. -0.06085694715802137
# z peněz -0.036198784819283736
# z města. -0.028183859332925776
# peněz města. -0.036198784819283736
# kaple roku -0.039720770839917874
# kaple 1841 -0.039720770839917874
# kaple opravena -0.004242473054076434
# z z -0.039720770839917874
# roku bude -0.039720770839917874
# roku opravena -0.039720770839917874
# roku z -0.039720770839917874
# 1841 bude -0.039720770839917874
# 1841 opravena -0.039720770839917874
# 1841 z -0.039720770839917874
# Kaple 14 -0.039720770839917874
# Kaple svatých -0.039720770839917874
# Kaple pomocníků -0.039720770839917874
# Kaple v -0.039720770839917874
# 14 svatých -0.039720770839917874
# 14 pomocníků -0.039720770839917874
# 14 v -0.039720770839917874
# svatých pomocníků -0.039720770839917874
# svatých v -0.09005965871078381
# svatých je -0.09861228866810956
# pomocníků v -0.07899220787758332
# pomocníků je -0.09861228866810956
# v majetku -0.09861228866810956
# v církve, -0.07899220787758332
# je majetku -0.09861228866810956
# je církve, -0.054920167986144186
# je ale -0.054920167986144186
# je opraví -0.054920167986144186
# v opraví -0.054920167986144186
# v ji -0.054920167986144186
# majetku církve, -0.054920167986144186
# majetku ale -0.054920167986144186
# majetku opraví -0.054920167986144186
# majetku ji -0.054920167986144186
# majetku město. -0.054920167986144186
# církve, ale -0.054920167986144186
# církve, opraví -0.054920167986144186
# církve, ji -0.054920167986144186
# církve, město. -0.054920167986144186
# Výstava představuje -0.011404264707351786
# Výstava osm -0.011404264707351786
# Velké představuje -0.011404264707351786
# Velké osm -0.011404264707351786
# ticho představuje -0.011404264707351786
# ticho osm -0.011404264707351786
# představuje osm -0.011404264707351786
# Tematická výstava -0.07899220787758332
# Tematická začíná -0.07899220787758332
# Tematická v -0.07899220787758332
# výstava začíná -0.07899220787758332
# výstava v -0.07899220787758332
# výstava Galerii -0.07899220787758332
# začíná v -0.057905424703673436
# začíná Galerii -0.07899220787758332
# začíná Moderního -0.07899220787758332
# v Galerii -0.07899220787758332
# v Moderního -0.07899220787758332
# Galerii Moderního -0.07899220787758332
# Tematická Galerii -0.011404264707351786
# výstava Moderního -0.011404264707351786
# začíná umění -0.011404264707351786
# v umění -0.011404264707351786
# Galerii umění -0.011404264707351786
# Galerii v -0.011404264707351786
# Moderního umění -0.011404264707351786
# Moderního v -0.011404264707351786
# umění v -0.08219553003876712
# Oceňovaný polský -0.09005965871078381
# Oceňovaný režisér -0.057905424703673436
# Oceňovaný Andrzej -0.057905424703673436
# Oceňovaný Žulawski -0.057905424703673436
# polský režisér -0.09005965871078381
# polský Andrzej -0.09005965871078381
# polský Žulawski -0.09005965871078381
# polský na -0.06085694715802137
# režisér Andrzej -0.057905424703673436
# režisér Žulawski -0.057905424703673436
# Oceňovaný zemřel -0.07899220787758332
# režisér zemřel -0.07899220787758332
# Režisér kontroverzního -0.09861228866810956
# Režisér snímku -0.09861228866810956
# Režisér Třetí -0.09861228866810956
# Režisér část -0.09861228866810956
# Režisér noci -0.09861228866810956
# kontroverzního snímku -0.09861228866810956
# kontroverzního Třetí -0.09861228866810956
# kontroverzního část -0.09861228866810956
# kontroverzního noci -0.09861228866810956
# kontroverzního (1971) -0.09861228866810956
# snímku Třetí -0.09861228866810956
# snímku část -0.09861228866810956
# snímku noci -0.09861228866810956
# snímku (1971) -0.09861228866810956
# snímku zemřel -0.09861228866810956
# Třetí část -0.09861228866810956
# Třetí noci -0.09861228866810956
# Třetí (1971) -0.09861228866810956
# Třetí zemřel -0.09861228866810956
# část noci -0.09861228866810956
# část (1971) -0.09861228866810956
# část zemřel -0.09861228866810956
# noci (1971) -0.09861228866810956
# noci zemřel -0.09861228866810956
# (1971) zemřel -0.09861228866810956
# Režisér zemřel -0.039720770839917874
# Režisér ve -0.039720770839917874
# zemřel Varšavě. -0.039720770839917874
# ve Varšavě. -0.039720770839917874
# ve svém -0.09861228866810956
# Podle Blixe -0.06085694715802137
# Blixe neplní -0.011404264707351786
# neplní své -0.004242473054076434
# neplní závazky -0.004242473054076434
# neplní na -0.004242473054076434
# neplní likvidaci -0.004242473054076434
# neplní zbraní -0.004242473054076434
# své závazky -0.004242473054076434
# své likvidaci -0.004242473054076434
# své zbraní -0.004242473054076434
# své hromadného -0.004242473054076434
# závazky na -0.004242473054076434
# závazky likvidaci -0.004242473054076434
# závazky zbraní -0.004242473054076434
# závazky hromadného -0.004242473054076434
# závazky ničení. -0.004242473054076434
# na likvidaci -0.004242473054076434
# na zbraní -0.004242473054076434
# na hromadného -0.004242473054076434
# na ničení. -0.004242473054076434
# likvidaci zbraní -0.004242473054076434
# likvidaci hromadného -0.004242473054076434
# likvidaci ničení. -0.004242473054076434
# Podle se -0.09861228866810956
# s OSN -0.09861228866810956
# s na -0.011404264707351786
# OSN na -0.039720770839917874
# Generální odsoudil -0.09861228866810956
# tajemník odsoudil -0.09861228866810956
# tajemník útok -0.09861228866810956
# OSN odsoudil -0.09861228866810956
# OSN útok -0.09861228866810956
# Pan odsoudil -0.09861228866810956
# Pan útok -0.09861228866810956
# Ki-mun odsoudil -0.09861228866810956
# Ki-mun útok -0.09861228866810956
# odsoudil útok -0.09861228866810956
# Podle je -0.039720770839917874
# Egyptská vláda -0.09861228866810956
# Egyptská se -0.09861228866810956
# Egyptská domnívá, -0.09861228866810956
# Egyptská že -0.09861228866810956
# vláda se -0.09861228866810956
# vláda domnívá, -0.09861228866810956
# vláda že -0.09861228866810956
# se domnívá, -0.09861228866810956
# se že -0.06085694715802137
# se šíří -0.039720770839917874
# domnívá, že -0.09861228866810956
# domnívá, šíří -0.09861228866810956
# domnívá, terorismus. -0.039720770839917874
# že šíří -0.09861228866810956
# že terorismus. -0.09861228866810956
# šíří terorismus. -0.09861228866810956
# Na v -0.011404264707351564
# vlakového nádraží -0.07899220787758332
# vlakového v -0.07899220787758332
# nádraží v -0.07899220787758332
# V rekonstrukce -0.011404264707351786
# hypotečních agentur -0.011404264707351564
# hypotečních Fannie -0.011404264707351564
# hypotečních Mae -0.011404264707351564
# hypotečních a -0.011404264707351564
# hypotečních Freddie -0.011404264707351564
# agentur Fannie -0.011404264707351564
# agentur Mae -0.011404264707351564
# agentur a -0.011404264707351564
# agentur Freddie -0.011404264707351564
# agentur Mac. -0.011404264707351564
# Fannie Mae -0.004242473054076434
# Fannie a -0.004242473054076434
# Fannie Freddie -0.004242473054076434
# Fannie Mac. -0.004242473054076434
# Mae a -0.004242473054076434
# Mae Freddie -0.004242473054076434
# Mae Mac. -0.004242473054076434
# a Freddie -0.004242473054076434
# a Mac. -0.004242473054076434
# Freddie Mac. -0.004242473054076434
# kubánský Chepe. -0.06085694715802137
# disident Chepe. -0.06085694715802137
# americké odmítá -0.012330839103173563
# v odmítá -0.012330839103173563
# v většina -0.036198784819283736
# Polsku odmítá -0.012330839103173563
# Polsku většina -0.036198784819283736
# odmítá většina -0.036198784819283736
# Petr Bódy -0.039720770839917874
# z světové -0.054920167986144186
# z války. -0.054920167986144186
# proběhla světové -0.054920167986144186
# pro v -0.09861228866810956
# se České -0.039720770839917874
# ve se -0.08219553003876734
# republice procenta -0.054920167986144186
# se zúčastnilo -0.039720770839917874
# procenta voličů. -0.09861228866810956
# v přes -0.039720770839917874
# Česko mělo -0.011404264707351564
# Česko na -0.011404264707351564
# mělo na -0.011404264707351564
# Česko se -0.09861228866810956
# se na -0.019865214277929866
# připraveni americké -0.039720770839917874
# Jan Pavel -0.011404264707351564
# Jan II. -0.011404264707351564
# Pavel II. -0.011404264707351564
# v Brně -0.039720770839917874
# o ve -0.054920167986144186
# po v -0.09861228866810956
# srovnání se -0.011404264707351564
# srovnání západní -0.054920167986144186
# srovnání Evropou -0.011404264707351564
# se západní -0.054920167986144186
# se Evropou -0.054920167986144186
# západní Evropou -0.054920167986144186
# obchod ve -0.054920167986144186
# obchod srovnání -0.054920167986144186
# v srovnání -0.054920167986144186
# ČR ve -0.054920167986144186
# ČR srovnání -0.054920167986144186
# ve srovnání -0.054920167986144186
# ve Evropou -0.039720770839917874
# ve a -0.039720770839917874
# obchod je -0.039720770839917874
# ČR se -0.039720770839917874
# je ve -0.09861228866810956
# je srovnání -0.039720770839917874
# je se -0.011404264707351564
# je západní -0.09861228866810956
# je Evropou -0.09861228866810956
# ve západní -0.09861228866810956
# Do větší -0.09861228866810956
# Prahy větší -0.09861228866810956
# Prahy těžší -0.09861228866810956
# létají helikoptéry. -0.09861228866810956
# stále helikoptéry. -0.09861228866810956
# větší helikoptéry. -0.09861228866810956
# a helikoptéry. -0.09861228866810956
# těžší helikoptéry. -0.09861228866810956
# V Brně -0.09861228866810956
# dostal cenu -0.039720770839917874
# poprvé v -0.011404264707351786
# Přes všech -0.054920167986144186
# Přes vozů -0.054920167986144186
# všech bylo -0.011404264707351786
# všech vyrobeno -0.011404264707351786
# vozů bylo -0.011404264707351786
# vozů vyrobeno -0.011404264707351786
# vozů v -0.004242473054076434
# vyrobeno v -0.011404264707351786
# v nad -0.011404264707351564
# Ledči nad -0.06085694715802137
# Ledči Sázavou -0.06085694715802137
# nad Sázavou -0.06085694715802137
# v Ledči -0.054920167986144186
# v Sázavou -0.054920167986144186
# V budově -0.054920167986144186
# V ministerstva -0.054920167986144186
# V zdravotnictví -0.054920167986144186
# budově ministerstva -0.054920167986144186
# budově zdravotnictví -0.054920167986144186
# ministerstva zdravotnictví -0.054920167986144186
# dorazilo s -0.039720770839917874
# obrněných vojáky. -0.039720770839917874
# Konvoj má -0.08219553003876734
# Konvoj demonstrovat -0.08219553003876734
# Konvoj podporu -0.07899220787758332
# Konvoj americké -0.039720770839917874
# Konvoj armády -0.054920167986144186
# má demonstrovat -0.08219553003876734
# má podporu -0.07899220787758332
# má americké -0.039720770839917874
# má armády -0.054920167986144186
# demonstrovat podporu -0.07899220787758332
# demonstrovat americké -0.039720770839917874
# demonstrovat armády -0.054920167986144186
# podporu americké -0.039720770839917874
# podporu armády -0.054920167986144186
# americké armády -0.039720770839917874
# má spojencům -0.011404264707351564
# demonstrovat spojencům -0.07899220787758332
# demonstrovat NATO. -0.039720770839917874
# podporu NATO. -0.039720770839917874
# armády spojencům -0.039720770839917874
# spojencům NATO. -0.054920167986144186
# americké spojencům -0.09861228866810956
# Konvoj USA -0.09861228866810956
# má USA -0.09861228866810956
# demonstrovat USA -0.09861228866810956
# USA spojencům -0.09861228866810956
# USA NATO. -0.09861228866810956
# světovou válku. -0.039720770839917874
# Epopej byla -0.054920167986144186
# Epopej vystavena -0.06085694715802137
# byla vystavena -0.06085694715802137
# vystavena v -0.054920167986144186
# za téměř -0.011404264707351564
# za 2,4 -0.011404264707351564
# téměř 2,4 -0.011404264707351564
# téměř korun. -0.011404264707351564
# 2,4 korun. -0.011404264707351564
# Křeče přehřátí -0.004242473054076434
# Křeče se -0.004242473054076434
# Křeče objevují -0.004242473054076434
# z přehřátí -0.004242473054076434
# z objevují -0.004242473054076434
# přehřátí se -0.004242473054076434
# přehřátí objevují -0.004242473054076434
# se objevují -0.004242473054076434
# přehřátí v -0.039720770839917874
# objevují v -0.039720770839917874
# a pojišťovna -0.054920167986144186
# Pojišťovna Zurich -0.08219553003876712
# Zurich a -0.029653014064573657
# Zurich představily -0.054920167986144186
# a představily -0.054920167986144186
# a nové -0.054920167986144186
# Česká nové -0.054920167986144186
# představily nové -0.054920167986144186
# představily společné -0.054920167986144186
# nové společné -0.054920167986144186
# finančních v -0.09861228866810956
# ve Francii. -0.054920167986144186
# a pohraniční -0.004242473054076434
# a stráž -0.004242473054076434
# a má -0.004242473054076434
# pohraniční stráž -0.004242473054076434
# pohraniční má -0.004242473054076434
# pohraniční k -0.004242473054076434
# stráž má -0.004242473054076434
# stráž k -0.004242473054076434
# stráž roku -0.004242473054076434
# má roku -0.004242473054076434
# má 2020 -0.004242473054076434
# k roku -0.004242473054076434
# k 2020 -0.004242473054076434
# roku 2020 -0.004242473054076434
# 2020 celkem -0.004242473054076434
# a roku -0.004242473054076434
# ArcelorMittal zaměstnancům -0.09861228866810956
# Ostrava zaměstnancům -0.09861228866810956
# Prezident Nicolas -0.011404264707351564
# Prezident Sarkozy -0.011404264707351564
# Nicolas Sarkozy -0.011404264707351564
# Stát loni -0.039720770839917874
# 7. července -0.039720770839917874
# darovali v -0.039720770839917874
# darovali Národnímu -0.09861228866810956
# Národnímu přes -0.09861228866810956
# v dva -0.09861228866810956
# roce dva -0.09861228866810956
# roce miliony -0.09861228866810956
# přes dva -0.09861228866810956
# přes miliony -0.09861228866810956
# hodnotě milionů -0.036198784819283736
# Železné v -0.039720770839917874
# Železné hodnotě -0.039720770839917874
# Rudě v -0.039720770839917874
# Rudě hodnotě -0.039720770839917874
# Rudě 15 -0.039720770839917874
# Noam je -0.039720770839917874
# Chomsky je -0.054920167986144186
# V na -0.011404264707351786
# se chystá -0.054920167986144186
# Gabriel sochu -0.011404264707351786
# roku na -0.039720770839917874
# Vedení mezinárodní -0.039720770839917874
# Vedení plavecké -0.039720770839917874
# Vedení federace -0.039720770839917874
# mezinárodní plavecké -0.039720770839917874
# mezinárodní federace -0.039720770839917874
# teploty měří -0.004242473054076434
# se měří -0.004242473054076434
# od měří -0.004242473054076434
# roku měří -0.004242473054076434
# 1775 měří -0.004242473054076434
# měří v -0.004242473054076434
# Morales plánuje -0.054920167986144186
# Morales kandidovat -0.054920167986144186
# plánuje kandidovat -0.054920167986144186
# prezident Morales -0.09861228866810956
# prezident plánuje -0.09861228866810956
# prezident kandidovat -0.09861228866810956
# Na filmový -0.09861228866810956
# Na festival -0.09861228866810956
# filmový festival -0.09861228866810956
# filmový přijíždí -0.09861228866810956
# festival přijíždí -0.09861228866810956
# přijíždí hvězdy, -0.09861228866810956
# přijíždí fanoušci -0.09861228866810956
# přijíždí čekají -0.09861228866810956
# přijíždí na -0.09861228866810956
# hvězdy, fanoušci -0.09861228866810956
# hvězdy, čekají -0.09861228866810956
# hvězdy, na -0.09861228866810956
# hvězdy, zahájení. -0.09861228866810956
# fanoušci čekají -0.09861228866810956
# fanoušci na -0.09861228866810956
# fanoušci zahájení. -0.09861228866810956
# čekají na -0.09861228866810956
# čekají zahájení. -0.09861228866810956
# na zahájení. -0.09861228866810956
# V Bulharsku -0.054920167986144186
# Na Tchaj-wanu -0.039720770839917874
# městě 8. -0.054920167986144186
# městě března -0.054920167986144186
# 8. března -0.054920167986144186
# 8. soudní -0.039720770839917874
# března soudní -0.039720770839917874
# Ve městě -0.039720770839917874
# Ve 8. -0.039720770839917874
# Ve Nassau -0.09861228866810956
# městě Nassau -0.09861228866810956
# Nassau 8. -0.09861228866810956
# Nassau března -0.09861228866810956
# Gymnasta Konečný -0.004242473054076434
# Gymnasta se -0.039720770839917874
# Martin se -0.039720770839917874
# Konečný se -0.039720770839917874
# bude o -0.039720770839917874
# Česká energetická -0.039720770839917874
# Česká firma -0.039720770839917874
# energetická firma -0.039720770839917874
# energetická chce -0.09861228866810956
# energetická koupit -0.09861228866810956
# firma chce -0.09861228866810956
# firma koupit -0.09861228866810956
# Air France -0.09861228866810956
# provozu letadla -0.039720770839917874
# Díky ozonová -0.09861228866810956
# ozonová díra -0.09861228866810956

# %%
bi_skip_label['ozonová díra']
# Out:
# {'SUPPORTS': 1, 'NOT ENOUGH INFO': 1, 'REFUTES': 1}

# %%
for k,v in lambh.items():
    if bi_skip_total[k] > 10 and v > 0.8:
        print(k, v)
# Out:
# Bühler Motor 0.9168568916127294
# Společnost Bühler 0.8882479343209676
# Společnost Motor 0.8882479343209676
# na území 0.8043237532297054
# V hlavním 1.0
# hlavním městě 0.9104519301976715
# v a 0.842693953748972
# se z 0.8882479343209676

# %%
bi_skip_label['Bühler Motor']
# Out:
# {'SUPPORTS': 20, 'NOT ENOUGH INFO': 1}
